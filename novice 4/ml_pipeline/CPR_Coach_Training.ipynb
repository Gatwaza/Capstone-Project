# %% [markdown]
# <a href="https://colab.research.google.com/github/Gatwaza/Capstone-Project/blob/main/novice%204/ml_pipeline/CPR_Coach_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CPR-Coach · Multi-Task Assessment · TensorFlow/Keras
# **Capstone — ML First Aid Simulation Training Tool**
#
#
# ---
# | Stage | Description |
# |---|---|
# | 1 | Drive mount, paths, GPU |
# | 2 | Annotation parsing (correct format from your actual files) |
# | 3 | PKL keypoint loading + key matching |
# | 4 | Biomechanical feature engineering (12 features) |
# | 5 | Class imbalance analysis + sample weights |
# | 6 | Train / Val / Test split 70-15-15 |
# | 7 | 7 TensorFlow model definitions |
# | 8 | Hyperparameter grid + **resumable** training loop |
# | 9 | Per-class F1, AUC-ROC, confusion matrices |
# | 10 | TFLite INT8 export + CPU latency benchmark |
# | 11 | Final summary report |

# %% [markdown]
# ## 🔧 Fixes Applied (v2)
#
# | # | Location | Bug | Fix |
# |---|----------|-----|-----|
# | 1 | Stage 5 | Class weights computed on full dataset before split — data leakage | Moved class weight computation to Stage 6, computed from training labels only |
# | 2 | Stage 5 | Recoil weights inverted: Complete=1.57, Incomplete=0.73 (Incomplete is actually majority) | Recomputed from training split — now correctly weighted |
# | 3 | Stage 6 | `stratify=y_rate` only — no guarantee depth/recoil stay balanced | Kept `stratify=y_rate`; also added combined label for diagnostics |
# | 4 | Stage 6 | `sample_weight` passed as a **dict** to `model.fit()` — silently ignored by Keras for multi-output models | Changed to a plain 1-D `numpy` array |
# | 5 | Stage 8 | Recoil `loss_weight` was 0.5–1.0 while depth was 2.0–2.5 — model ignored recoil | Raised recoil `loss_weight` to **2.0** across all configs |
# | 6 | Stage 8 | Plain `CategoricalCrossentropy` cannot handle severe class imbalance | Replaced with **FocalCrossEntropy** (γ=2.0, label_smoothing=0.05) |
# | 7 | Stage 8 | `except Exception: break` stops entire sweep on any failure | Changed to `continue` so remaining models still train |
# | 8 | Stage 9 | `preds[i]` (integer index) fails — model returns a **dict** | Fixed to `preds[task]` (key-based indexing) |
# | 9 | Stage 9 | Confusion matrix used same integer indexing bug | Fixed to `preds[task]` |
# | 10 | Stage 4 | `extract_features()` z-scored EVERY sequence against its OWN mean/std before the model ever saw it -- forces every sample, regardless of class, to mean=0/std=1 individually. This made the Stage 4.5 EDA's per-class means and Cohen's d structurally incapable of showing real separability (confirmed: all near-zero/weak, even though the trained model later achieves 75-94% F1) | Removed per-sequence normalization; `extract_features()` now returns raw features. A single `StandardScaler` is fit once on `X_train` only (Stage 6, after the split) and applied to train/val/test -- preserves real absolute-magnitude differences between classes while still scaling inputs sensibly |
# | 11 | Stage 4 + Stage 6 | TRAIN/INFERENCE TEMPORAL-SCALE MISMATCH: `extract_features()` compressed each ~15-46s video down to 60 frames via `np.linspace` (evenly resampled across the WHOLE clip). The live Flutter app, by contrast, sends 60 CONSECUTIVE real-time frames (~2.4s at the dataset's confirmed 25fps) per inference call. The model had never actually seen a "2.4 seconds of consecutive motion" input -- a plausible root cause of the observed `rate_too_fast` over-prediction bias in live testing | `extract_features()` now extracts per-frame features across each FULL video, then a sliding window (60 consecutive frames, stride 30) produces multiple real-time-consistent training windows per video -- matching exactly what the live app sends. Stage 6's split was changed from plain `train_test_split` to `GroupShuffleSplit` keyed on source video, with an explicit assertion verifying zero video overlap across train/val/test (since multiple windows can now share a source video, a naive split would leak video identity across splits and invalidate test metrics) |

# %% [markdown]
# ## STAGE 1 — Environment Setup

# %%
from google.colab import drive
drive.mount('/content/drive')

import os, pickle, re, time, json, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (classification_report, confusion_matrix,
                              roc_auc_score, f1_score)
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks, optimizers, losses, metrics

warnings.filterwarnings('ignore')
tf.random.set_seed(42)
np.random.seed(42)

# ── GPU ──────────────────────────────────────────────────────────────────────
gpus = tf.config.list_physical_devices('GPU')
print(f'TensorFlow : {tf.__version__}')
print(f'GPUs       : {len(gpus)}')
if gpus:
    print(f'GPU name   : {tf.test.gpu_device_name()}')
    tf.config.experimental.set_memory_growth(gpus[0], True)

# ── Paths ─────────────────────────────────────────────────────────────────────
DATA_ROOT      = Path('/content/drive/MyDrive/cpr_coach_data')
KEYPOINTS_DIR  = DATA_ROOT / 'Keypoints'
ANN_DIR        = DATA_ROOT / 'ann'
CHECKPOINT_DIR = Path('/content/drive/MyDrive/cpr_coach_checkpoints_tf')
CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)

# ── Resume state file (tracks which models are already done) ─────────────────
RESUME_FILE = CHECKPOINT_DIR / 'resume_state.json'

print(f'Data root      : {DATA_ROOT}')
print(f'Keypoints dir  : {KEYPOINTS_DIR}')
print(f'Annotation dir : {ANN_DIR}')
print(f'Checkpoint dir : {CHECKPOINT_DIR}')
print('\n✓ Stage 1 complete')
# Out:
# Mounted at /content/drive
# TensorFlow : 2.20.0
# GPUs       : 1
# GPU name   : /device:GPU:0
# Data root      : /content/drive/MyDrive/cpr_coach_data
# Keypoints dir  : /content/drive/MyDrive/cpr_coach_data/Keypoints
# Annotation dir : /content/drive/MyDrive/cpr_coach_data/ann
# Checkpoint dir : /content/drive/MyDrive/cpr_coach_checkpoints_tf
#
# ✓ Stage 1 complete

# %% [markdown]
# ## STAGE 2 — Annotation Parsing (Actual Format)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# ACTION LIST STRUCTURE (from your actual ActionList.txt)
#
# Line indices (1-based) → error descriptions:
#   1  = Correct
#   2  = Overlap Hands          → hand position error  → recoil=Incomplete
#   3  = Clenching Hands        → hand position error  → recoil=Incomplete
#   4  = Single Hand            → hand position error  → recoil=Incomplete
#   5  = Bending Arms           → elbow error          → recoil=Incomplete
#   6  = Tilting Arms           → posture error        → recoil=Incomplete
#   7  = Jump Pressing          → posture/rate error   → rate=Too_Fast
#   8  = Squatting              → posture error        → recoil=Incomplete
#   9  = Standing               → posture error        → recoil=Incomplete
#   10 = Wrong Position         → hand position error  → recoil=Incomplete
#   11 = Insufficient Pressing  → depth error          → depth=Too_Shallow
#   12 = Slow Frequency         → rate error           → rate=Too_Slow
#   13 = Excessive Pressing     → depth error          → depth=Too_Deep
#   14 = Random Position        → hand position error  → recoil=Incomplete
#
# Annotation file formats:
#   trainlist.txt / testlist.txt:
#     <video_path> <numeric_id> <attribute_id>
#     e.g.  CPR_Dataset_S0/C00_S0/r00/ch0  286  0
#     attribute_id=0 → index into doubleClsList OR single-class ID
#
#   all_errors / double_errors / triquad:
#     <video_path> <numeric_id> <class_label> <attribute_id> [<attr2> ...]
#     e.g.  CPR_Double_Dataset_S0/DC00_S0/r00/ch0  381  1  4
#     class_label=1, attribute_id=4 → doubleClsList["4"] = (1,8)
# ─────────────────────────────────────────────────────────────────────────────

# ── Hard-coded doubleClsList from your ActionList.txt ────────────────────────
DOUBLE_CLS = {
    0:(1,4),  1:(1,5),  2:(1,6),  3:(1,7),  4:(1,8),  5:(1,9),
    6:(1,10), 7:(1,11), 8:(1,12), 9:(1,13), 10:(2,6), 11:(2,7),
    12:(2,8), 13:(2,9), 14:(2,10),15:(2,11),16:(2,12),17:(3,6),
    18:(3,7), 19:(3,8), 20:(3,9), 21:(3,10),22:(3,11),23:(3,13),
    24:(4,5), 25:(4,6), 26:(4,7), 27:(4,8), 28:(4,9), 29:(4,10),
    30:(4,11),31:(4,13),32:(5,7), 33:(5,8), 34:(5,9), 35:(5,10),
    36:(5,11),37:(5,13),38:(6,7), 39:(6,8), 40:(6,9), 41:(6,10),
    42:(6,11),43:(6,12),44:(7,9), 45:(7,10),46:(7,11),47:(7,12),
    48:(7,13),49:(8,9), 50:(8,10),51:(8,11),52:(8,12),53:(8,13),
    54:(9,10),55:(9,11),56:(10,11),57:(10,12),58:(10,13)
}

# Map single error index → (rate, depth, recoil) labels
def single_error_to_labels(idx):
    """
    idx: 1-based action list index
    Returns (rate_label, depth_label, recoil_label)
    """
    if idx == 1:  return 'Correct',   'Correct',     'Complete'
    if idx == 7:  return 'Too_Fast',  'Correct',     'Incomplete'  # Jump Pressing
    if idx == 12: return 'Too_Slow',  'Correct',     'Complete'    # Slow Frequency
    if idx == 11: return 'Correct',   'Too_Shallow', 'Complete'    # Insufficient
    if idx == 13: return 'Correct',   'Too_Deep',    'Complete'    # Excessive
    # Everything else is a posture / hand / position error → recoil incomplete
    return 'Correct', 'Correct', 'Incomplete'

def error_tuple_to_labels(error_tuple):
    """
    Combine labels from a tuple of single error indices.
    Worst-case wins per dimension.
    """
    rate, depth, recoil = 'Correct', 'Correct', 'Complete'
    for idx in error_tuple:
        r, d, rc = single_error_to_labels(idx)
        if r   != 'Correct':  rate   = r
        if d   != 'Correct':  depth  = d
        if rc  != 'Complete': recoil = rc
    return rate, depth, recoil


def parse_ann_line(parts):
    """
    Parse one annotation line into (video_path, rate, depth, recoil).
    Handles both 3-column (trainlist) and 4/5-column (multi-error) formats.
    """
    video_path = parts[0]
    # numeric_id = parts[1]  # not used for labels

    if len(parts) == 3:
        # trainlist / testlist: <path> <id> <attr_id>
        attr_id = int(parts[2])
        if attr_id == 0:
            # Correct action
            return video_path, 'Correct', 'Correct', 'Complete'
        else:
            # Single-class error: attr_id is 1-based action index
            r, d, rc = single_error_to_labels(attr_id)
            return video_path, r, d, rc

    elif len(parts) >= 4:
        # Multi-error lists: <path> <id> <class_label> <attr_id> [<attr2>...]
        # attr_id here is key into DOUBLE_CLS
        attr_id = int(parts[3])
        error_tuple = DOUBLE_CLS.get(attr_id, (1,))  # fallback = Correct

        # If triquad: additional error indices follow
        extra = [int(p) for p in parts[4:] if p.isdigit()]
        if extra:
            error_tuple = error_tuple + tuple(extra)

        r, d, rc = error_tuple_to_labels(error_tuple)
        return video_path, r, d, rc

    return None


def load_all_annotations(ann_dir):
    """
    Load every txt file (except ActionList.txt) and return a single DataFrame.
    Excludes optical-flow lists (*_of.txt) since we use skeleton keypoints.
    """
    records = []
    skip = {'ActionList.txt', 'trainlist_of.txt', 'testlist_of.txt'}

    for f in sorted(ann_dir.glob('*.txt')):
        if f.name in skip:
            continue
        source = f.stem
        with open(f) as fh:
            for line in fh:
                parts = line.strip().split()
                if len(parts) < 3:
                    continue
                result = parse_ann_line(parts)
                if result:
                    records.append(result + (source,))

    df = pd.DataFrame(records,
                      columns=['video_path','rate','depth','recoil','source'])
    # Keep one entry per video path (trainlist takes priority over test)
    df = df.drop_duplicates(subset='video_path', keep='first').reset_index(drop=True)
    return df


ann_df = load_all_annotations(ANN_DIR)
print(f'Total annotated sequences : {len(ann_df)}')
print(f'\nSource breakdown:')
print(ann_df['source'].value_counts().to_string())
print(f'\nRate  distribution:')
print(ann_df['rate'].value_counts().to_string())
print(f'\nDepth distribution:')
print(ann_df['depth'].value_counts().to_string())
print(f'\nRecoil distribution:')
print(ann_df['recoil'].value_counts().to_string())
print('\n✓ Stage 2 complete')
# Out:
# Total annotated sequences : 5664
#
# Source breakdown:
# source
# all_errors_testlist    3312
# trainlist              1344
# testlist               1008
#
# Rate  distribution:
# rate
# Correct     4528
# Too_Fast     648
# Too_Slow     488
#
# Depth distribution:
# depth
# Correct        4656
# Too_Deep        552
# Too_Shallow     456
#
# Recoil distribution:
# recoil
# Incomplete    3864
# Complete      1800
#
# ✓ Stage 2 complete

# %% [markdown]
# ## STAGE 3 — PKL Loading + Key Matching

# %%
import pickle

def load_pkl(path):
    with open(path, 'rb') as f:
        return pickle.load(f)

print('Loading pkl files...')
train_kps = load_pkl(KEYPOINTS_DIR / 'train_keypoints.pkl')
test_kps  = load_pkl(KEYPOINTS_DIR / 'test_keypoints.pkl')

for label, kps in [('train', train_kps), ('test', test_kps)]:
    print(f'\n{label}_keypoints.pkl')
    print(f'  count : {len(kps)}')
    if kps:
        item = kps[0]
        if isinstance(item, dict):
            print(f'  keys       : {list(item.keys())}')
            print(f'  frame_dir  : {item.get("frame_dir", "N/A")}')
            if 'keypoint' in item:
                print(f'  kp shape   : {np.array(item["keypoint"]).shape}')

all_kps = {}
for kps_list in [train_kps, test_kps]:
    for item in kps_list:
        if isinstance(item, dict) and 'frame_dir' in item and 'keypoint' in item:
            all_kps[item['frame_dir']] = item['keypoint']

print(f'\nUnique physical videos in PKL : {len(all_kps)}')

print('\nSample raw PKL frame_dir keys:')
for k in list(all_kps.keys())[:8]:
    print(f'  {k!r}')

print('\nSample raw annotation video_path values:')
for p in ann_df['video_path'].head(8).tolist():
    print(f'  {p!r}')

def strip_key(k):
    return str(k).lstrip('./').strip()

pkl_exact = {strip_key(k): k for k in all_kps.keys()}
ann_df['key_norm'] = ann_df['video_path'].apply(strip_key)
matched = ann_df['key_norm'].isin(pkl_exact)
print(f'\nExact-path match   : {matched.sum()} / {len(ann_df)}')

if matched.sum() < len(all_kps) * 0.5:
    def suffix3(k):
        parts = strip_key(k).replace('\\', '/').split('/')
        return '/'.join(parts[-3:]) if len(parts) >= 3 else strip_key(k)
    pkl_s3  = {suffix3(k): k for k in all_kps.keys()}
    ann_df['key_norm'] = ann_df['video_path'].apply(suffix3)
    matched = ann_df['key_norm'].isin(pkl_s3)
    pkl_exact = pkl_s3
    print(f'3-part suffix match: {matched.sum()} / {len(ann_df)}')

if matched.sum() < len(all_kps) * 0.5:
    def suffix2(k):
        parts = strip_key(k).replace('\\', '/').split('/')
        return '/'.join(parts[-2:]) if len(parts) >= 2 else strip_key(k)
    pkl_s2  = {suffix2(k): k for k in all_kps.keys()}
    ann_df['key_norm'] = ann_df['video_path'].apply(suffix2)
    matched = ann_df['key_norm'].isin(pkl_s2)
    pkl_exact = pkl_s2
    print(f'2-part suffix match: {matched.sum()} / {len(ann_df)}')
    print('⚠ WARNING: 2-part keys cause collisions across datasets.')
    print('  Multiple annotations will map to the same physical video.')
    print('  EDA below will detect and deduplicate these.')

pkl_norm    = pkl_exact
ann_matched = ann_df[matched].copy()
print(f'\nProceeding with {len(ann_matched)} matched annotation rows')
print(f'Unique matched keys : {ann_matched["key_norm"].nunique()}')
if ann_matched["key_norm"].nunique() < len(ann_matched):
    n_dup = len(ann_matched) - ann_matched["key_norm"].nunique()
    print(f'⚠ {n_dup} annotation rows share a PKL key — EDA will resolve.')
print('\n✓ Stage 3 complete')
# Out:
# Loading pkl files...
#
# train_keypoints.pkl
#   count : 1344
#   keys       : ['label', 'frame_dir', 'img_shape', 'original_shape', 'keypoint', 'keypoint_score', 'total_frames']
#   frame_dir  : CPR_Dataset_S0_BIG/C00_S0/r00/ch0
#   kp shape   : (1, 286, 68, 2)
#
# test_keypoints.pkl
#   count : 1008
#   keys       : ['label', 'frame_dir', 'img_shape', 'original_shape', 'keypoint', 'keypoint_score', 'total_frames']
#   frame_dir  : CPR_Dataset_S0_BIG/C00_S0/r11/ch0
#   kp shape   : (1, 293, 68, 2)
#
# Unique physical videos in PKL : 2352
#
# Sample raw PKL frame_dir keys:
#   'CPR_Dataset_S0_BIG/C00_S0/r00/ch0'
#   'CPR_Dataset_S0_BIG/C00_S0/r00/ch1'
#   'CPR_Dataset_S0_BIG/C00_S0/r00/ch2'
#   'CPR_Dataset_S0_BIG/C00_S0/r00/ch3'
#   'CPR_Dataset_S0_BIG/C00_S0/r01/ch0'
#   'CPR_Dataset_S0_BIG/C00_S0/r01/ch1'
#   'CPR_Dataset_S0_BIG/C00_S0/r01/ch2'
#   'CPR_Dataset_S0_BIG/C00_S0/r01/ch3'
#
# Sample raw annotation video_path values:
#   'CPR_Double_Dataset_S0/DC00_S0/r00/ch0'
#   'CPR_Double_Dataset_S0/DC00_S0/r00/ch1'
#   'CPR_Double_Dataset_S0/DC00_S0/r00/ch2'
#   'CPR_Double_Dataset_S0/DC00_S0/r00/ch3'
#   'CPR_Double_Dataset_S0/DC00_S0/r01/ch0'
#   'CPR_Double_Dataset_S0/DC00_S0/r01/ch1'
#   'CPR_Double_Dataset_S0/DC00_S0/r01/ch2'
#   'CPR_Double_Dataset_S0/DC00_S0/r01/ch3'
#
# Exact-path match   : 0 / 5664
# 3-part suffix match: 2352 / 5664
#
# Proceeding with 2352 matched annotation rows
# Unique matched keys : 2352
#
# ✓ Stage 3 complete

# %% [markdown]
# New Cell — Stage 3.5 EDA (insert after Cell 6, before Stage 4)

# %%
print('='*65)
print('EDA 1 — KEY COLLISION AUDIT')
print('='*65)
collision = ann_matched.groupby('key_norm').size()
multi     = collision[collision > 1]
print(f'Annotation rows               : {len(ann_matched)}')
print(f'Unique PKL keys               : {len(all_kps)}')
print(f'Unique matched annotation keys: {ann_matched["key_norm"].nunique()}')
print(f'PKL keys with >1 annotation   : {len(multi)}')

if len(multi) > 0:
    print('\nSample collisions (same physical video, multiple annotation rows):')
    for key in multi.index[:4]:
        rows = ann_matched[ann_matched['key_norm'] == key][
            ['source', 'video_path', 'rate', 'depth', 'recoil']]
        print(f'\n  PKL key: {key!r}')
        print(rows.to_string(index=False))
    print(f'\n→ Resolution: keep first annotation per key (train > test priority).')
    print(f'  Before dedup: {len(ann_matched)} rows')
    ann_matched = (ann_matched
                   .sort_values('source',
                                key=lambda s: s.map({'trainlist':0,'testlist':1,
                                                     'all_errors_testlist':2}).fillna(3))
                   .drop_duplicates(subset='key_norm', keep='first')
                   .reset_index(drop=True))
    print(f'  After dedup : {len(ann_matched)} rows  ← true dataset size')
else:
    print('✓ No collisions.')

print('\n' + '='*65)
print('EDA 2 — TRUE LABEL DISTRIBUTION (post-dedup)')
print('='*65)
for col in ['rate', 'depth', 'recoil']:
    vc = ann_matched[col].value_counts()
    print(f'\n{col}:')
    for cls, n in vc.items():
        bar = '█' * (n * 35 // vc.max())
        print(f'  {cls:15s}  {n:5d}  ({100*n/len(ann_matched):5.1f}%)  {bar}')

print('\n' + '='*65)
print('EDA 3 — LABEL DISTRIBUTION PER SOURCE FILE')
print('='*65)
for col in ['rate', 'depth', 'recoil']:
    print(f'\n{col.upper()} × source:')
    print(pd.crosstab(ann_matched['source'], ann_matched[col], margins=True).to_string())

print('\n' + '='*65)
print('EDA 4 — LABEL CO-OCCURRENCE')
print('='*65)
print('Rate × Depth:')
print(pd.crosstab(ann_matched['rate'], ann_matched['depth'], margins=True).to_string())
print('\nRate × Recoil:')
print(pd.crosstab(ann_matched['rate'], ann_matched['recoil'], margins=True).to_string())
print('\nDepth × Recoil:')
print(pd.crosstab(ann_matched['depth'], ann_matched['recoil'], margins=True).to_string())

print('\n' + '='*65)
print('EDA 5 — SEQUENCE LENGTH DISTRIBUTION')
print('='*65)
frame_counts = []
for row in ann_matched.itertuples():
    raw_key = pkl_norm.get(row.key_norm)
    if raw_key is None:
        continue
    arr = np.array(all_kps[raw_key], dtype=np.float32)
    if arr.ndim == 4:
        arr = arr.squeeze(0)
    frame_counts.append(arr.shape[0])

fc = np.array(frame_counts)
print(f'n={len(fc)}  min={fc.min()}  median={np.median(fc):.0f}  '
      f'mean={fc.mean():.0f}  max={fc.max()}  std={fc.std():.1f}')
bins  = [0,30,60,90,120,150,200,9999]
blbls = ['<30','30-60','60-90','90-120','120-150','150-200','>200']
hist,_ = np.histogram(fc, bins=bins)
for lbl, cnt in zip(blbls, hist):
    bar = '█' * (cnt * 40 // (hist.max()+1))
    print(f'  {lbl:>10}  {cnt:4d}  {bar}')
pct_short = 100*(fc < 60).sum()/len(fc)
print(f'\nSEQ_LEN=60. Sequences shorter: {(fc<60).sum()} ({pct_short:.1f}%)')
if pct_short > 20:
    print(f'⚠ Consider lowering SEQ_LEN to ~{int(np.percentile(fc,25))} (25th pct).')

print('\n' + '='*65)
print('EDA 6 — RECOIL ENCODING DIRECTION CHECK')
print('='*65)
_enc = LabelEncoder().fit(ann_matched['recoil'].tolist())
_y   = _enc.transform(ann_matched['recoil'].tolist())
_w   = compute_class_weight('balanced', classes=np.unique(_y), y=_y)
for i, (cls, w) in enumerate(zip(_enc.classes_, _w)):
    n   = (ann_matched['recoil'] == cls).sum()
    tag = 'MAJORITY → weight must be <1.0' if n > len(ann_matched)//2 else 'minority → weight >1.0'
    ok  = '✓' if (n > len(ann_matched)//2 and w < 1.0) or \
                  (n <= len(ann_matched)//2 and w > 1.0) else '✗ INVERTED'
    print(f'  {i} → {cls:12s}  n={n:5d}  weight={w:.3f}  {tag}  {ok}')

print('\n✓ Stage 3.5 EDA complete — review before running Stage 4')
# Out:
# =================================================================
# EDA 1 — KEY COLLISION AUDIT
# =================================================================
# Annotation rows               : 2352
# Unique PKL keys               : 2352
# Unique matched annotation keys: 2352
# PKL keys with >1 annotation   : 0
# ✓ No collisions.
#
# =================================================================
# EDA 2 — TRUE LABEL DISTRIBUTION (post-dedup)
# =================================================================
#
# rate:
#   Correct           2016  ( 85.7%)  ███████████████████████████████████
#   Too_Fast           168  (  7.1%)  ██
#   Too_Slow           168  (  7.1%)  ██
#
# depth:
#   Correct           2016  ( 85.7%)  ███████████████████████████████████
#   Too_Shallow        168  (  7.1%)  ██
#   Too_Deep           168  (  7.1%)  ██
#
# recoil:
#   Incomplete        1512  ( 64.3%)  ███████████████████████████████████
#   Complete           840  ( 35.7%)  ███████████████████
#
# =================================================================
# EDA 3 — LABEL DISTRIBUTION PER SOURCE FILE
# =================================================================
#
# RATE × source:
# rate       Correct  Too_Fast  Too_Slow   All
# source
# testlist       864        72        72  1008
# trainlist     1152        96        96  1344
# All           2016       168       168  2352
#
# DEPTH × source:
# depth      Correct  Too_Deep  Too_Shallow   All
# source
# testlist       864        72           72  1008
# trainlist     1152        96           96  1344
# All           2016       168          168  2352
#
# RECOIL × source:
# recoil     Complete  Incomplete   All
# source
# testlist        360         648  1008
# trainlist       480         864  1344
# All             840        1512  2352
#
# =================================================================
# EDA 4 — LABEL CO-OCCURRENCE
# =================================================================
# Rate × Depth:
# depth     Correct  Too_Deep  Too_Shallow   All
# rate
# Correct      1680       168          168  2016
# Too_Fast      168         0            0   168
# Too_Slow      168         0            0   168
# All          2016       168          168  2352
#
# Rate × Recoil:
# recoil    Complete  Incomplete   All
# rate
# Correct        672        1344  2016
# Too_Fast         0         168   168
# Too_Slow       168           0   168
# All            840        1512  2352
#
# Depth × Recoil:
# recoil       Complete  Incomplete   All
# depth
# Correct           504        1512  2016
# Too_Deep          168           0   168
# Too_Shallow       168           0   168
# All               840        1512  2352
#
# =================================================================
# EDA 5 — SEQUENCE LENGTH DISTRIBUTION
# =================================================================
# n=2352  min=158  median=350  mean=374  max=1155  std=161.7
#          <30     0
#        30-60     0
#        60-90     0
#       90-120     0
#      120-150     0
#      150-200   156  ██
#         >200  2196  ███████████████████████████████████████
#
# SEQ_LEN=60. Sequences shorter: 0 (0.0%)
#
# =================================================================
# EDA 6 — RECOIL ENCODING DIRECTION CHECK
# =================================================================
#   0 → Complete      n=  840  weight=1.400  minority → weight >1.0  ✓
#   1 → Incomplete    n= 1512  weight=0.778  MAJORITY → weight must be <1.0  ✓
#
# ✓ Stage 3.5 EDA complete — review before running Stage 4

# %% [markdown]
# ## STAGE 4 — Biomechanical Feature Engineering (12 Features)

# %%
# ── AlphaPose COCO-17 joint indices ──────────────────────────────────────────
J = dict(nose=0, l_shoulder=5, r_shoulder=6,
         l_elbow=7, r_elbow=8, l_wrist=9, r_wrist=10,
         l_hip=11,  r_hip=12)

SEQ_LEN  = 60
N_JOINTS = 17
N_COORDS = 3   # x, y, confidence
N_FEATS  = 12

# FIX (major, post v2): root-cause fix for systematic misclassification
# (confirmed live-app bias toward "rate_too_fast") -- a TRAIN/INFERENCE
# TEMPORAL-SCALE MISMATCH, not a hyperparameter or normalization issue.
#
# The CPR-Coach dataset paper (Table 2) confirms recording at 25 FPS, and
# our live Flutter app also runs pose estimation at 25 FPS -- so frame
# RATE was never the problem. The actual mismatch: every training video
# averages ~374 frames (~15s) and up to 1155 frames (~46s) per the Stage
# 3.5 EDA, but the OLD extract_features() compressed each entire video
# down to just SEQ_LEN=60 frames using `np.linspace(0, T-1, 60)` --
# i.e. 60 frames EVENLY RESAMPLED ACROSS THE WHOLE CLIP, not 60
# consecutive real-time frames.
#
# The live app, by contrast, sends the API 60 CONSECUTIVE real-time
# frames at 25fps (~2.4 real seconds) every inference call
# (inference_service_web.dart's _frameBuffer). The trained model has
# never actually seen "2.4 seconds of consecutive motion" as an input --
# it only ever saw "a sparse, evenly-spaced skeleton of an entire ~15s
# clip." These are different signals occupying the same (60, 12) shape.
# A genuinely-correct-rate compression sampled at full real-time density
# can look, frame-to-frame, like the rapid/jittery pattern the model
# associates with Too_Fast from its sparse training view -- a plausible
# driver of the observed rate_too_fast bias.
#
# FIX: extract per-frame features across the FULL video (no resampling),
# then slide a SEQ_LEN=60 CONSECUTIVE-frame window across it with stride
# WINDOW_STRIDE, producing multiple training windows per video. This
# matches exactly what the live app actually sends at inference time.
# Every window inherits its source video's single label (the CPR-Coach
# protocol has each volunteer perform ONE demonstrated error for the
# video's whole duration, so this is a valid label assignment).
#
# NOTE: this means multiple windows can come from the same physical
# video. Stage 6 train/val/test split MUST split by video (frame_dir),
# not by window, to avoid windows from one video leaking across splits.
# See `video_key` tracking added below and the updated Stage 6 split.
WINDOW_STRIDE = 30  # 1.2s hop at 25fps -- 50% overlap between windows

def angle_deg(a, b, c):
    """Interior angle at b, given 2-D points a, b, c."""
    ba = a - b;  bc = c - b
    cos = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc) + 1e-8)
    return np.degrees(np.arccos(np.clip(cos, -1.0, 1.0)))

def coerce_shape(arr):
    arr = np.array(arr, dtype=np.float32)
    if arr.ndim == 4: # Handle (1, T, 68, 2) common in some AlphaPose versions
        arr = arr.squeeze(0)
    if arr.shape[-2] == 68:
        # Crop 68 joints to first 17 (COCO format)
        arr = arr[:, :17, :]

    if arr.ndim == 3 and arr.shape[1] == N_JOINTS:
        if arr.shape[2] == 2:
            # Add dummy confidence if missing
            conf = np.ones((arr.shape[0], N_JOINTS, 1))
            arr = np.concatenate([arr, conf], axis=-1)
        return arr

    # Fallback to existing logic
    if arr.ndim == 3 and arr.shape[1] == N_JOINTS and arr.shape[2] == N_COORDS:
        return arr
    total = arr.size
    if total % (N_JOINTS * N_COORDS) == 0:
        T = total // (N_JOINTS * N_COORDS)
        return arr.reshape(T, N_JOINTS, N_COORDS)
    raise ValueError(f'Cannot interpret array shape {arr.shape} as keypoints')

def extract_features_full(seq_data):
    """Per-frame features across the ENTIRE video (no resampling, no
    windowing) -- shape (T, N_FEATS) where T is the video's true frame
    count. Windowing into SEQ_LEN-frame consecutive clips happens
    separately, in the extraction loop below."""
    seq  = coerce_shape(seq_data)          # (T, 17, 3)
    T    = seq.shape[0]
    xy   = seq[:, :, :2]
    conf = seq[:, :, 2]
    feats = np.zeros((T, N_FEATS), dtype=np.float32)
    upper_joints = [J['l_shoulder'], J['r_shoulder'], J['l_elbow'], J['r_elbow'], J['l_wrist'], J['r_wrist']]

    for t in range(T):
        ls, rs = xy[t, J['l_shoulder']], xy[t, J['r_shoulder']]
        le, re = xy[t, J['l_elbow']], xy[t, J['r_elbow']]
        lw, rw = xy[t, J['l_wrist']], xy[t, J['r_wrist']]
        lh, rh = xy[t, J['l_hip']], xy[t, J['r_hip']]

        feats[t, 0] = angle_deg(ls, le, lw)
        feats[t, 1] = angle_deg(rs, re, rw)
        feats[t, 2] = (feats[t, 0] + feats[t, 1]) / 2.0
        mid_s, mid_h = (ls + rs) / 2.0, (lh + rh) / 2.0
        spine = mid_h - mid_s
        feats[t, 3] = np.degrees(np.arctan2(np.abs(spine[0]), np.abs(spine[1]) + 1e-8))
        sw = np.linalg.norm(rs - ls) + 1e-8
        feats[t, 8] = sw
        feats[t, 4] = ((lw[1] + rw[1]) / 2.0) / sw
        feats[t, 9] = conf[t, upper_joints].mean()
        feats[t, 10] = float(conf[t, J['l_elbow']] < 0.3)
        feats[t, 11] = float(conf[t, J['r_elbow']] < 0.3)

    wy = feats[:, 4]
    feats[:, 5], feats[:, 6] = np.gradient(wy), np.gradient(np.gradient(wy))
    feats[:, 7] = np.abs(wy - wy.mean()) / (feats[:, 8].mean() + 1e-8)

    # Per-frame angle/ratio features are already scale-invariant by
    # construction -- no normalization here. wrist_vel/wrist_accel/
    # wrist_amp get a SHARED, GLOBAL scale fitted once on X_train only in
    # Stage 6 (after the split), not per-video and not per-window.
    return feats.astype(np.float32)

def make_windows(feats_full, seq_len=SEQ_LEN, stride=WINDOW_STRIDE):
    """Slide a `seq_len`-consecutive-frame window across a full video's
    feature sequence, producing one or more (seq_len, N_FEATS) windows.
    Videos shorter than seq_len are zero-padded at the end into a single
    window (rare -- EDA showed min length 158, well above 60, but this
    guards against any edge case)."""
    T = feats_full.shape[0]
    if T < seq_len:
        pad = np.zeros((seq_len - T, N_FEATS), dtype=np.float32)
        return [np.concatenate([feats_full, pad], axis=0)]
    starts = list(range(0, T - seq_len + 1, stride))
    if not starts or starts[-1] != T - seq_len:
        starts.append(T - seq_len)  # ensure the tail of the video is covered
    return [feats_full[s:s + seq_len] for s in starts]

print('Building feature matrix (sliding-window, consecutive-frame)...')
X_list, rate_list, depth_list, recoil_list, video_key_list = [], [], [], [], []
skipped_keys, skipped_errors = 0, 0
windows_per_video = []

for i, (_, row) in enumerate(ann_matched.iterrows()):
    raw_key = pkl_norm.get(row['key_norm'])
    if raw_key is None:
        skipped_keys += 1
        continue
    try:
        feats_full = extract_features_full(all_kps[raw_key])
        windows = make_windows(feats_full)
        windows_per_video.append(len(windows))
        for w in windows:
            X_list.append(w)
            rate_list.append(row['rate'])
            depth_list.append(row['depth'])
            recoil_list.append(row['recoil'])
            video_key_list.append(row['key_norm'])  # tracks source video for Stage 6 split
    except Exception as e:
        skipped_errors += 1
        if skipped_errors < 5:
            print(f"Error processing {raw_key}: {e}")

X = np.array(X_list, dtype=np.float32)
video_keys = np.array(video_key_list)
print(f'Feature matrix      : {X.shape}')
print(f'Source videos used  : {len(windows_per_video)}')
print(f'Windows per video   : min={min(windows_per_video)}  '
      f'mean={np.mean(windows_per_video):.1f}  max={max(windows_per_video)}')
print(f'Total windows       : {len(X_list)}  (was {len(windows_per_video)} before windowing)')
print(f'Key missing         : {skipped_keys}')
print(f'Process errors      : {skipped_errors}')
# Out:
# Building feature matrix (sliding-window, consecutive-frame)...
# Feature matrix      : (28076, 60, 12)
# Source videos used  : 2352
# Windows per video   : min=5  mean=11.9  max=38
# Total windows       : 28076  (was 2352 before windowing)
# Key missing         : 0
# Process errors      : 0

# %% [markdown]
# New Cell — Stage 4.5 Feature EDA (insert after Stage 4)

# %%
# NOTE: Stage 4 changed in two ways since the original version of this
# notebook:
#   1. extract_features() no longer z-scores each window individually --
#      X_list now holds RAW feature values (global scaling happens once,
#      later, in Stage 6, fit on X_train only).
#   2. Each video now contributes MULTIPLE overlapping 60-consecutive-
#      frame windows (sliding window) instead of one resampled window --
#      X_list is now indexed by WINDOW, not by video.
# Both changes mean the Cohen's d / per-class-mean numbers below will
# look very different from earlier runs: previously every sequence was
# forced to mean=0/std=1 BEFORE this cell ever ran (guaranteeing near-zero
# separability regardless of true signal), and windows are now a more
# direct, consecutive-frame view of each class's actual motion pattern.
# This cell is the first real look at whether the 12 features actually
# separate the classes under the corrected representation.
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler

X_arr  = np.array(X_list)
X_mean = X_arr.mean(axis=1)

feat_names = ['L_elbow_angle','R_elbow_angle','mean_elbow','spine_lean',
              'wrist_ht_norm','wrist_vel','wrist_accel','wrist_amp',
              'shoulder_w','upper_conf','L_elbow_low_c','R_elbow_low_c']

def cohens_d(a, b):
    return abs(a.mean()-b.mean()) / (np.sqrt((a.var()+b.var())/2)+1e-8)

task_info = [('Rate',rate_list,'Correct'),('Depth',depth_list,'Correct'),
             ('Recoil',recoil_list,'Complete')]

print('='*65)
print("FEATURE SEPARABILITY — Cohen's d")
print('='*65)
sep_warnings = []
for task, labels, ref_cls in task_info:
    la  = np.array(labels)
    ref = X_mean[la == ref_cls]
    print(f'\n{task}:')
    for cls in sorted(set(labels)):
        if cls == ref_cls: continue
        err = X_mean[la == cls]
        ds  = [cohens_d(ref[:,f], err[:,f]) for f in range(12)]
        bf  = int(np.argmax(ds))
        bd  = ds[bf]
        flag = '✓ separable' if bd > 0.5 else '⚠ WEAK (<0.5)'
        print(f'  vs {cls:12s} (n={len(err):4d})  best: {feat_names[bf]:20s}  d={bd:.3f}  {flag}')
        if bd <= 0.5: sep_warnings.append(f'{task}:{cls}')

if sep_warnings:
    print(f'\n⚠ Weak classes: {sep_warnings}')
    print('  Add features: peak wrist-Y, compression rate (velocity zero-crossings).')

print('\n' + '='*65)
print('MEAN FEATURE VALUES PER CLASS')
print('='*65)
for task, labels, _ in task_info:
    la = np.array(labels)
    df_tmp = pd.DataFrame(X_mean, columns=feat_names)
    df_tmp['label'] = la
    print(f'\n{task}:')
    print(df_tmp.groupby('label').mean().round(3).to_string())

fig, axes = plt.subplots(2, 3, figsize=(18, 8))
for col, (task, labels, _) in enumerate(task_info):
    la = np.array(labels)
    for feat_idx, feat_lbl, row in [(5,'wrist_vel',0),(4,'wrist_ht_norm',1)]:
        ax = axes[row][col]
        for cls in sorted(set(labels)):
            idx = np.where(la == cls)[0]
            ax.plot(X_arr[idx,:,feat_idx].mean(axis=0),
                    label=f'{cls} (n={len(idx)})', lw=1.8)
        ax.set_title(f'{task} — {feat_lbl}')
        ax.set_xlabel('Frame (0-59)')
        ax.legend(fontsize=7)
        ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(str(CHECKPOINT_DIR / 'eda_temporal_profiles.png'), dpi=150, bbox_inches='tight')
plt.show()

print('\n' + '='*65)
print('LDA SEPARABILITY SCORE')
print('='*65)
scaler = StandardScaler()
X_sc   = scaler.fit_transform(X_mean)
for task, labels, ref_cls in task_info:
    la    = np.array(labels)
    y_bin = (la != ref_cls).astype(int)
    lda   = LinearDiscriminantAnalysis()
    score = lda.fit(X_sc, y_bin).score(X_sc, y_bin)
    print(f'  {task:6s}  LDA acc = {score*100:.1f}%  (50%=random, 100%=perfectly separable)')

print('\n✓ Feature EDA complete')
# Out:
# =================================================================
# FEATURE SEPARABILITY — Cohen's d
# =================================================================
#
# Rate:
#   vs Too_Fast     (n=1788)  best: R_elbow_angle         d=0.532  ✓ separable
#   vs Too_Slow     (n=1804)  best: R_elbow_angle         d=0.377  ⚠ WEAK (<0.5)
#
# Depth:
#   vs Too_Deep     (n=1927)  best: R_elbow_angle         d=0.315  ⚠ WEAK (<0.5)
#   vs Too_Shallow  (n=4987)  best: R_elbow_angle         d=0.350  ⚠ WEAK (<0.5)
#
# Recoil:
#   vs Incomplete   (n=15737)  best: R_elbow_angle         d=0.461  ⚠ WEAK (<0.5)
#
# ⚠ Weak classes: ['Rate:Too_Slow', 'Depth:Too_Deep', 'Depth:Too_Shallow', 'Recoil:Incomplete']
#   Add features: peak wrist-Y, compression rate (velocity zero-crossings).
#
# =================================================================
# MEAN FEATURE VALUES PER CLASS
# =================================================================
#
# Rate:
#           L_elbow_angle  R_elbow_angle  mean_elbow  spine_lean  wrist_ht_norm    wrist_vel   wrist_accel     wrist_amp  shoulder_w  upper_conf  L_elbow_low_c  R_elbow_low_c
# label
# Correct      162.136993     166.501007  164.319000   35.543999    159736544.0  523263.6250  2.701422e+05  5.991566e+06  352.364990         1.0            0.0            0.0
# Too_Fast     164.615005     172.856995  168.735992   30.990000      4308382.5  673905.0625 -2.021715e+06  1.050876e+05  346.138000         1.0            0.0            0.0
# Too_Slow     159.143005     171.151001  165.147003   38.174000     41742432.0  675782.1250 -4.472504e+04  9.858719e+05  343.790985         1.0            0.0            0.0
#
# Depth:
#              L_elbow_angle  R_elbow_angle  mean_elbow  spine_lean  wrist_ht_norm   wrist_vel    wrist_accel     wrist_amp  shoulder_w  upper_conf  L_elbow_low_c  R_elbow_low_c
# label
# Correct         161.841003     166.106003  163.973007   35.837002    155990080.0  719952.750  135586.109375  6.316032e+06  354.326996         1.0            0.0            0.0
# Too_Deep        164.011993     170.098999  167.056000   32.456001    353600448.0      -0.397   25624.210938  7.657869e+06  337.407990         1.0            0.0            0.0
# Too_Shallow     162.473007     170.746002  166.608994   34.811001      2315289.5      -0.001       0.000000  4.959480e+04  344.484009         1.0            0.0            0.0
#
# Recoil:
#             L_elbow_angle  R_elbow_angle  mean_elbow  spine_lean  wrist_ht_norm     wrist_vel  wrist_accel  wrist_amp  shoulder_w  upper_conf  L_elbow_low_c  R_elbow_low_c
# label
# Complete       163.261993     170.860992  167.061996   35.410000    131034984.0 -2.130292e+05 -169650.9375  3589394.0  347.596008         1.0            0.0            0.0
# Incomplete     161.192001     164.337006  162.764999   35.432999    151055200.0  1.135172e+06  318483.5000  6632419.0  354.415009         1.0            0.0            0.0
# =================================================================
# LDA SEPARABILITY SCORE
# =================================================================
#   Rate    LDA acc = 87.2%  (50%=random, 100%=perfectly separable)
#   Depth   LDA acc = 75.4%  (50%=random, 100%=perfectly separable)
#   Recoil  LDA acc = 55.5%  (50%=random, 100%=perfectly separable)
#
# ✓ Feature EDA complete

# %% [markdown]
# ## STAGE 5 — Label Encoding + Class Imbalance

# %%
le_rate   = LabelEncoder().fit(rate_list)
le_depth  = LabelEncoder().fit(depth_list)
le_recoil = LabelEncoder().fit(recoil_list)

y_rate   = le_rate.transform(rate_list)
y_depth  = le_depth.transform(depth_list)
y_recoil = le_recoil.transform(recoil_list)

N_RATE   = len(le_rate.classes_)
N_DEPTH  = len(le_depth.classes_)
N_RECOIL = len(le_recoil.classes_)

print('Rate   classes:', le_rate.classes_,   f'→ {N_RATE}')
print('Depth  classes:', le_depth.classes_,  f'→ {N_DEPTH}')
print('Recoil classes:', le_recoil.classes_, f'→ {N_RECOIL}')

# ── Distribution plot ─────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for ax, lbls, title, enc in zip(
        axes,
        [rate_list, depth_list, recoil_list],
        ['Rate', 'Depth', 'Recoil'],
        [le_rate, le_depth, le_recoil]):
    cnt = Counter(lbls)
    ax.bar(cnt.keys(), cnt.values(), color='steelblue', edgecolor='white')
    ax.set_title(f'{title} Distribution', fontweight='bold')
    ax.set_ylabel('Count')
    ax.tick_params(axis='x', rotation=15)
    for k, v in cnt.items():
        ax.text(k, v + 2, str(v), ha='center', fontsize=9)
plt.tight_layout()
plt.savefig(str(CHECKPOINT_DIR / 'class_distributions.png'), dpi=150,
            bbox_inches='tight')
plt.show()

# NOTE: Class weights are computed AFTER the train/val/test split in Stage 6
# so they reflect only training data distribution (not the full dataset).
print('\n✓ Stage 5 complete')
# Out:
# Rate   classes: ['Correct' 'Too_Fast' 'Too_Slow'] → 3
# Depth  classes: ['Correct' 'Too_Deep' 'Too_Shallow'] → 3
# Recoil classes: ['Complete' 'Incomplete'] → 2
# ✓ Stage 5 complete

# %% [markdown]
# > **⚠ Compute/time note:** sliding-window extraction (stride=30) produces roughly 8-12x more training windows than the old one-window-per-video approach (~2,352 videos → an estimated ~20,000-25,000 windows, exact count printed by Stage 4 below). Epoch counts and hyperparameters in Stage 8 are unchanged, so each epoch will take proportionally longer (more steps per epoch, same number of epochs) — expect the full 7-model training sweep to take meaningfully longer wall-clock time than previous runs. Stage 8's resume-state mechanism (`load_resume_state`) already saves progress per-model, so an interrupted Colab session can resume without restarting the whole sweep. If Colab compute limits become a problem, the stride can be safely increased (e.g. 30→45 or →60) to reduce window count at the cost of less data augmentation — but do not reduce below SEQ_LEN (60), or windows would overlap by more than they're offset, which adds redundancy rather than new signal.

# %% [markdown]
# ## STAGE 6 — Train / Val / Test Split (70 / 15 / 15)

# %%
# FIX: Stage 4 now produces MULTIPLE consecutive-frame windows per source
# video (sliding window, replacing the old single-resampled-window-per-
# video approach). That means many rows in X share the same underlying
# physical video via `video_keys`. A plain train_test_split here would
# split by WINDOW, letting windows from the same video land in both train
# and test -- the model would partly memorize that specific video rather
# than generalizing, inflating test metrics. We must split by VIDEO
# (group), so every window from a given video goes entirely into one
# split. GroupShuffleSplit guarantees no group (video) straddles a split.
from sklearn.model_selection import GroupShuffleSplit

_gss1 = GroupShuffleSplit(n_splits=1, test_size=0.30, random_state=42)
_train_idx, _tmp_idx = next(_gss1.split(X, y_rate, groups=video_keys))

X_train, y_rate_tmp_holder = X[_train_idx], None  # placeholder to keep naming consistent below
X_tmp = X[_tmp_idx]
yr_tr,  yr_tmp  = y_rate[_train_idx],   y_rate[_tmp_idx]
yd_tr,  yd_tmp  = y_depth[_train_idx],  y_depth[_tmp_idx]
yrc_tr, yrc_tmp = y_recoil[_train_idx], y_recoil[_tmp_idx]
groups_tmp = video_keys[_tmp_idx]

_gss2 = GroupShuffleSplit(n_splits=1, test_size=0.50, random_state=42)
_val_idx, _test_idx = next(_gss2.split(X_tmp, yr_tmp, groups=groups_tmp))

X_val,  X_test  = X_tmp[_val_idx],  X_tmp[_test_idx]
yr_val, yr_test   = yr_tmp[_val_idx],  yr_tmp[_test_idx]
yd_val, yd_test   = yd_tmp[_val_idx],  yd_tmp[_test_idx]
yrc_val, yrc_test = yrc_tmp[_val_idx], yrc_tmp[_test_idx]

# Sanity check: confirm zero video overlap between splits (this MUST print
# 0/0/0 -- if it doesn't, the group split has a bug and results downstream
# are not trustworthy).
_train_videos = set(video_keys[_train_idx])
_val_videos   = set(groups_tmp[_val_idx])
_test_videos  = set(groups_tmp[_test_idx])
print(f'Train : {X_train.shape}  ({len(_train_videos)} unique videos)')
print(f'Val   : {X_val.shape}  ({len(_val_videos)} unique videos)')
print(f'Test  : {X_test.shape}  ({len(_test_videos)} unique videos)')
print(f'Video overlap train∩val={len(_train_videos & _val_videos)}  '
      f'train∩test={len(_train_videos & _test_videos)}  '
      f'val∩test={len(_val_videos & _test_videos)}  (must all be 0)')
assert len(_train_videos & _val_videos) == 0
assert len(_train_videos & _test_videos) == 0
assert len(_val_videos & _test_videos) == 0
print('✓ No video leakage across train/val/test splits')

# FIX: extract_features() (Stage 4) used to z-score each 60-frame sequence
# against ITS OWN mean/std before this split ever happened. That destroyed
# all absolute-magnitude signal (every sequence forced to mean=0, std=1
# independently of its class) and is why the Stage 4.5 EDA's per-class
# means and Cohen's d looked uniformly near-zero/weak across the board --
# an artifact of the normalization, not evidence the raw signal is weak.
#
# extract_features() now returns RAW (unnormalized) features. We fit a
# single StandardScaler here on X_TRAIN ONLY (no leakage from val/test),
# then apply that same fitted scaler to train/val/test. This preserves
# class-discriminating differences in absolute magnitude (e.g. a faster
# compression really does have a different mean wrist_vel than a correct
# one) while still giving the network well-scaled inputs.
#
# Must run BEFORE oversampling below, so the scaler is fit on genuine
# samples only, not duplicated minority-class copies.
from sklearn.preprocessing import StandardScaler as _GlobalScaler

_N0, _T, _F = X_train.shape
_global_scaler = _GlobalScaler()
_global_scaler.fit(X_train.reshape(-1, _F))  # fit on TRAIN frames only

def _apply_global_scaler(arr):
    n, t, f = arr.shape
    return _global_scaler.transform(arr.reshape(-1, f)).reshape(n, t, f).astype(np.float32)

X_train = _apply_global_scaler(X_train)
X_val   = _apply_global_scaler(X_val)
X_test  = _apply_global_scaler(X_test)

print('\n✓ Global StandardScaler fit on X_train only, applied to train/val/test')
print(f'  X_train mean≈{X_train.mean():.4f}  std≈{X_train.std():.4f}  (now globally scaled, not per-sequence)')

def cw_from(y):
    w = compute_class_weight('balanced', classes=np.unique(y), y=y)
    return dict(enumerate(w))

cw_rate, cw_depth, cw_recoil = cw_from(yr_tr), cw_from(yd_tr), cw_from(yrc_tr)
print('\nClass weights (train only):')
for lbl, cw, enc, yt in [('rate',cw_rate,le_rate,yr_tr),
                           ('depth',cw_depth,le_depth,yd_tr),
                           ('recoil',cw_recoil,le_recoil,yrc_tr)]:
    for k, v in cw.items():
        tag = 'majority ✓' if v < 1.0 else 'minority ✓'
        print(f'  {lbl} {enc.classes_[k]:12s}: w={v:.3f}  n={int((yt==k).sum())}  ({tag})')

try:
    from imblearn.over_sampling import RandomOverSampler
    N0,T,F = X_train.shape
    comb   = np.array([f'{r}_{d}_{rc}' for r,d,rc in zip(yr_tr,yd_tr,yrc_tr)])
    X_res, c_res = RandomOverSampler(random_state=42).fit_resample(
                       X_train.reshape(N0,T*F), comb)
    X_train = X_res.reshape(-1,T,F)
    # FIX: Convert string-encoded integers back to integers directly
    yr_tr  = np.array([int(s.split('_')[0]) for s in c_res])
    yd_tr  = np.array([int(s.split('_')[1]) for s in c_res])
    yrc_tr = np.array([int(s.split('_')[2]) for s in c_res])
    print(f'\nAfter oversampling — train: {len(X_train)}')
    for lbl,yt,enc in [('rate',yr_tr,le_rate),('depth',yd_tr,le_depth),
                        ('recoil',yrc_tr,le_recoil)]:
        u,c = np.unique(yt, return_counts=True)
        print(f'  {lbl}: { {enc.classes_[i]:int(n) for i,n in zip(u,c)} }')
    cw_rate, cw_depth, cw_recoil = cw_from(yr_tr), cw_from(yd_tr), cw_from(yrc_tr)
except ImportError:
    print('⚠ pip install imbalanced-learn')

to_oh = lambda y,n: tf.keras.utils.to_categorical(y,n)
yr_tr_oh  = to_oh(yr_tr, N_RATE);   yr_val_oh  = to_oh(yr_val, N_RATE)
yd_tr_oh  = to_oh(yd_tr, N_DEPTH);  yd_val_oh  = to_oh(yd_val, N_DEPTH)
yrc_tr_oh = to_oh(yrc_tr,N_RECOIL); yrc_val_oh = to_oh(yrc_val,N_RECOIL)
yr_test_oh  = to_oh(yr_test, N_RATE)
yd_test_oh  = to_oh(yd_test, N_DEPTH)
yrc_test_oh = to_oh(yrc_test,N_RECOIL)

sw = (np.array([cw_rate[y]   for y in yr_tr]) +
      np.array([cw_depth[y]  for y in yd_tr]) +
      np.array([cw_recoil[y] for y in yrc_tr])) / 3.0
print(f'\nsw: min={sw.min():.3f}  max={sw.max():.3f}  mean={sw.mean():.3f}')
print('\n✓ Stage 6 complete')
# Out:
# Train : (19812, 60, 12)  (1646 unique videos)
# Val   : (4142, 60, 12)  (353 unique videos)
# Test  : (4122, 60, 12)  (353 unique videos)
# Video overlap train∩val=0  train∩test=0  val∩test=0  (must all be 0)
# ✓ No video leakage across train/val/test splits
#
# ✓ Global StandardScaler fit on X_train only, applied to train/val/test
#   X_train mean≈-0.0000  std≈0.8660  (now globally scaled, not per-sequence)
#
# Class weights (train only):
#   rate Correct     : w=0.382  n=17300  (majority ✓)
#   rate Too_Fast    : w=5.200  n=1270  (minority ✓)
#   rate Too_Slow    : w=5.317  n=1242  (minority ✓)
#   depth Correct     : w=0.448  n=14734  (majority ✓)
#   depth Too_Deep    : w=4.874  n=1355  (minority ✓)
#   depth Too_Shallow : w=1.774  n=3723  (minority ✓)
#   recoil Complete    : w=1.126  n=8795  (minority ✓)
#   recoil Incomplete  : w=0.899  n=11017  (majority ✓)
#
# After oversampling — train: 58482
#   rate: {np.str_('Correct'): 38988, np.str_('Too_Fast'): 9747, np.str_('Too_Slow'): 9747}
#   depth: {np.str_('Correct'): 38988, np.str_('Too_Deep'): 9747, np.str_('Too_Shallow'): 9747}
#   recoil: {np.str_('Complete'): 38988, np.str_('Incomplete'): 19494}
#
# sw: min=0.583  max=1.333  mean=1.000
#
# ✓ Stage 6 complete

# %% [markdown]
# ## STAGE 7 — Seven TensorFlow Model Definitions

# %%
def output_heads(x, dropout=0.3):
    x = layers.Dropout(dropout)(x)
    r  = layers.Dense(N_RATE,   activation='softmax', name='rate'  )(x)
    d  = layers.Dense(N_DEPTH,  activation='softmax', name='depth' )(x)
    rc = layers.Dense(N_RECOIL, activation='softmax', name='recoil')(x)
    return {'rate': r, 'depth': d, 'recoil': rc}

# 1. BiLSTM — unchanged
def build_bilstm(dropout=0.3, units=64):
    i = layers.Input((SEQ_LEN, N_FEATS))
    x = layers.Bidirectional(layers.LSTM(units, return_sequences=True, dropout=dropout))(i)
    x = layers.Bidirectional(layers.LSTM(units//2, dropout=dropout))(x)
    x = layers.Dense(64, activation='relu')(x)
    return keras.Model(inputs=i, outputs=output_heads(x, dropout), name='BiLSTM')

# 2. CNN-LSTM — unchanged
def build_cnn_lstm(dropout=0.3, filters=64, units=64):
    i = layers.Input((SEQ_LEN, N_FEATS))
    x = layers.Conv1D(filters, 3, activation='relu', padding='same')(i)
    x = layers.Conv1D(filters, 3, activation='relu', padding='same')(x)
    x = layers.MaxPooling1D(2)(x)
    x = layers.LSTM(units, dropout=dropout)(x)
    x = layers.Dense(64, activation='relu')(x)
    return keras.Model(inputs=i, outputs=output_heads(x, dropout), name='CNN_LSTM')

# 3. GRU — 3-layer stack for more capacity
#    Previously single-layer; stuck at ~44% recoil and 0.00 F1 on Too_Shallow
def build_gru(dropout=0.4, units=128):
    i = layers.Input((SEQ_LEN, N_FEATS))
    x = layers.GRU(units,     return_sequences=True, dropout=dropout)(i)
    x = layers.GRU(units//2,  return_sequences=True, dropout=dropout)(x)
    x = layers.GRU(units//4,  dropout=dropout)(x)
    x = layers.Dense(64, activation='relu')(x)
    return keras.Model(inputs=i, outputs=output_heads(x, dropout), name='GRU')

# 4. TCN — SpatialDropout1D inside each block to curb overfitting
#    Previously reached 99% train acc by epoch 3, val loss diverged to 1.38
def _tcn_block(x, filters, kernel, dilation, spatial_dropout=0.2):
    skip = x
    x = layers.Conv1D(filters, kernel, padding='causal', dilation_rate=dilation, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.SpatialDropout1D(spatial_dropout)(x)
    x = layers.Conv1D(filters, kernel, padding='causal', dilation_rate=dilation, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.SpatialDropout1D(spatial_dropout)(x)
    if skip.shape[-1] != filters:
        skip = layers.Conv1D(filters, 1)(skip)
    return layers.Add()([x, skip])

def build_tcn(dropout=0.4, filters=64):
    i = layers.Input((SEQ_LEN, N_FEATS))
    x = i
    for d in [1, 2, 4, 8]:
        x = _tcn_block(x, filters, 3, d, spatial_dropout=0.2)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    return keras.Model(inputs=i, outputs=output_heads(x, dropout), name='TCN')

# 5. Conv1D — SpatialDropout1D after each conv + dropout raised 0.2 -> 0.35
#    Previously val loss diverged to 1.42 by epoch 12
def build_1dcnn(dropout=0.35, filters=64):
    i = layers.Input((SEQ_LEN, N_FEATS))
    x = layers.Conv1D(filters,     3, activation='relu', padding='same')(i)
    x = layers.SpatialDropout1D(0.2)(x)
    x = layers.Conv1D(filters * 2, 3, activation='relu', padding='same')(x)
    x = layers.SpatialDropout1D(0.2)(x)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(filters * 2, 3, activation='relu', padding='same')(x)
    x = layers.SpatialDropout1D(0.2)(x)
    x = layers.GlobalMaxPooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    return keras.Model(inputs=i, outputs=output_heads(x, dropout), name='Conv1D')

# 6. ST-Transformer — architecture unchanged, LR schedule changed in CONFIGS
def _transformer_block(x, n_heads, ff_dim, dropout):
    kd = max(1, x.shape[-1] // n_heads)
    attn = layers.MultiHeadAttention(num_heads=n_heads, key_dim=kd)(x, x)
    attn = layers.Dropout(dropout)(attn)
    x = layers.LayerNormalization()(x + attn)
    ff = layers.Dense(ff_dim, activation='relu')(x)
    ff = layers.Dense(x.shape[-1])(ff)
    ff = layers.Dropout(dropout)(ff)
    return layers.LayerNormalization()(x + ff)

def build_transformer(dropout=0.3, n_heads=4, ff_dim=128, n_layers=2):
    i = layers.Input((SEQ_LEN, N_FEATS))
    x = layers.Dense(64)(i)
    for _ in range(n_layers):
        x = _transformer_block(x, n_heads, ff_dim, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    return keras.Model(inputs=i, outputs=output_heads(x, dropout), name='ST_Transformer')

# 7. CNN-BiLSTM — unchanged, best overall model
def build_cnn_bilstm(dropout=0.3, filters=64, units=64):
    i = layers.Input((SEQ_LEN, N_FEATS))
    x = layers.Conv1D(filters,     3, activation='relu', padding='same')(i)
    x = layers.Conv1D(filters * 2, 3, activation='relu', padding='same')(x)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Bidirectional(layers.LSTM(units,    return_sequences=True, dropout=dropout))(x)
    x = layers.Bidirectional(layers.LSTM(units//2, dropout=dropout))(x)
    x = layers.Dense(64, activation='relu')(x)
    return keras.Model(inputs=i, outputs=output_heads(x, dropout), name='CNN_BiLSTM')

print('✓ Model definitions updated: GRU 3-layer, TCN/Conv1D SpatialDropout, dropout tuned')
# Out:
# ✓ Model definitions updated: GRU 3-layer, TCN/Conv1D SpatialDropout, dropout tuned

# %% [markdown]
# ## STAGE 8 — Hyperparameter Grid + Resumable Training Loop

# %%
import tensorflow as tf
from tensorflow.keras import losses

class FocalCrossEntropy(losses.Loss):
    """Categorical focal cross-entropy for multi-class imbalanced tasks."""
    def __init__(self, gamma=2.0, label_smoothing=0.05, **kwargs):
        super().__init__(**kwargs)
        self.gamma = gamma
        self.label_smoothing = label_smoothing

    def call(self, y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0)
        if self.label_smoothing > 0:
            n_classes = tf.cast(tf.shape(y_true)[-1], tf.float32)
            y_true = y_true * (1 - self.label_smoothing) + self.label_smoothing / n_classes
        ce = -tf.reduce_sum(y_true * tf.math.log(y_pred), axis=-1)
        p_t = tf.reduce_sum(y_true * y_pred, axis=-1)
        focal_weight = tf.pow(1.0 - p_t, self.gamma)
        return focal_weight * ce

    def get_config(self):
        cfg = super().get_config()
        cfg.update({'gamma': self.gamma, 'label_smoothing': self.label_smoothing})
        return cfg

# Changes from previous run:
#   GRU:            epochs 20->30, lr 1e-3->5e-4, batch 64->32
#                   (deeper 3-layer stack needs more time; smaller batch
#                    gives more gradient updates per epoch for minority classes)
#   TCN:            dropout 0.3->0.4, epochs 20->25
#                   (val loss was diverging to 1.38 from epoch 3)
#   Conv1D:         dropout 0.2->0.35, epochs 20->25
#                   (val loss was diverging to 1.42 from epoch 3)
#   ST_Transformer: lr 2e-4->5e-4, epochs 25->35, cosine_lr=True
#                   (ReduceLROnPlateau cut LR to 5e-5 by epoch 13, stalling training)
#   BiLSTM, CNN_LSTM, CNN_BiLSTM: unchanged — well-behaved in previous run

CONFIGS = [
    dict(name='BiLSTM',         build=build_bilstm,      epochs=25, lr=1e-3,
         batch=32,  opt='adam',  dropout=0.3,
         lw=dict(rate=1.0, depth=2.0, recoil=2.0)),

    dict(name='CNN_LSTM',       build=build_cnn_lstm,    epochs=25, lr=5e-4,
         batch=32,  opt='adam',  dropout=0.3,
         lw=dict(rate=1.0, depth=2.0, recoil=2.0)),

    dict(name='GRU',            build=build_gru,         epochs=30, lr=5e-4,
         batch=32,  opt='adam',  dropout=0.4,
         lw=dict(rate=1.0, depth=2.0, recoil=2.0)),

    dict(name='TCN',            build=build_tcn,         epochs=25, lr=5e-4,
         batch=32,  opt='adamw', dropout=0.4,
         lw=dict(rate=1.0, depth=2.0, recoil=2.0)),

    dict(name='Conv1D',         build=build_1dcnn,       epochs=25, lr=1e-3,
         batch=32,  opt='adam',  dropout=0.35,
         lw=dict(rate=1.0, depth=2.0, recoil=2.0)),

    dict(name='ST_Transformer', build=build_transformer, epochs=35, lr=5e-4,
         batch=32,  opt='adamw', dropout=0.3,
         cosine_lr=True,
         lw=dict(rate=1.0, depth=2.0, recoil=2.0)),

    dict(name='CNN_BiLSTM',     build=build_cnn_bilstm,  epochs=25, lr=5e-4,
         batch=32,  opt='adam',  dropout=0.3,
         lw=dict(rate=1.0, depth=2.0, recoil=2.0)),
]

print(f'Scheduled experiments: {len(CONFIGS)}')
print('FocalCrossEntropy + updated configs: GRU stacked, TCN/Conv1D SpatialDropout, ST_Transformer cosine LR')
# Out:
# Scheduled experiments: 7
# FocalCrossEntropy + updated configs: GRU stacked, TCN/Conv1D SpatialDropout, ST_Transformer cosine LR

# %%
def load_resume_state():
    if RESUME_FILE.exists():
        with open(RESUME_FILE, 'r') as f:
            return json.load(f)
    return {'completed': [], 'metrics': {}}

def save_resume_state(state):
    with open(RESUME_FILE, 'w') as f:
        json.dump(state, f, indent=4)

def compile_model(model, cfg):
    lr = cfg['lr']
    opt_name = cfg['opt'].lower()
    if opt_name == 'adamw':
        opt = optimizers.AdamW(learning_rate=lr, weight_decay=1e-4)
    else:
        opt = optimizers.Adam(learning_rate=lr)

    focal = FocalCrossEntropy(gamma=2.0, label_smoothing=0.05)

    model.compile(
        optimizer=opt,
        loss={'rate': focal, 'depth': focal, 'recoil': focal},
        loss_weights=cfg['lw'],
        metrics={
            'rate':   [metrics.CategoricalAccuracy(name='acc_rate')],
            'depth':  [metrics.CategoricalAccuracy(name='acc_depth')],
            'recoil': [metrics.CategoricalAccuracy(name='acc_recoil')],
        }
    )
    return model

def make_callbacks(cfg):
    # CHANGED: accepts full cfg dict instead of just model name string.
    # ST_Transformer gets CosineDecayRestarts — fixes the LR-stall problem
    # where ReduceLROnPlateau had already cut LR to 5e-5 by epoch 13.
    # All other models keep ReduceLROnPlateau with patience raised 3->4.
    name = cfg['name']
    cb = [
        callbacks.EarlyStopping(monitor='val_loss', patience=8,
                                restore_best_weights=True),
        callbacks.ModelCheckpoint(
            str(CHECKPOINT_DIR / f'{name}_best.keras'),
            monitor='val_loss', save_best_only=True),
        callbacks.CSVLogger(
            str(CHECKPOINT_DIR / f'{name}_log.csv'), append=True),
    ]

    if cfg.get('cosine_lr', False):
        # Warm restarts every 10 epochs, decays from lr down to lr/10
        # then restarts at 90% of previous peak — suits transformer training
        steps_per_epoch = max(1, len(X_train) // cfg['batch'])
        cosine_schedule = tf.keras.optimizers.schedules.CosineDecayRestarts(
            initial_learning_rate=cfg['lr'],
            first_decay_steps=10 * steps_per_epoch,
            t_mul=1.0,
            m_mul=0.9,
            alpha=cfg['lr'] / 10
        )
        def lr_scheduler(epoch, lr):
            step = epoch * steps_per_epoch
            return float(cosine_schedule(step))
        cb.append(callbacks.LearningRateScheduler(lr_scheduler, verbose=1))
    else:
        # patience raised 3->4 to give GRU/TCN more room before LR is cut
        cb.append(callbacks.ReduceLROnPlateau(
            monitor='val_loss', factor=0.5, patience=4,
            min_lr=1e-6, verbose=1))

    return cb

print('✓ make_callbacks updated: cosine LR for ST_Transformer, ReduceLROnPlateau patience=4')
# Out:
# ✓ make_callbacks updated: cosine LR for ST_Transformer, ReduceLROnPlateau patience=4

# %%
# Reset resume state to retrain with all fixes applied
resume = {'completed': [], 'metrics': {}}
save_resume_state(resume)

histories  = {}
all_models = {}

train_targets = {'rate': yr_tr_oh, 'depth': yd_tr_oh, 'recoil': yrc_tr_oh}
val_targets   = {'rate': yr_val_oh, 'depth': yd_val_oh, 'recoil': yrc_val_oh}

# ── FIX: sample_weight must be a 1-D numpy array for multi-output Keras models.
#    Passing a dict silently fails / gets ignored depending on Keras version,
#    causing all class-weighting to be dropped during training.
sample_weight_1d = sw   # already a 1-D array from Stage 6

for cfg in CONFIGS:
    name = cfg['name']
    print(f'\n[STARTING] {name} | lw={cfg["lw"]} | lr={cfg["lr"]}')

    tf.keras.backend.clear_session()
    model = cfg['build'](dropout=cfg['dropout'])
    model = compile_model(model, cfg)

    try:
        hist = model.fit(
            X_train, train_targets,
            validation_data=(X_val, val_targets),
            # FIX: single 1-D array, not a dict
            sample_weight=sample_weight_1d,
            epochs=cfg['epochs'],
            batch_size=cfg['batch'],
            callbacks=make_callbacks(cfg),
            verbose=1
        )
        histories[name] = hist.history
        all_models[name] = model
        resume['completed'].append(name)
        save_resume_state(resume)
        print(f'✓ {name} complete')
    except KeyboardInterrupt:
        print('Interrupted by user — stopping.')
        break
    except Exception as e:
        # FIX: continue instead of break so one failure doesn't kill the sweep
        print(f'✗ {name} failed: {e}')
        import traceback; traceback.print_exc()
        continue
# Out:
# [STARTING] BiLSTM | lw={'rate': 1.0, 'depth': 2.0, 'recoil': 2.0} | lr=0.001
# Epoch 1/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 71s 36ms/step - depth_acc_depth: 0.7238 - depth_loss: 0.3032 - loss: 1.2092 - rate_acc_rate: 0.6488 - rate_loss: 0.3280 - recoil_acc_recoil: 0.7454 - recoil_loss: 0.1374 - val_depth_acc_depth: 0.8947 - val_depth_loss: 0.1306 - val_loss: 0.7087 - val_rate_acc_rate: 0.7115 - val_rate_loss: 0.2117 - val_recoil_acc_recoil: 0.7817 - val_recoil_loss: 0.1232 - learning_rate: 0.0010
# Epoch 2/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 63s 25ms/step - depth_acc_depth: 0.8563 - depth_loss: 0.1601 - loss: 0.7862 - rate_acc_rate: 0.6896 - rate_loss: 0.2504 - recoil_acc_recoil: 0.8072 - recoil_loss: 0.1078 - val_depth_acc_depth: 0.8984 - val_depth_loss: 0.1135 - val_loss: 0.7140 - val_rate_acc_rate: 0.6197 - val_rate_loss: 0.2479 - val_recoil_acc_recoil: 0.7793 - val_recoil_loss: 0.1264 - learning_rate: 0.0010
# Epoch 3/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 45s 25ms/step - depth_acc_depth: 0.8865 - depth_loss: 0.1203 - loss: 0.6492 - rate_acc_rate: 0.7203 - rate_loss: 0.2177 - recoil_acc_recoil: 0.8247 - recoil_loss: 0.0955 - val_depth_acc_depth: 0.9155 - val_depth_loss: 0.1055 - val_loss: 0.7310 - val_rate_acc_rate: 0.6427 - val_rate_loss: 0.2740 - val_recoil_acc_recoil: 0.7933 - val_recoil_loss: 0.1300 - learning_rate: 0.0010
# Epoch 4/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 83s 26ms/step - depth_acc_depth: 0.9016 - depth_loss: 0.1017 - loss: 0.5826 - rate_acc_rate: 0.7448 - rate_loss: 0.2003 - recoil_acc_recoil: 0.8368 - recoil_loss: 0.0895 - val_depth_acc_depth: 0.9237 - val_depth_loss: 0.0960 - val_loss: 0.7248 - val_rate_acc_rate: 0.6217 - val_rate_loss: 0.2754 - val_recoil_acc_recoil: 0.7834 - val_recoil_loss: 0.1362 - learning_rate: 0.0010
# Epoch 5/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 49s 27ms/step - depth_acc_depth: 0.9131 - depth_loss: 0.0909 - loss: 0.5363 - rate_acc_rate: 0.7642 - rate_loss: 0.1864 - recoil_acc_recoil: 0.8445 - recoil_loss: 0.0841 - val_depth_acc_depth: 0.9382 - val_depth_loss: 0.0949 - val_loss: 0.6827 - val_rate_acc_rate: 0.6765 - val_rate_loss: 0.2580 - val_recoil_acc_recoil: 0.8001 - val_recoil_loss: 0.1260 - learning_rate: 0.0010
# Epoch 6/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9203 - depth_loss: 0.0825 - loss: 0.4995 - rate_acc_rate: 0.7781 - rate_loss: 0.1756 - recoil_acc_recoil: 0.8536 - recoil_loss: 0.0794 - val_depth_acc_depth: 0.9203 - val_depth_loss: 0.0964 - val_loss: 0.6792 - val_rate_acc_rate: 0.6883 - val_rate_loss: 0.2378 - val_recoil_acc_recoil: 0.7904 - val_recoil_loss: 0.1319 - learning_rate: 0.0010
# Epoch 7/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 45s 25ms/step - depth_acc_depth: 0.9263 - depth_loss: 0.0772 - loss: 0.4768 - rate_acc_rate: 0.7889 - rate_loss: 0.1686 - recoil_acc_recoil: 0.8584 - recoil_loss: 0.0769 - val_depth_acc_depth: 0.9399 - val_depth_loss: 0.0723 - val_loss: 0.5943 - val_rate_acc_rate: 0.7009 - val_rate_loss: 0.2295 - val_recoil_acc_recoil: 0.8006 - val_recoil_loss: 0.1177 - learning_rate: 0.0010
# Epoch 8/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9326 - depth_loss: 0.0714 - loss: 0.4482 - rate_acc_rate: 0.8034 - rate_loss: 0.1580 - recoil_acc_recoil: 0.8645 - recoil_loss: 0.0736 - val_depth_acc_depth: 0.9437 - val_depth_loss: 0.0790 - val_loss: 0.6573 - val_rate_acc_rate: 0.7286 - val_rate_loss: 0.2553 - val_recoil_acc_recoil: 0.7967 - val_recoil_loss: 0.1339 - learning_rate: 0.0010
# Epoch 9/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 45s 24ms/step - depth_acc_depth: 0.9355 - depth_loss: 0.0668 - loss: 0.4277 - rate_acc_rate: 0.8119 - rate_loss: 0.1520 - recoil_acc_recoil: 0.8672 - recoil_loss: 0.0710 - val_depth_acc_depth: 0.9396 - val_depth_loss: 0.1002 - val_loss: 0.7682 - val_rate_acc_rate: 0.7202 - val_rate_loss: 0.2837 - val_recoil_acc_recoil: 0.8042 - val_recoil_loss: 0.1536 - learning_rate: 0.0010
# Epoch 10/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9396 - depth_loss: 0.0627 - loss: 0.4061 - rate_acc_rate: 0.8241 - rate_loss: 0.1443 - recoil_acc_recoil: 0.8752 - recoil_loss: 0.0682 - val_depth_acc_depth: 0.9358 - val_depth_loss: 0.0939 - val_loss: 0.6910 - val_rate_acc_rate: 0.7183 - val_rate_loss: 0.2494 - val_recoil_acc_recoil: 0.7996 - val_recoil_loss: 0.1370 - learning_rate: 0.0010
# Epoch 11/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - depth_acc_depth: 0.9394 - depth_loss: 0.0616 - loss: 0.3973 - rate_acc_rate: 0.8254 - rate_loss: 0.1417 - recoil_acc_recoil: 0.8781 - recoil_loss: 0.0662
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 81s 25ms/step - depth_acc_depth: 0.9405 - depth_loss: 0.0617 - loss: 0.3967 - rate_acc_rate: 0.8281 - rate_loss: 0.1408 - recoil_acc_recoil: 0.8799 - recoil_loss: 0.0662 - val_depth_acc_depth: 0.9387 - val_depth_loss: 0.0824 - val_loss: 0.6421 - val_rate_acc_rate: 0.7424 - val_rate_loss: 0.2347 - val_recoil_acc_recoil: 0.8025 - val_recoil_loss: 0.1328 - learning_rate: 0.0010
# Epoch 12/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 48s 26ms/step - depth_acc_depth: 0.9483 - depth_loss: 0.0537 - loss: 0.3568 - rate_acc_rate: 0.8443 - rate_loss: 0.1273 - recoil_acc_recoil: 0.8884 - recoil_loss: 0.0610 - val_depth_acc_depth: 0.9454 - val_depth_loss: 0.0750 - val_loss: 0.6275 - val_rate_acc_rate: 0.7595 - val_rate_loss: 0.2411 - val_recoil_acc_recoil: 0.8143 - val_recoil_loss: 0.1311 - learning_rate: 5.0000e-04
# Epoch 13/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9509 - depth_loss: 0.0499 - loss: 0.3375 - rate_acc_rate: 0.8518 - rate_loss: 0.1208 - recoil_acc_recoil: 0.8918 - recoil_loss: 0.0585 - val_depth_acc_depth: 0.9367 - val_depth_loss: 0.0963 - val_loss: 0.7566 - val_rate_acc_rate: 0.7535 - val_rate_loss: 0.2741 - val_recoil_acc_recoil: 0.8001 - val_recoil_loss: 0.1582 - learning_rate: 5.0000e-04
# Epoch 14/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9518 - depth_loss: 0.0486 - loss: 0.3283 - rate_acc_rate: 0.8576 - rate_loss: 0.1171 - recoil_acc_recoil: 0.8961 - recoil_loss: 0.0571 - val_depth_acc_depth: 0.9348 - val_depth_loss: 0.1032 - val_loss: 0.7762 - val_rate_acc_rate: 0.7622 - val_rate_loss: 0.2721 - val_recoil_acc_recoil: 0.8158 - val_recoil_loss: 0.1646 - learning_rate: 5.0000e-04
# Epoch 15/25
# 1827/1828 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - depth_acc_depth: 0.9534 - depth_loss: 0.0461 - loss: 0.3208 - rate_acc_rate: 0.8589 - rate_loss: 0.1163 - recoil_acc_recoil: 0.8974 - recoil_loss: 0.0562
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 47s 26ms/step - depth_acc_depth: 0.9541 - depth_loss: 0.0462 - loss: 0.3172 - rate_acc_rate: 0.8608 - rate_loss: 0.1139 - recoil_acc_recoil: 0.8988 - recoil_loss: 0.0555 - val_depth_acc_depth: 0.9408 - val_depth_loss: 0.1038 - val_loss: 0.8342 - val_rate_acc_rate: 0.7521 - val_rate_loss: 0.2948 - val_recoil_acc_recoil: 0.8083 - val_recoil_loss: 0.1824 - learning_rate: 5.0000e-04
# ✓ BiLSTM complete
#
# [STARTING] CNN_LSTM | lw={'rate': 1.0, 'depth': 2.0, 'recoil': 2.0} | lr=0.0005
# Epoch 1/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 31s 15ms/step - depth_acc_depth: 0.7385 - depth_loss: 0.2477 - loss: 0.9890 - rate_acc_rate: 0.6971 - rate_loss: 0.2560 - recoil_acc_recoil: 0.7898 - recoil_loss: 0.1188 - val_depth_acc_depth: 0.8766 - val_depth_loss: 0.1015 - val_loss: 0.6348 - val_rate_acc_rate: 0.7134 - val_rate_loss: 0.1722 - val_recoil_acc_recoil: 0.7624 - val_recoil_loss: 0.1342 - learning_rate: 5.0000e-04
# Epoch 2/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 40s 15ms/step - depth_acc_depth: 0.8894 - depth_loss: 0.0925 - loss: 0.5270 - rate_acc_rate: 0.7635 - rate_loss: 0.1721 - recoil_acc_recoil: 0.8502 - recoil_loss: 0.0849 - val_depth_acc_depth: 0.9015 - val_depth_loss: 0.0750 - val_loss: 0.5466 - val_rate_acc_rate: 0.7571 - val_rate_loss: 0.1633 - val_recoil_acc_recoil: 0.7769 - val_recoil_loss: 0.1236 - learning_rate: 5.0000e-04
# Epoch 3/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - depth_acc_depth: 0.9221 - depth_loss: 0.0646 - loss: 0.4187 - rate_acc_rate: 0.7950 - rate_loss: 0.1461 - recoil_acc_recoil: 0.8722 - recoil_loss: 0.0717 - val_depth_acc_depth: 0.9285 - val_depth_loss: 0.0602 - val_loss: 0.5122 - val_rate_acc_rate: 0.7636 - val_rate_loss: 0.1658 - val_recoil_acc_recoil: 0.7861 - val_recoil_loss: 0.1204 - learning_rate: 5.0000e-04
# Epoch 4/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - depth_acc_depth: 0.9397 - depth_loss: 0.0509 - loss: 0.3605 - rate_acc_rate: 0.8124 - rate_loss: 0.1319 - recoil_acc_recoil: 0.8851 - recoil_loss: 0.0634 - val_depth_acc_depth: 0.9488 - val_depth_loss: 0.0520 - val_loss: 0.4552 - val_rate_acc_rate: 0.7960 - val_rate_loss: 0.1637 - val_recoil_acc_recoil: 0.8143 - val_recoil_loss: 0.1044 - learning_rate: 5.0000e-04
# Epoch 5/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 27s 15ms/step - depth_acc_depth: 0.9543 - depth_loss: 0.0406 - loss: 0.3115 - rate_acc_rate: 0.8318 - rate_loss: 0.1165 - recoil_acc_recoil: 0.8997 - recoil_loss: 0.0570 - val_depth_acc_depth: 0.9447 - val_depth_loss: 0.0530 - val_loss: 0.4905 - val_rate_acc_rate: 0.7810 - val_rate_loss: 0.1597 - val_recoil_acc_recoil: 0.7948 - val_recoil_loss: 0.1195 - learning_rate: 5.0000e-04
# Epoch 6/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 27s 15ms/step - depth_acc_depth: 0.9627 - depth_loss: 0.0337 - loss: 0.2812 - rate_acc_rate: 0.8443 - rate_loss: 0.1078 - recoil_acc_recoil: 0.9070 - recoil_loss: 0.0530 - val_depth_acc_depth: 0.9546 - val_depth_loss: 0.0581 - val_loss: 0.4729 - val_rate_acc_rate: 0.8143 - val_rate_loss: 0.1528 - val_recoil_acc_recoil: 0.8141 - val_recoil_loss: 0.1146 - learning_rate: 5.0000e-04
# Epoch 7/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 27s 15ms/step - depth_acc_depth: 0.9685 - depth_loss: 0.0296 - loss: 0.2569 - rate_acc_rate: 0.8582 - rate_loss: 0.0996 - recoil_acc_recoil: 0.9138 - recoil_loss: 0.0490 - val_depth_acc_depth: 0.9556 - val_depth_loss: 0.0575 - val_loss: 0.4604 - val_rate_acc_rate: 0.8064 - val_rate_loss: 0.1612 - val_recoil_acc_recoil: 0.8375 - val_recoil_loss: 0.1039 - learning_rate: 5.0000e-04
# Epoch 8/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - depth_acc_depth: 0.9722 - depth_loss: 0.0259 - loss: 0.2371 - rate_acc_rate: 0.8700 - rate_loss: 0.0924 - recoil_acc_recoil: 0.9193 - recoil_loss: 0.0465 - val_depth_acc_depth: 0.9652 - val_depth_loss: 0.0411 - val_loss: 0.4146 - val_rate_acc_rate: 0.8209 - val_rate_loss: 0.1537 - val_recoil_acc_recoil: 0.8404 - val_recoil_loss: 0.0999 - learning_rate: 5.0000e-04
# Epoch 9/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - depth_acc_depth: 0.9765 - depth_loss: 0.0221 - loss: 0.2173 - rate_acc_rate: 0.8768 - rate_loss: 0.0859 - recoil_acc_recoil: 0.9233 - recoil_loss: 0.0436 - val_depth_acc_depth: 0.9582 - val_depth_loss: 0.0500 - val_loss: 0.4789 - val_rate_acc_rate: 0.7921 - val_rate_loss: 0.1662 - val_recoil_acc_recoil: 0.8305 - val_recoil_loss: 0.1181 - learning_rate: 5.0000e-04
# Epoch 10/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - depth_acc_depth: 0.9784 - depth_loss: 0.0209 - loss: 0.2054 - rate_acc_rate: 0.8847 - rate_loss: 0.0805 - recoil_acc_recoil: 0.9274 - recoil_loss: 0.0416 - val_depth_acc_depth: 0.9633 - val_depth_loss: 0.0495 - val_loss: 0.4259 - val_rate_acc_rate: 0.8349 - val_rate_loss: 0.1515 - val_recoil_acc_recoil: 0.8465 - val_recoil_loss: 0.1029 - learning_rate: 5.0000e-04
# Epoch 11/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - depth_acc_depth: 0.9806 - depth_loss: 0.0185 - loss: 0.1909 - rate_acc_rate: 0.8925 - rate_loss: 0.0759 - recoil_acc_recoil: 0.9327 - recoil_loss: 0.0390 - val_depth_acc_depth: 0.9619 - val_depth_loss: 0.0454 - val_loss: 0.4329 - val_rate_acc_rate: 0.8392 - val_rate_loss: 0.1541 - val_recoil_acc_recoil: 0.8428 - val_recoil_loss: 0.1115 - learning_rate: 5.0000e-04
# Epoch 12/25
# 1825/1828 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - depth_acc_depth: 0.9823 - depth_loss: 0.0167 - loss: 0.1791 - rate_acc_rate: 0.8986 - rate_loss: 0.0714 - recoil_acc_recoil: 0.9348 - recoil_loss: 0.0371
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - depth_acc_depth: 0.9822 - depth_loss: 0.0173 - loss: 0.1806 - rate_acc_rate: 0.8996 - rate_loss: 0.0711 - recoil_acc_recoil: 0.9348 - recoil_loss: 0.0374 - val_depth_acc_depth: 0.9650 - val_depth_loss: 0.0514 - val_loss: 0.4459 - val_rate_acc_rate: 0.8486 - val_rate_loss: 0.1605 - val_recoil_acc_recoil: 0.8489 - val_recoil_loss: 0.1088 - learning_rate: 5.0000e-04
# Epoch 13/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - depth_acc_depth: 0.9871 - depth_loss: 0.0123 - loss: 0.1506 - rate_acc_rate: 0.9149 - rate_loss: 0.0612 - recoil_acc_recoil: 0.9436 - recoil_loss: 0.0324 - val_depth_acc_depth: 0.9672 - val_depth_loss: 0.0483 - val_loss: 0.4405 - val_rate_acc_rate: 0.8542 - val_rate_loss: 0.1553 - val_recoil_acc_recoil: 0.8561 - val_recoil_loss: 0.1105 - learning_rate: 2.5000e-04
# Epoch 14/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - depth_acc_depth: 0.9886 - depth_loss: 0.0115 - loss: 0.1452 - rate_acc_rate: 0.9180 - rate_loss: 0.0591 - recoil_acc_recoil: 0.9453 - recoil_loss: 0.0315 - val_depth_acc_depth: 0.9635 - val_depth_loss: 0.0494 - val_loss: 0.4496 - val_rate_acc_rate: 0.8515 - val_rate_loss: 0.1664 - val_recoil_acc_recoil: 0.8554 - val_recoil_loss: 0.1087 - learning_rate: 2.5000e-04
# Epoch 15/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - depth_acc_depth: 0.9885 - depth_loss: 0.0113 - loss: 0.1399 - rate_acc_rate: 0.9230 - rate_loss: 0.0565 - recoil_acc_recoil: 0.9474 - recoil_loss: 0.0304 - val_depth_acc_depth: 0.9701 - val_depth_loss: 0.0485 - val_loss: 0.4319 - val_rate_acc_rate: 0.8566 - val_rate_loss: 0.1575 - val_recoil_acc_recoil: 0.8621 - val_recoil_loss: 0.1076 - learning_rate: 2.5000e-04
# Epoch 16/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - depth_acc_depth: 0.9908 - depth_loss: 0.0095 - loss: 0.1316 - rate_acc_rate: 0.9268 - rate_loss: 0.0543 - recoil_acc_recoil: 0.9501 - recoil_loss: 0.0291 - val_depth_acc_depth: 0.9722 - val_depth_loss: 0.0431 - val_loss: 0.4089 - val_rate_acc_rate: 0.8602 - val_rate_loss: 0.1559 - val_recoil_acc_recoil: 0.8679 - val_recoil_loss: 0.1025 - learning_rate: 2.5000e-04
# Epoch 17/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 41s 16ms/step - depth_acc_depth: 0.9904 - depth_loss: 0.0093 - loss: 0.1282 - rate_acc_rate: 0.9284 - rate_loss: 0.0529 - recoil_acc_recoil: 0.9510 - recoil_loss: 0.0283 - val_depth_acc_depth: 0.9734 - val_depth_loss: 0.0431 - val_loss: 0.4103 - val_rate_acc_rate: 0.8617 - val_rate_loss: 0.1584 - val_recoil_acc_recoil: 0.8732 - val_recoil_loss: 0.1042 - learning_rate: 2.5000e-04
# Epoch 18/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - depth_acc_depth: 0.9908 - depth_loss: 0.0096 - loss: 0.1252 - rate_acc_rate: 0.9317 - rate_loss: 0.0507 - recoil_acc_recoil: 0.9529 - recoil_loss: 0.0276 - val_depth_acc_depth: 0.9722 - val_depth_loss: 0.0466 - val_loss: 0.4353 - val_rate_acc_rate: 0.8602 - val_rate_loss: 0.1653 - val_recoil_acc_recoil: 0.8665 - val_recoil_loss: 0.1116 - learning_rate: 2.5000e-04
# Epoch 19/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - depth_acc_depth: 0.9905 - depth_loss: 0.0094 - loss: 0.1247 - rate_acc_rate: 0.9326 - rate_loss: 0.0509 - recoil_acc_recoil: 0.9535 - recoil_loss: 0.0275 - val_depth_acc_depth: 0.9698 - val_depth_loss: 0.0440 - val_loss: 0.4176 - val_rate_acc_rate: 0.8660 - val_rate_loss: 0.1558 - val_recoil_acc_recoil: 0.8684 - val_recoil_loss: 0.1086 - learning_rate: 2.5000e-04
# Epoch 20/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - depth_acc_depth: 0.9903 - depth_loss: 0.0096 - loss: 0.1197 - rate_acc_rate: 0.9376 - rate_loss: 0.0480 - recoil_acc_recoil: 0.9559 - recoil_loss: 0.0262
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - depth_acc_depth: 0.9904 - depth_loss: 0.0094 - loss: 0.1190 - rate_acc_rate: 0.9375 - rate_loss: 0.0473 - recoil_acc_recoil: 0.9558 - recoil_loss: 0.0265 - val_depth_acc_depth: 0.9715 - val_depth_loss: 0.0476 - val_loss: 0.4121 - val_rate_acc_rate: 0.8655 - val_rate_loss: 0.1516 - val_recoil_acc_recoil: 0.8723 - val_recoil_loss: 0.1010 - learning_rate: 2.5000e-04
# Epoch 21/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - depth_acc_depth: 0.9930 - depth_loss: 0.0068 - loss: 0.1061 - rate_acc_rate: 0.9414 - rate_loss: 0.0438 - recoil_acc_recoil: 0.9593 - recoil_loss: 0.0243 - val_depth_acc_depth: 0.9720 - val_depth_loss: 0.0447 - val_loss: 0.4165 - val_rate_acc_rate: 0.8718 - val_rate_loss: 0.1572 - val_recoil_acc_recoil: 0.8740 - val_recoil_loss: 0.1040 - learning_rate: 1.2500e-04
# Epoch 22/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - depth_acc_depth: 0.9932 - depth_loss: 0.0069 - loss: 0.1043 - rate_acc_rate: 0.9435 - rate_loss: 0.0430 - recoil_acc_recoil: 0.9603 - recoil_loss: 0.0237 - val_depth_acc_depth: 0.9744 - val_depth_loss: 0.0424 - val_loss: 0.4092 - val_rate_acc_rate: 0.8742 - val_rate_loss: 0.1529 - val_recoil_acc_recoil: 0.8732 - val_recoil_loss: 0.1034 - learning_rate: 1.2500e-04
# Epoch 23/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - depth_acc_depth: 0.9934 - depth_loss: 0.0068 - loss: 0.1009 - rate_acc_rate: 0.9449 - rate_loss: 0.0417 - recoil_acc_recoil: 0.9621 - recoil_loss: 0.0228 - val_depth_acc_depth: 0.9722 - val_depth_loss: 0.0479 - val_loss: 0.4268 - val_rate_acc_rate: 0.8783 - val_rate_loss: 0.1574 - val_recoil_acc_recoil: 0.8732 - val_recoil_loss: 0.1069 - learning_rate: 1.2500e-04
# Epoch 24/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - depth_acc_depth: 0.9937 - depth_loss: 0.0075 - loss: 0.1049 - rate_acc_rate: 0.9443 - rate_loss: 0.0425 - recoil_acc_recoil: 0.9606 - recoil_loss: 0.0237
# Epoch 24: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - depth_acc_depth: 0.9939 - depth_loss: 0.0070 - loss: 0.1034 - rate_acc_rate: 0.9454 - rate_loss: 0.0420 - recoil_acc_recoil: 0.9607 - recoil_loss: 0.0237 - val_depth_acc_depth: 0.9744 - val_depth_loss: 0.0480 - val_loss: 0.4294 - val_rate_acc_rate: 0.8788 - val_rate_loss: 0.1623 - val_recoil_acc_recoil: 0.8807 - val_recoil_loss: 0.1079 - learning_rate: 1.2500e-04
# ✓ CNN_LSTM complete
#
# [STARTING] GRU | lw={'rate': 1.0, 'depth': 2.0, 'recoil': 2.0} | lr=0.0005
# Epoch 1/30
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 23ms/step - depth_acc_depth: 0.6638 - depth_loss: 0.3914 - loss: 1.5034 - rate_acc_rate: 0.6601 - rate_loss: 0.3959 - recoil_acc_recoil: 0.6689 - recoil_loss: 0.1624 - val_depth_acc_depth: 0.7525 - val_depth_loss: 0.2912 - val_loss: 1.1655 - val_rate_acc_rate: 0.8725 - val_rate_loss: 0.2583 - val_recoil_acc_recoil: 0.5963 - val_recoil_loss: 0.1634 - learning_rate: 5.0000e-04
# Epoch 2/30
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 39s 21ms/step - depth_acc_depth: 0.7052 - depth_loss: 0.3310 - loss: 1.3095 - rate_acc_rate: 0.6588 - rate_loss: 0.3554 - recoil_acc_recoil: 0.7151 - recoil_loss: 0.1461 - val_depth_acc_depth: 0.8880 - val_depth_loss: 0.1371 - val_loss: 0.7747 - val_rate_acc_rate: 0.7711 - val_rate_loss: 0.2331 - val_recoil_acc_recoil: 0.6697 - val_recoil_loss: 0.1362 - learning_rate: 5.0000e-04
# Epoch 3/30
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 40s 22ms/step - depth_acc_depth: 0.7792 - depth_loss: 0.2346 - loss: 1.0535 - rate_acc_rate: 0.6713 - rate_loss: 0.3196 - recoil_acc_recoil: 0.7384 - recoil_loss: 0.1324 - val_depth_acc_depth: 0.9087 - val_depth_loss: 0.0875 - val_loss: 0.6624 - val_rate_acc_rate: 0.5937 - val_rate_loss: 0.2610 - val_recoil_acc_recoil: 0.7624 - val_recoil_loss: 0.1165 - learning_rate: 5.0000e-04
# Epoch 4/30
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - depth_acc_depth: 0.8057 - depth_loss: 0.2044 - loss: 0.9520 - rate_acc_rate: 0.6839 - rate_loss: 0.2972 - recoil_acc_recoil: 0.7565 - recoil_loss: 0.1230 - val_depth_acc_depth: 0.9099 - val_depth_loss: 0.0916 - val_loss: 0.7261 - val_rate_acc_rate: 0.5196 - val_rate_loss: 0.3010 - val_recoil_acc_recoil: 0.7627 - val_recoil_loss: 0.1242 - learning_rate: 5.0000e-04
# Epoch 5/30
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - depth_acc_depth: 0.8229 - depth_loss: 0.1869 - loss: 0.8998 - rate_acc_rate: 0.6947 - rate_loss: 0.2864 - recoil_acc_recoil: 0.7655 - recoil_loss: 0.1198 - val_depth_acc_depth: 0.9227 - val_depth_loss: 0.0804 - val_loss: 0.6902 - val_rate_acc_rate: 0.5357 - val_rate_loss: 0.2877 - val_recoil_acc_recoil: 0.7764 - val_recoil_loss: 0.1249 - learning_rate: 5.0000e-04
# Epoch 6/30
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - depth_acc_depth: 0.8364 - depth_loss: 0.1726 - loss: 0.8509 - rate_acc_rate: 0.7040 - rate_loss: 0.2764 - recoil_acc_recoil: 0.7750 - recoil_loss: 0.1146 - val_depth_acc_depth: 0.9249 - val_depth_loss: 0.0906 - val_loss: 0.6700 - val_rate_acc_rate: 0.6028 - val_rate_loss: 0.2701 - val_recoil_acc_recoil: 0.7789 - val_recoil_loss: 0.1146 - learning_rate: 5.0000e-04
# Epoch 7/30
# 1826/1828 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - depth_acc_depth: 0.8446 - depth_loss: 0.1673 - loss: 0.8308 - rate_acc_rate: 0.7110 - rate_loss: 0.2706 - recoil_acc_recoil: 0.7764 - recoil_loss: 0.1128
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 41s 23ms/step - depth_acc_depth: 0.8452 - depth_loss: 0.1649 - loss: 0.8221 - rate_acc_rate: 0.7134 - rate_loss: 0.2678 - recoil_acc_recoil: 0.7767 - recoil_loss: 0.1123 - val_depth_acc_depth: 0.9254 - val_depth_loss: 0.1045 - val_loss: 0.7771 - val_rate_acc_rate: 0.5589 - val_rate_loss: 0.3114 - val_recoil_acc_recoil: 0.7738 - val_recoil_loss: 0.1355 - learning_rate: 5.0000e-04
# Epoch 8/30
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - depth_acc_depth: 0.8570 - depth_loss: 0.1530 - loss: 0.7762 - rate_acc_rate: 0.7245 - rate_loss: 0.2554 - recoil_acc_recoil: 0.7872 - recoil_loss: 0.1073 - val_depth_acc_depth: 0.9310 - val_depth_loss: 0.1015 - val_loss: 0.8081 - val_rate_acc_rate: 0.5369 - val_rate_loss: 0.3416 - val_recoil_acc_recoil: 0.7781 - val_recoil_loss: 0.1400 - learning_rate: 2.5000e-04
# Epoch 9/30
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - depth_acc_depth: 0.8606 - depth_loss: 0.1500 - loss: 0.7636 - rate_acc_rate: 0.7287 - rate_loss: 0.2516 - recoil_acc_recoil: 0.7880 - recoil_loss: 0.1059 - val_depth_acc_depth: 0.9295 - val_depth_loss: 0.1006 - val_loss: 0.7894 - val_rate_acc_rate: 0.5864 - val_rate_loss: 0.3318 - val_recoil_acc_recoil: 0.7846 - val_recoil_loss: 0.1373 - learning_rate: 2.5000e-04
# Epoch 10/30
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 39s 22ms/step - depth_acc_depth: 0.8639 - depth_loss: 0.1453 - loss: 0.7483 - rate_acc_rate: 0.7306 - rate_loss: 0.2490 - recoil_acc_recoil: 0.7902 - recoil_loss: 0.1044 - val_depth_acc_depth: 0.9326 - val_depth_loss: 0.1069 - val_loss: 0.7903 - val_rate_acc_rate: 0.5500 - val_rate_loss: 0.3252 - val_recoil_acc_recoil: 0.7808 - val_recoil_loss: 0.1339 - learning_rate: 2.5000e-04
# Epoch 11/30
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - depth_acc_depth: 0.8677 - depth_loss: 0.1416 - loss: 0.7339 - rate_acc_rate: 0.7369 - rate_loss: 0.2446 - recoil_acc_recoil: 0.7948 - recoil_loss: 0.1031
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 39s 21ms/step - depth_acc_depth: 0.8667 - depth_loss: 0.1422 - loss: 0.7346 - rate_acc_rate: 0.7361 - rate_loss: 0.2442 - recoil_acc_recoil: 0.7949 - recoil_loss: 0.1030 - val_depth_acc_depth: 0.9312 - val_depth_loss: 0.1119 - val_loss: 0.8812 - val_rate_acc_rate: 0.5343 - val_rate_loss: 0.3675 - val_recoil_acc_recoil: 0.7764 - val_recoil_loss: 0.1537 - learning_rate: 2.5000e-04
# ✓ GRU complete
#
# [STARTING] TCN | lw={'rate': 1.0, 'depth': 2.0, 'recoil': 2.0} | lr=0.0005
# Epoch 1/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 43s 14ms/step - depth_acc_depth: 0.7402 - depth_loss: 0.2478 - loss: 1.1375 - rate_acc_rate: 0.6582 - rate_loss: 0.3166 - recoil_acc_recoil: 0.7258 - recoil_loss: 0.1625 - val_depth_acc_depth: 0.9136 - val_depth_loss: 0.0744 - val_loss: 0.5678 - val_rate_acc_rate: 0.7197 - val_rate_loss: 0.2077 - val_recoil_acc_recoil: 0.7796 - val_recoil_loss: 0.1088 - learning_rate: 5.0000e-04
# Epoch 2/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.8613 - depth_loss: 0.1084 - loss: 0.6120 - rate_acc_rate: 0.7670 - rate_loss: 0.1959 - recoil_acc_recoil: 0.8192 - recoil_loss: 0.0996 - val_depth_acc_depth: 0.9300 - val_depth_loss: 0.0563 - val_loss: 0.4934 - val_rate_acc_rate: 0.7948 - val_rate_loss: 0.1632 - val_recoil_acc_recoil: 0.7924 - val_recoil_loss: 0.1138 - learning_rate: 5.0000e-04
# Epoch 3/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - depth_acc_depth: 0.8934 - depth_loss: 0.0851 - loss: 0.4992 - rate_acc_rate: 0.8134 - rate_loss: 0.1582 - recoil_acc_recoil: 0.8472 - recoil_loss: 0.0853 - val_depth_acc_depth: 0.9317 - val_depth_loss: 0.0485 - val_loss: 0.4482 - val_rate_acc_rate: 0.8281 - val_rate_loss: 0.1324 - val_recoil_acc_recoil: 0.7885 - val_recoil_loss: 0.1132 - learning_rate: 5.0000e-04
# Epoch 4/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - depth_acc_depth: 0.9155 - depth_loss: 0.0688 - loss: 0.4254 - rate_acc_rate: 0.8405 - rate_loss: 0.1369 - recoil_acc_recoil: 0.8666 - recoil_loss: 0.0754 - val_depth_acc_depth: 0.9261 - val_depth_loss: 0.0564 - val_loss: 0.4640 - val_rate_acc_rate: 0.8433 - val_rate_loss: 0.1368 - val_recoil_acc_recoil: 0.7950 - val_recoil_loss: 0.1147 - learning_rate: 5.0000e-04
# Epoch 5/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9311 - depth_loss: 0.0589 - loss: 0.3748 - rate_acc_rate: 0.8571 - rate_loss: 0.1212 - recoil_acc_recoil: 0.8823 - recoil_loss: 0.0678 - val_depth_acc_depth: 0.9370 - val_depth_loss: 0.0456 - val_loss: 0.3964 - val_rate_acc_rate: 0.8839 - val_rate_loss: 0.1025 - val_recoil_acc_recoil: 0.8040 - val_recoil_loss: 0.1065 - learning_rate: 5.0000e-04
# Epoch 6/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9433 - depth_loss: 0.0497 - loss: 0.3315 - rate_acc_rate: 0.8713 - rate_loss: 0.1077 - recoil_acc_recoil: 0.8934 - recoil_loss: 0.0621 - val_depth_acc_depth: 0.9549 - val_depth_loss: 0.0373 - val_loss: 0.3818 - val_rate_acc_rate: 0.8817 - val_rate_loss: 0.1128 - val_recoil_acc_recoil: 0.8170 - val_recoil_loss: 0.1025 - learning_rate: 5.0000e-04
# Epoch 7/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9518 - depth_loss: 0.0418 - loss: 0.2933 - rate_acc_rate: 0.8827 - rate_loss: 0.0980 - recoil_acc_recoil: 0.9042 - recoil_loss: 0.0558 - val_depth_acc_depth: 0.9611 - val_depth_loss: 0.0357 - val_loss: 0.3984 - val_rate_acc_rate: 0.8737 - val_rate_loss: 0.1239 - val_recoil_acc_recoil: 0.8199 - val_recoil_loss: 0.1098 - learning_rate: 5.0000e-04
# Epoch 8/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9577 - depth_loss: 0.0389 - loss: 0.2758 - rate_acc_rate: 0.8905 - rate_loss: 0.0918 - recoil_acc_recoil: 0.9101 - recoil_loss: 0.0531 - val_depth_acc_depth: 0.9684 - val_depth_loss: 0.0324 - val_loss: 0.3742 - val_rate_acc_rate: 0.8790 - val_rate_loss: 0.1184 - val_recoil_acc_recoil: 0.8317 - val_recoil_loss: 0.1037 - learning_rate: 5.0000e-04
# Epoch 9/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - depth_acc_depth: 0.9634 - depth_loss: 0.0342 - loss: 0.2526 - rate_acc_rate: 0.8972 - rate_loss: 0.0856 - recoil_acc_recoil: 0.9168 - recoil_loss: 0.0493 - val_depth_acc_depth: 0.9669 - val_depth_loss: 0.0263 - val_loss: 0.3604 - val_rate_acc_rate: 0.8778 - val_rate_loss: 0.1161 - val_recoil_acc_recoil: 0.8332 - val_recoil_loss: 0.1017 - learning_rate: 5.0000e-04
# Epoch 10/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9650 - depth_loss: 0.0315 - loss: 0.2378 - rate_acc_rate: 0.9033 - rate_loss: 0.0802 - recoil_acc_recoil: 0.9206 - recoil_loss: 0.0472 - val_depth_acc_depth: 0.9720 - val_depth_loss: 0.0251 - val_loss: 0.3275 - val_rate_acc_rate: 0.8935 - val_rate_loss: 0.1039 - val_recoil_acc_recoil: 0.8411 - val_recoil_loss: 0.0937 - learning_rate: 5.0000e-04
# Epoch 11/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - depth_acc_depth: 0.9680 - depth_loss: 0.0281 - loss: 0.2212 - rate_acc_rate: 0.9069 - rate_loss: 0.0758 - recoil_acc_recoil: 0.9230 - recoil_loss: 0.0446 - val_depth_acc_depth: 0.9730 - val_depth_loss: 0.0277 - val_loss: 0.3443 - val_rate_acc_rate: 0.9039 - val_rate_loss: 0.0979 - val_recoil_acc_recoil: 0.8332 - val_recoil_loss: 0.1025 - learning_rate: 5.0000e-04
# Epoch 12/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - depth_acc_depth: 0.9706 - depth_loss: 0.0266 - loss: 0.2113 - rate_acc_rate: 0.9121 - rate_loss: 0.0720 - recoil_acc_recoil: 0.9266 - recoil_loss: 0.0430 - val_depth_acc_depth: 0.9730 - val_depth_loss: 0.0272 - val_loss: 0.3449 - val_rate_acc_rate: 0.8979 - val_rate_loss: 0.1032 - val_recoil_acc_recoil: 0.8404 - val_recoil_loss: 0.0993 - learning_rate: 5.0000e-04
# Epoch 13/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - depth_acc_depth: 0.9728 - depth_loss: 0.0248 - loss: 0.2009 - rate_acc_rate: 0.9154 - rate_loss: 0.0687 - recoil_acc_recoil: 0.9290 - recoil_loss: 0.0414 - val_depth_acc_depth: 0.9744 - val_depth_loss: 0.0285 - val_loss: 0.3227 - val_rate_acc_rate: 0.8981 - val_rate_loss: 0.1027 - val_recoil_acc_recoil: 0.8503 - val_recoil_loss: 0.0888 - learning_rate: 5.0000e-04
# Epoch 14/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9742 - depth_loss: 0.0243 - loss: 0.1951 - rate_acc_rate: 0.9196 - rate_loss: 0.0660 - recoil_acc_recoil: 0.9317 - recoil_loss: 0.0402 - val_depth_acc_depth: 0.9759 - val_depth_loss: 0.0227 - val_loss: 0.3157 - val_rate_acc_rate: 0.8974 - val_rate_loss: 0.0998 - val_recoil_acc_recoil: 0.8535 - val_recoil_loss: 0.0904 - learning_rate: 5.0000e-04
# Epoch 15/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - depth_acc_depth: 0.9762 - depth_loss: 0.0225 - loss: 0.1867 - rate_acc_rate: 0.9209 - rate_loss: 0.0641 - recoil_acc_recoil: 0.9337 - recoil_loss: 0.0388 - val_depth_acc_depth: 0.9754 - val_depth_loss: 0.0270 - val_loss: 0.3170 - val_rate_acc_rate: 0.9097 - val_rate_loss: 0.0981 - val_recoil_acc_recoil: 0.8530 - val_recoil_loss: 0.0903 - learning_rate: 5.0000e-04
# Epoch 16/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9769 - depth_loss: 0.0209 - loss: 0.1787 - rate_acc_rate: 0.9232 - rate_loss: 0.0617 - recoil_acc_recoil: 0.9347 - recoil_loss: 0.0376 - val_depth_acc_depth: 0.9746 - val_depth_loss: 0.0304 - val_loss: 0.3483 - val_rate_acc_rate: 0.8998 - val_rate_loss: 0.1046 - val_recoil_acc_recoil: 0.8457 - val_recoil_loss: 0.0977 - learning_rate: 5.0000e-04
# Epoch 17/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - depth_acc_depth: 0.9772 - depth_loss: 0.0212 - loss: 0.1774 - rate_acc_rate: 0.9252 - rate_loss: 0.0605 - recoil_acc_recoil: 0.9373 - recoil_loss: 0.0373 - val_depth_acc_depth: 0.9766 - val_depth_loss: 0.0254 - val_loss: 0.3062 - val_rate_acc_rate: 0.9080 - val_rate_loss: 0.0948 - val_recoil_acc_recoil: 0.8631 - val_recoil_loss: 0.0863 - learning_rate: 5.0000e-04
# Epoch 18/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9794 - depth_loss: 0.0197 - loss: 0.1686 - rate_acc_rate: 0.9295 - rate_loss: 0.0572 - recoil_acc_recoil: 0.9384 - recoil_loss: 0.0360 - val_depth_acc_depth: 0.9766 - val_depth_loss: 0.0245 - val_loss: 0.3139 - val_rate_acc_rate: 0.9000 - val_rate_loss: 0.1026 - val_recoil_acc_recoil: 0.8624 - val_recoil_loss: 0.0882 - learning_rate: 5.0000e-04
# Epoch 19/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9802 - depth_loss: 0.0186 - loss: 0.1641 - rate_acc_rate: 0.9304 - rate_loss: 0.0566 - recoil_acc_recoil: 0.9408 - recoil_loss: 0.0352 - val_depth_acc_depth: 0.9790 - val_depth_loss: 0.0203 - val_loss: 0.2993 - val_rate_acc_rate: 0.9104 - val_rate_loss: 0.0967 - val_recoil_acc_recoil: 0.8682 - val_recoil_loss: 0.0862 - learning_rate: 5.0000e-04
# Epoch 20/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9805 - depth_loss: 0.0184 - loss: 0.1612 - rate_acc_rate: 0.9318 - rate_loss: 0.0560 - recoil_acc_recoil: 0.9424 - recoil_loss: 0.0341 - val_depth_acc_depth: 0.9814 - val_depth_loss: 0.0208 - val_loss: 0.2995 - val_rate_acc_rate: 0.9194 - val_rate_loss: 0.0977 - val_recoil_acc_recoil: 0.8626 - val_recoil_loss: 0.0880 - learning_rate: 5.0000e-04
# Epoch 21/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9808 - depth_loss: 0.0182 - loss: 0.1576 - rate_acc_rate: 0.9344 - rate_loss: 0.0539 - recoil_acc_recoil: 0.9423 - recoil_loss: 0.0336 - val_depth_acc_depth: 0.9817 - val_depth_loss: 0.0212 - val_loss: 0.2982 - val_rate_acc_rate: 0.9109 - val_rate_loss: 0.1010 - val_recoil_acc_recoil: 0.8730 - val_recoil_loss: 0.0857 - learning_rate: 5.0000e-04
# Epoch 22/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9810 - depth_loss: 0.0182 - loss: 0.1553 - rate_acc_rate: 0.9362 - rate_loss: 0.0528 - recoil_acc_recoil: 0.9433 - recoil_loss: 0.0330 - val_depth_acc_depth: 0.9754 - val_depth_loss: 0.0260 - val_loss: 0.3135 - val_rate_acc_rate: 0.9025 - val_rate_loss: 0.1046 - val_recoil_acc_recoil: 0.8713 - val_recoil_loss: 0.0860 - learning_rate: 5.0000e-04
# Epoch 23/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9821 - depth_loss: 0.0168 - loss: 0.1510 - rate_acc_rate: 0.9378 - rate_loss: 0.0512 - recoil_acc_recoil: 0.9447 - recoil_loss: 0.0330 - val_depth_acc_depth: 0.9780 - val_depth_loss: 0.0246 - val_loss: 0.3231 - val_rate_acc_rate: 0.9049 - val_rate_loss: 0.1135 - val_recoil_acc_recoil: 0.8764 - val_recoil_loss: 0.0877 - learning_rate: 5.0000e-04
# Epoch 24/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - depth_acc_depth: 0.9836 - depth_loss: 0.0163 - loss: 0.1472 - rate_acc_rate: 0.9399 - rate_loss: 0.0502 - recoil_acc_recoil: 0.9455 - recoil_loss: 0.0322 - val_depth_acc_depth: 0.9771 - val_depth_loss: 0.0245 - val_loss: 0.3071 - val_rate_acc_rate: 0.9092 - val_rate_loss: 0.1067 - val_recoil_acc_recoil: 0.8807 - val_recoil_loss: 0.0831 - learning_rate: 5.0000e-04
# Epoch 25/25
# 1823/1828 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - depth_acc_depth: 0.9826 - depth_loss: 0.0168 - loss: 0.1488 - rate_acc_rate: 0.9383 - rate_loss: 0.0517 - recoil_acc_recoil: 0.9450 - recoil_loss: 0.0317
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - depth_acc_depth: 0.9834 - depth_loss: 0.0157 - loss: 0.1440 - rate_acc_rate: 0.9395 - rate_loss: 0.0500 - recoil_acc_recoil: 0.9466 - recoil_loss: 0.0313 - val_depth_acc_depth: 0.9802 - val_depth_loss: 0.0227 - val_loss: 0.3017 - val_rate_acc_rate: 0.9177 - val_rate_loss: 0.0994 - val_recoil_acc_recoil: 0.8778 - val_recoil_loss: 0.0862 - learning_rate: 5.0000e-04
# ✓ TCN complete
#
# [STARTING] Conv1D | lw={'rate': 1.0, 'depth': 2.0, 'recoil': 2.0} | lr=0.001
# Epoch 1/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 23s 8ms/step - depth_acc_depth: 0.7783 - depth_loss: 0.2230 - loss: 0.9445 - rate_acc_rate: 0.7077 - rate_loss: 0.2613 - recoil_acc_recoil: 0.7913 - recoil_loss: 0.1186 - val_depth_acc_depth: 0.9124 - val_depth_loss: 0.0860 - val_loss: 0.6241 - val_rate_acc_rate: 0.7446 - val_rate_loss: 0.1840 - val_recoil_acc_recoil: 0.7436 - val_recoil_loss: 0.1375 - learning_rate: 0.0010
# Epoch 2/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - depth_acc_depth: 0.8936 - depth_loss: 0.0950 - loss: 0.5443 - rate_acc_rate: 0.7723 - rate_loss: 0.1798 - recoil_acc_recoil: 0.8521 - recoil_loss: 0.0873 - val_depth_acc_depth: 0.9167 - val_depth_loss: 0.0635 - val_loss: 0.5357 - val_rate_acc_rate: 0.7670 - val_rate_loss: 0.1587 - val_recoil_acc_recoil: 0.7586 - val_recoil_loss: 0.1293 - learning_rate: 0.0010
# Epoch 3/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - depth_acc_depth: 0.9182 - depth_loss: 0.0726 - loss: 0.4478 - rate_acc_rate: 0.8023 - rate_loss: 0.1513 - recoil_acc_recoil: 0.8735 - recoil_loss: 0.0756 - val_depth_acc_depth: 0.9401 - val_depth_loss: 0.0598 - val_loss: 0.4924 - val_rate_acc_rate: 0.7658 - val_rate_loss: 0.1703 - val_recoil_acc_recoil: 0.7859 - val_recoil_loss: 0.1075 - learning_rate: 0.0010
# Epoch 4/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9323 - depth_loss: 0.0609 - loss: 0.3872 - rate_acc_rate: 0.8238 - rate_loss: 0.1305 - recoil_acc_recoil: 0.8865 - recoil_loss: 0.0675 - val_depth_acc_depth: 0.9191 - val_depth_loss: 0.0607 - val_loss: 0.5001 - val_rate_acc_rate: 0.7735 - val_rate_loss: 0.1641 - val_recoil_acc_recoil: 0.7938 - val_recoil_loss: 0.1145 - learning_rate: 0.0010
# Epoch 5/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9405 - depth_loss: 0.0543 - loss: 0.3546 - rate_acc_rate: 0.8339 - rate_loss: 0.1212 - recoil_acc_recoil: 0.8945 - recoil_loss: 0.0624 - val_depth_acc_depth: 0.9493 - val_depth_loss: 0.0447 - val_loss: 0.4720 - val_rate_acc_rate: 0.7656 - val_rate_loss: 0.1752 - val_recoil_acc_recoil: 0.7895 - val_recoil_loss: 0.1134 - learning_rate: 0.0010
# Epoch 6/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9461 - depth_loss: 0.0482 - loss: 0.3252 - rate_acc_rate: 0.8497 - rate_loss: 0.1114 - recoil_acc_recoil: 0.9013 - recoil_loss: 0.0587 - val_depth_acc_depth: 0.9336 - val_depth_loss: 0.0638 - val_loss: 0.5069 - val_rate_acc_rate: 0.7813 - val_rate_loss: 0.1687 - val_recoil_acc_recoil: 0.7970 - val_recoil_loss: 0.1138 - learning_rate: 0.0010
# Epoch 7/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - depth_acc_depth: 0.9504 - depth_loss: 0.0442 - loss: 0.3042 - rate_acc_rate: 0.8526 - rate_loss: 0.1052 - recoil_acc_recoil: 0.9062 - recoil_loss: 0.0553 - val_depth_acc_depth: 0.9435 - val_depth_loss: 0.0493 - val_loss: 0.4357 - val_rate_acc_rate: 0.8030 - val_rate_loss: 0.1584 - val_recoil_acc_recoil: 0.8233 - val_recoil_loss: 0.1001 - learning_rate: 0.0010
# Epoch 8/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9542 - depth_loss: 0.0426 - loss: 0.2927 - rate_acc_rate: 0.8609 - rate_loss: 0.1008 - recoil_acc_recoil: 0.9095 - recoil_loss: 0.0533 - val_depth_acc_depth: 0.9442 - val_depth_loss: 0.0499 - val_loss: 0.4414 - val_rate_acc_rate: 0.8213 - val_rate_loss: 0.1504 - val_recoil_acc_recoil: 0.8129 - val_recoil_loss: 0.1061 - learning_rate: 0.0010
# Epoch 9/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - depth_acc_depth: 0.9573 - depth_loss: 0.0392 - loss: 0.2754 - rate_acc_rate: 0.8672 - rate_loss: 0.0962 - recoil_acc_recoil: 0.9148 - recoil_loss: 0.0504 - val_depth_acc_depth: 0.9488 - val_depth_loss: 0.0483 - val_loss: 0.4231 - val_rate_acc_rate: 0.8213 - val_rate_loss: 0.1478 - val_recoil_acc_recoil: 0.8141 - val_recoil_loss: 0.0978 - learning_rate: 0.0010
# Epoch 10/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - depth_acc_depth: 0.9607 - depth_loss: 0.0368 - loss: 0.2629 - rate_acc_rate: 0.8737 - rate_loss: 0.0911 - recoil_acc_recoil: 0.9177 - recoil_loss: 0.0491 - val_depth_acc_depth: 0.9358 - val_depth_loss: 0.0584 - val_loss: 0.4321 - val_rate_acc_rate: 0.8351 - val_rate_loss: 0.1393 - val_recoil_acc_recoil: 0.8071 - val_recoil_loss: 0.0991 - learning_rate: 0.0010
# Epoch 11/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9621 - depth_loss: 0.0346 - loss: 0.2500 - rate_acc_rate: 0.8799 - rate_loss: 0.0883 - recoil_acc_recoil: 0.9217 - recoil_loss: 0.0462 - val_depth_acc_depth: 0.9476 - val_depth_loss: 0.0509 - val_loss: 0.4515 - val_rate_acc_rate: 0.8170 - val_rate_loss: 0.1513 - val_recoil_acc_recoil: 0.8201 - val_recoil_loss: 0.1092 - learning_rate: 0.0010
# Epoch 12/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9637 - depth_loss: 0.0345 - loss: 0.2477 - rate_acc_rate: 0.8824 - rate_loss: 0.0863 - recoil_acc_recoil: 0.9228 - recoil_loss: 0.0462 - val_depth_acc_depth: 0.9577 - val_depth_loss: 0.0480 - val_loss: 0.4235 - val_rate_acc_rate: 0.8209 - val_rate_loss: 0.1598 - val_recoil_acc_recoil: 0.8341 - val_recoil_loss: 0.0957 - learning_rate: 0.0010
# Epoch 13/25
# 1820/1828 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - depth_acc_depth: 0.9664 - depth_loss: 0.0316 - loss: 0.2368 - rate_acc_rate: 0.8843 - rate_loss: 0.0839 - recoil_acc_recoil: 0.9255 - recoil_loss: 0.0449
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - depth_acc_depth: 0.9658 - depth_loss: 0.0316 - loss: 0.2358 - rate_acc_rate: 0.8859 - rate_loss: 0.0831 - recoil_acc_recoil: 0.9260 - recoil_loss: 0.0448 - val_depth_acc_depth: 0.9551 - val_depth_loss: 0.0495 - val_loss: 0.4233 - val_rate_acc_rate: 0.8254 - val_rate_loss: 0.1396 - val_recoil_acc_recoil: 0.8257 - val_recoil_loss: 0.0996 - learning_rate: 0.0010
# Epoch 14/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9732 - depth_loss: 0.0255 - loss: 0.2042 - rate_acc_rate: 0.8990 - rate_loss: 0.0734 - recoil_acc_recoil: 0.9334 - recoil_loss: 0.0398 - val_depth_acc_depth: 0.9493 - val_depth_loss: 0.0542 - val_loss: 0.4285 - val_rate_acc_rate: 0.8291 - val_rate_loss: 0.1477 - val_recoil_acc_recoil: 0.8375 - val_recoil_loss: 0.0953 - learning_rate: 5.0000e-04
# Epoch 15/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9772 - depth_loss: 0.0221 - loss: 0.1863 - rate_acc_rate: 0.9064 - rate_loss: 0.0676 - recoil_acc_recoil: 0.9369 - recoil_loss: 0.0372 - val_depth_acc_depth: 0.9524 - val_depth_loss: 0.0562 - val_loss: 0.4282 - val_rate_acc_rate: 0.8452 - val_rate_loss: 0.1404 - val_recoil_acc_recoil: 0.8358 - val_recoil_loss: 0.0969 - learning_rate: 5.0000e-04
# Epoch 16/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - depth_acc_depth: 0.9771 - depth_loss: 0.0218 - loss: 0.1827 - rate_acc_rate: 0.9101 - rate_loss: 0.0661 - recoil_acc_recoil: 0.9386 - recoil_loss: 0.0365 - val_depth_acc_depth: 0.9561 - val_depth_loss: 0.0561 - val_loss: 0.4250 - val_rate_acc_rate: 0.8402 - val_rate_loss: 0.1439 - val_recoil_acc_recoil: 0.8431 - val_recoil_loss: 0.0957 - learning_rate: 5.0000e-04
# Epoch 17/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9773 - depth_loss: 0.0221 - loss: 0.1836 - rate_acc_rate: 0.9101 - rate_loss: 0.0657 - recoil_acc_recoil: 0.9376 - recoil_loss: 0.0369 - val_depth_acc_depth: 0.9544 - val_depth_loss: 0.0545 - val_loss: 0.4054 - val_rate_acc_rate: 0.8481 - val_rate_loss: 0.1387 - val_recoil_acc_recoil: 0.8363 - val_recoil_loss: 0.0885 - learning_rate: 5.0000e-04
# Epoch 18/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9780 - depth_loss: 0.0213 - loss: 0.1745 - rate_acc_rate: 0.9158 - rate_loss: 0.0622 - recoil_acc_recoil: 0.9410 - recoil_loss: 0.0349 - val_depth_acc_depth: 0.9592 - val_depth_loss: 0.0504 - val_loss: 0.4007 - val_rate_acc_rate: 0.8489 - val_rate_loss: 0.1471 - val_recoil_acc_recoil: 0.8479 - val_recoil_loss: 0.0891 - learning_rate: 5.0000e-04
# Epoch 19/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9789 - depth_loss: 0.0205 - loss: 0.1731 - rate_acc_rate: 0.9164 - rate_loss: 0.0623 - recoil_acc_recoil: 0.9413 - recoil_loss: 0.0349 - val_depth_acc_depth: 0.9515 - val_depth_loss: 0.0569 - val_loss: 0.4254 - val_rate_acc_rate: 0.8590 - val_rate_loss: 0.1515 - val_recoil_acc_recoil: 0.8407 - val_recoil_loss: 0.0932 - learning_rate: 5.0000e-04
# Epoch 20/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - depth_acc_depth: 0.9797 - depth_loss: 0.0201 - loss: 0.1699 - rate_acc_rate: 0.9174 - rate_loss: 0.0611 - recoil_acc_recoil: 0.9432 - recoil_loss: 0.0342 - val_depth_acc_depth: 0.9532 - val_depth_loss: 0.0585 - val_loss: 0.4269 - val_rate_acc_rate: 0.8481 - val_rate_loss: 0.1494 - val_recoil_acc_recoil: 0.8452 - val_recoil_loss: 0.0949 - learning_rate: 5.0000e-04
# Epoch 21/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9791 - depth_loss: 0.0198 - loss: 0.1670 - rate_acc_rate: 0.9200 - rate_loss: 0.0601 - recoil_acc_recoil: 0.9427 - recoil_loss: 0.0337 - val_depth_acc_depth: 0.9549 - val_depth_loss: 0.0566 - val_loss: 0.4097 - val_rate_acc_rate: 0.8469 - val_rate_loss: 0.1402 - val_recoil_acc_recoil: 0.8525 - val_recoil_loss: 0.0893 - learning_rate: 5.0000e-04
# Epoch 22/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - depth_acc_depth: 0.9794 - depth_loss: 0.0196 - loss: 0.1640 - rate_acc_rate: 0.9207 - rate_loss: 0.0585 - recoil_acc_recoil: 0.9446 - recoil_loss: 0.0332 - val_depth_acc_depth: 0.9544 - val_depth_loss: 0.0522 - val_loss: 0.3995 - val_rate_acc_rate: 0.8539 - val_rate_loss: 0.1360 - val_recoil_acc_recoil: 0.8433 - val_recoil_loss: 0.0899 - learning_rate: 5.0000e-04
# Epoch 23/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - depth_acc_depth: 0.9810 - depth_loss: 0.0181 - loss: 0.1623 - rate_acc_rate: 0.9215 - rate_loss: 0.0597 - recoil_acc_recoil: 0.9449 - recoil_loss: 0.0332 - val_depth_acc_depth: 0.9529 - val_depth_loss: 0.0542 - val_loss: 0.4131 - val_rate_acc_rate: 0.8510 - val_rate_loss: 0.1453 - val_recoil_acc_recoil: 0.8484 - val_recoil_loss: 0.0927 - learning_rate: 5.0000e-04
# Epoch 24/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9814 - depth_loss: 0.0180 - loss: 0.1571 - rate_acc_rate: 0.9233 - rate_loss: 0.0570 - recoil_acc_recoil: 0.9453 - recoil_loss: 0.0321 - val_depth_acc_depth: 0.9556 - val_depth_loss: 0.0555 - val_loss: 0.4339 - val_rate_acc_rate: 0.8544 - val_rate_loss: 0.1475 - val_recoil_acc_recoil: 0.8394 - val_recoil_loss: 0.0998 - learning_rate: 5.0000e-04
# Epoch 25/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - depth_acc_depth: 0.9821 - depth_loss: 0.0173 - loss: 0.1524 - rate_acc_rate: 0.9284 - rate_loss: 0.0550 - recoil_acc_recoil: 0.9465 - recoil_loss: 0.0314 - val_depth_acc_depth: 0.9534 - val_depth_loss: 0.0601 - val_loss: 0.4058 - val_rate_acc_rate: 0.8677 - val_rate_loss: 0.1301 - val_recoil_acc_recoil: 0.8513 - val_recoil_loss: 0.0899 - learning_rate: 5.0000e-04
# ✓ Conv1D complete
#
# [STARTING] ST_Transformer | lw={'rate': 1.0, 'depth': 2.0, 'recoil': 2.0} | lr=0.0005
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.0005000000237487257.
# Epoch 1/35
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 38s 13ms/step - depth_acc_depth: 0.7987 - depth_loss: 0.1927 - loss: 0.8330 - rate_acc_rate: 0.7138 - rate_loss: 0.2411 - recoil_acc_recoil: 0.8242 - recoil_loss: 0.1033 - val_depth_acc_depth: 0.8778 - val_depth_loss: 0.1310 - val_loss: 0.7132 - val_rate_acc_rate: 0.7772 - val_rate_loss: 0.1861 - val_recoil_acc_recoil: 0.7743 - val_recoil_loss: 0.1440 - learning_rate: 5.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0004877647734247148.
# Epoch 2/35
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.8997 - depth_loss: 0.0952 - loss: 0.4964 - rate_acc_rate: 0.7973 - rate_loss: 0.1585 - recoil_acc_recoil: 0.8767 - recoil_loss: 0.0737 - val_depth_acc_depth: 0.8607 - val_depth_loss: 0.1574 - val_loss: 0.8216 - val_rate_acc_rate: 0.7603 - val_rate_loss: 0.1992 - val_recoil_acc_recoil: 0.7583 - val_recoil_loss: 0.1675 - learning_rate: 4.8776e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00045225664507597685.
# Epoch 3/35
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9198 - depth_loss: 0.0755 - loss: 0.4188 - rate_acc_rate: 0.8200 - rate_loss: 0.1369 - recoil_acc_recoil: 0.8900 - recoil_loss: 0.0655 - val_depth_acc_depth: 0.8906 - val_depth_loss: 0.1500 - val_loss: 0.7750 - val_rate_acc_rate: 0.7883 - val_rate_loss: 0.1871 - val_recoil_acc_recoil: 0.7801 - val_recoil_loss: 0.1611 - learning_rate: 4.5226e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.00039695148007012904.
# Epoch 4/35
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - depth_acc_depth: 0.9345 - depth_loss: 0.0622 - loss: 0.3633 - rate_acc_rate: 0.8394 - rate_loss: 0.1221 - recoil_acc_recoil: 0.9022 - recoil_loss: 0.0584 - val_depth_acc_depth: 0.8812 - val_depth_loss: 0.1648 - val_loss: 0.8158 - val_rate_acc_rate: 0.7909 - val_rate_loss: 0.1882 - val_recoil_acc_recoil: 0.7866 - val_recoil_loss: 0.1716 - learning_rate: 3.9695e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0003272628819104284.
# Epoch 5/35
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - depth_acc_depth: 0.9420 - depth_loss: 0.0544 - loss: 0.3271 - rate_acc_rate: 0.8556 - rate_loss: 0.1107 - recoil_acc_recoil: 0.9100 - recoil_loss: 0.0538 - val_depth_acc_depth: 0.9003 - val_depth_loss: 0.1464 - val_loss: 0.7875 - val_rate_acc_rate: 0.7931 - val_rate_loss: 0.1946 - val_recoil_acc_recoil: 0.7813 - val_recoil_loss: 0.1668 - learning_rate: 3.2726e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.00025001249741762877.
# Epoch 6/35
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - depth_acc_depth: 0.9508 - depth_loss: 0.0466 - loss: 0.2889 - rate_acc_rate: 0.8668 - rate_loss: 0.0984 - recoil_acc_recoil: 0.9185 - recoil_loss: 0.0487 - val_depth_acc_depth: 0.9104 - val_depth_loss: 0.1519 - val_loss: 0.8522 - val_rate_acc_rate: 0.8059 - val_rate_loss: 0.2109 - val_recoil_acc_recoil: 0.7822 - val_recoil_loss: 0.1915 - learning_rate: 2.5001e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.00017276206926908344.
# Epoch 7/35
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - depth_acc_depth: 0.9571 - depth_loss: 0.0408 - loss: 0.2626 - rate_acc_rate: 0.8793 - rate_loss: 0.0902 - recoil_acc_recoil: 0.9239 - recoil_loss: 0.0453 - val_depth_acc_depth: 0.9174 - val_depth_loss: 0.1565 - val_loss: 0.8413 - val_rate_acc_rate: 0.8134 - val_rate_loss: 0.2159 - val_recoil_acc_recoil: 0.8052 - val_recoil_loss: 0.1822 - learning_rate: 1.7276e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.00010307353659300134.
# Epoch 8/35
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - depth_acc_depth: 0.9629 - depth_loss: 0.0357 - loss: 0.2399 - rate_acc_rate: 0.8863 - rate_loss: 0.0832 - recoil_acc_recoil: 0.9264 - recoil_loss: 0.0426 - val_depth_acc_depth: 0.9244 - val_depth_loss: 0.1527 - val_loss: 0.8190 - val_rate_acc_rate: 0.8141 - val_rate_loss: 0.2220 - val_recoil_acc_recoil: 0.8211 - val_recoil_loss: 0.1759 - learning_rate: 1.0307e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 4.776834975928068e-05.
# Epoch 9/35
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - depth_acc_depth: 0.9656 - depth_loss: 0.0319 - loss: 0.2219 - rate_acc_rate: 0.8940 - rate_loss: 0.0782 - recoil_acc_recoil: 0.9322 - recoil_loss: 0.0399 - val_depth_acc_depth: 0.9259 - val_depth_loss: 0.1515 - val_loss: 0.8164 - val_rate_acc_rate: 0.8143 - val_rate_loss: 0.2174 - val_recoil_acc_recoil: 0.8192 - val_recoil_loss: 0.1782 - learning_rate: 4.7768e-05
# ✓ ST_Transformer complete
#
# [STARTING] CNN_BiLSTM | lw={'rate': 1.0, 'depth': 2.0, 'recoil': 2.0} | lr=0.0005
# Epoch 1/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 52s 25ms/step - depth_acc_depth: 0.7906 - depth_loss: 0.1983 - loss: 0.8535 - rate_acc_rate: 0.7147 - rate_loss: 0.2348 - recoil_acc_recoil: 0.8023 - recoil_loss: 0.1110 - val_depth_acc_depth: 0.9022 - val_depth_loss: 0.0797 - val_loss: 0.5489 - val_rate_acc_rate: 0.7699 - val_rate_loss: 0.1679 - val_recoil_acc_recoil: 0.7839 - val_recoil_loss: 0.1178 - learning_rate: 5.0000e-04
# Epoch 2/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 45s 25ms/step - depth_acc_depth: 0.9247 - depth_loss: 0.0651 - loss: 0.4254 - rate_acc_rate: 0.7880 - rate_loss: 0.1506 - recoil_acc_recoil: 0.8744 - recoil_loss: 0.0723 - val_depth_acc_depth: 0.9324 - val_depth_loss: 0.0633 - val_loss: 0.5233 - val_rate_acc_rate: 0.7859 - val_rate_loss: 0.1688 - val_recoil_acc_recoil: 0.7933 - val_recoil_loss: 0.1226 - learning_rate: 5.0000e-04
# Epoch 3/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9519 - depth_loss: 0.0434 - loss: 0.3349 - rate_acc_rate: 0.8147 - rate_loss: 0.1273 - recoil_acc_recoil: 0.8958 - recoil_loss: 0.0604 - val_depth_acc_depth: 0.9491 - val_depth_loss: 0.0541 - val_loss: 0.4948 - val_rate_acc_rate: 0.7680 - val_rate_loss: 0.1741 - val_recoil_acc_recoil: 0.7977 - val_recoil_loss: 0.1165 - learning_rate: 5.0000e-04
# Epoch 4/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9640 - depth_loss: 0.0340 - loss: 0.2875 - rate_acc_rate: 0.8366 - rate_loss: 0.1125 - recoil_acc_recoil: 0.9077 - recoil_loss: 0.0535 - val_depth_acc_depth: 0.9553 - val_depth_loss: 0.0523 - val_loss: 0.4715 - val_rate_acc_rate: 0.7827 - val_rate_loss: 0.1641 - val_recoil_acc_recoil: 0.8151 - val_recoil_loss: 0.1123 - learning_rate: 5.0000e-04
# Epoch 5/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 81s 25ms/step - depth_acc_depth: 0.9722 - depth_loss: 0.0271 - loss: 0.2494 - rate_acc_rate: 0.8564 - rate_loss: 0.0986 - recoil_acc_recoil: 0.9165 - recoil_loss: 0.0483 - val_depth_acc_depth: 0.9614 - val_depth_loss: 0.0524 - val_loss: 0.4760 - val_rate_acc_rate: 0.8001 - val_rate_loss: 0.1652 - val_recoil_acc_recoil: 0.8124 - val_recoil_loss: 0.1142 - learning_rate: 5.0000e-04
# Epoch 6/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 83s 26ms/step - depth_acc_depth: 0.9765 - depth_loss: 0.0227 - loss: 0.2225 - rate_acc_rate: 0.8733 - rate_loss: 0.0879 - recoil_acc_recoil: 0.9243 - recoil_loss: 0.0446 - val_depth_acc_depth: 0.9652 - val_depth_loss: 0.0430 - val_loss: 0.4544 - val_rate_acc_rate: 0.8059 - val_rate_loss: 0.1597 - val_recoil_acc_recoil: 0.8083 - val_recoil_loss: 0.1181 - learning_rate: 5.0000e-04
# Epoch 7/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 47s 25ms/step - depth_acc_depth: 0.9801 - depth_loss: 0.0190 - loss: 0.1995 - rate_acc_rate: 0.8901 - rate_loss: 0.0794 - recoil_acc_recoil: 0.9306 - recoil_loss: 0.0410 - val_depth_acc_depth: 0.9742 - val_depth_loss: 0.0425 - val_loss: 0.4315 - val_rate_acc_rate: 0.8230 - val_rate_loss: 0.1617 - val_recoil_acc_recoil: 0.8245 - val_recoil_loss: 0.1056 - learning_rate: 5.0000e-04
# Epoch 8/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 81s 25ms/step - depth_acc_depth: 0.9830 - depth_loss: 0.0163 - loss: 0.1789 - rate_acc_rate: 0.9022 - rate_loss: 0.0709 - recoil_acc_recoil: 0.9352 - recoil_loss: 0.0377 - val_depth_acc_depth: 0.9696 - val_depth_loss: 0.0489 - val_loss: 0.4550 - val_rate_acc_rate: 0.8423 - val_rate_loss: 0.1587 - val_recoil_acc_recoil: 0.8416 - val_recoil_loss: 0.1186 - learning_rate: 5.0000e-04
# Epoch 9/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - depth_acc_depth: 0.9852 - depth_loss: 0.0151 - loss: 0.1662 - rate_acc_rate: 0.9114 - rate_loss: 0.0650 - recoil_acc_recoil: 0.9406 - recoil_loss: 0.0355 - val_depth_acc_depth: 0.9754 - val_depth_loss: 0.0406 - val_loss: 0.3995 - val_rate_acc_rate: 0.8687 - val_rate_loss: 0.1328 - val_recoil_acc_recoil: 0.8438 - val_recoil_loss: 0.1067 - learning_rate: 5.0000e-04
# Epoch 10/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 45s 25ms/step - depth_acc_depth: 0.9874 - depth_loss: 0.0130 - loss: 0.1482 - rate_acc_rate: 0.9236 - rate_loss: 0.0576 - recoil_acc_recoil: 0.9463 - recoil_loss: 0.0323 - val_depth_acc_depth: 0.9727 - val_depth_loss: 0.0414 - val_loss: 0.4148 - val_rate_acc_rate: 0.8621 - val_rate_loss: 0.1426 - val_recoil_acc_recoil: 0.8496 - val_recoil_loss: 0.1133 - learning_rate: 5.0000e-04
# Epoch 11/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9888 - depth_loss: 0.0111 - loss: 0.1353 - rate_acc_rate: 0.9315 - rate_loss: 0.0525 - recoil_acc_recoil: 0.9485 - recoil_loss: 0.0303 - val_depth_acc_depth: 0.9742 - val_depth_loss: 0.0401 - val_loss: 0.4027 - val_rate_acc_rate: 0.8737 - val_rate_loss: 0.1392 - val_recoil_acc_recoil: 0.8600 - val_recoil_loss: 0.1120 - learning_rate: 5.0000e-04
# Epoch 12/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - depth_acc_depth: 0.9899 - depth_loss: 0.0109 - loss: 0.1305 - rate_acc_rate: 0.9361 - rate_loss: 0.0509 - recoil_acc_recoil: 0.9521 - recoil_loss: 0.0289 - val_depth_acc_depth: 0.9708 - val_depth_loss: 0.0422 - val_loss: 0.3988 - val_rate_acc_rate: 0.8754 - val_rate_loss: 0.1404 - val_recoil_acc_recoil: 0.8585 - val_recoil_loss: 0.1074 - learning_rate: 5.0000e-04
# Epoch 13/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9907 - depth_loss: 0.0095 - loss: 0.1182 - rate_acc_rate: 0.9425 - rate_loss: 0.0449 - recoil_acc_recoil: 0.9541 - recoil_loss: 0.0271 - val_depth_acc_depth: 0.9734 - val_depth_loss: 0.0427 - val_loss: 0.3985 - val_rate_acc_rate: 0.8699 - val_rate_loss: 0.1407 - val_recoil_acc_recoil: 0.8670 - val_recoil_loss: 0.1032 - learning_rate: 5.0000e-04
# Epoch 14/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9914 - depth_loss: 0.0089 - loss: 0.1106 - rate_acc_rate: 0.9476 - rate_loss: 0.0418 - recoil_acc_recoil: 0.9575 - recoil_loss: 0.0255 - val_depth_acc_depth: 0.9715 - val_depth_loss: 0.0436 - val_loss: 0.3992 - val_rate_acc_rate: 0.8940 - val_rate_loss: 0.1366 - val_recoil_acc_recoil: 0.8675 - val_recoil_loss: 0.1105 - learning_rate: 5.0000e-04
# Epoch 15/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - depth_acc_depth: 0.9920 - depth_loss: 0.0084 - loss: 0.1072 - rate_acc_rate: 0.9513 - rate_loss: 0.0398 - recoil_acc_recoil: 0.9583 - recoil_loss: 0.0253 - val_depth_acc_depth: 0.9742 - val_depth_loss: 0.0449 - val_loss: 0.3998 - val_rate_acc_rate: 0.8945 - val_rate_loss: 0.1333 - val_recoil_acc_recoil: 0.8679 - val_recoil_loss: 0.1103 - learning_rate: 5.0000e-04
# Epoch 16/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 45s 25ms/step - depth_acc_depth: 0.9937 - depth_loss: 0.0066 - loss: 0.0938 - rate_acc_rate: 0.9570 - rate_loss: 0.0356 - recoil_acc_recoil: 0.9624 - recoil_loss: 0.0224 - val_depth_acc_depth: 0.9742 - val_depth_loss: 0.0474 - val_loss: 0.4065 - val_rate_acc_rate: 0.9121 - val_rate_loss: 0.1320 - val_recoil_acc_recoil: 0.8831 - val_recoil_loss: 0.1163 - learning_rate: 5.0000e-04
# Epoch 17/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 95s 32ms/step - depth_acc_depth: 0.9938 - depth_loss: 0.0069 - loss: 0.0935 - rate_acc_rate: 0.9571 - rate_loss: 0.0346 - recoil_acc_recoil: 0.9626 - recoil_loss: 0.0225 - val_depth_acc_depth: 0.9788 - val_depth_loss: 0.0450 - val_loss: 0.3810 - val_rate_acc_rate: 0.9252 - val_rate_loss: 0.1180 - val_recoil_acc_recoil: 0.8901 - val_recoil_loss: 0.1137 - learning_rate: 5.0000e-04
# Epoch 18/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9942 - depth_loss: 0.0066 - loss: 0.0878 - rate_acc_rate: 0.9608 - rate_loss: 0.0324 - recoil_acc_recoil: 0.9650 - recoil_loss: 0.0211 - val_depth_acc_depth: 0.9744 - val_depth_loss: 0.0482 - val_loss: 0.4093 - val_rate_acc_rate: 0.9220 - val_rate_loss: 0.1194 - val_recoil_acc_recoil: 0.8764 - val_recoil_loss: 0.1250 - learning_rate: 5.0000e-04
# Epoch 19/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9947 - depth_loss: 0.0061 - loss: 0.0838 - rate_acc_rate: 0.9631 - rate_loss: 0.0306 - recoil_acc_recoil: 0.9650 - recoil_loss: 0.0205 - val_depth_acc_depth: 0.9754 - val_depth_loss: 0.0442 - val_loss: 0.3981 - val_rate_acc_rate: 0.9083 - val_rate_loss: 0.1348 - val_recoil_acc_recoil: 0.8848 - val_recoil_loss: 0.1128 - learning_rate: 5.0000e-04
# Epoch 20/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9948 - depth_loss: 0.0063 - loss: 0.0831 - rate_acc_rate: 0.9642 - rate_loss: 0.0300 - recoil_acc_recoil: 0.9662 - recoil_loss: 0.0203 - val_depth_acc_depth: 0.9703 - val_depth_loss: 0.0615 - val_loss: 0.4676 - val_rate_acc_rate: 0.9206 - val_rate_loss: 0.1582 - val_recoil_acc_recoil: 0.8984 - val_recoil_loss: 0.1254 - learning_rate: 5.0000e-04
# Epoch 21/25
# 1827/1828 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - depth_acc_depth: 0.9947 - depth_loss: 0.0062 - loss: 0.0806 - rate_acc_rate: 0.9652 - rate_loss: 0.0294 - recoil_acc_recoil: 0.9681 - recoil_loss: 0.0194
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 45s 25ms/step - depth_acc_depth: 0.9950 - depth_loss: 0.0058 - loss: 0.0805 - rate_acc_rate: 0.9644 - rate_loss: 0.0296 - recoil_acc_recoil: 0.9675 - recoil_loss: 0.0197 - val_depth_acc_depth: 0.9800 - val_depth_loss: 0.0422 - val_loss: 0.3929 - val_rate_acc_rate: 0.9237 - val_rate_loss: 0.1337 - val_recoil_acc_recoil: 0.8986 - val_recoil_loss: 0.1176 - learning_rate: 5.0000e-04
# Epoch 22/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9972 - depth_loss: 0.0028 - loss: 0.0578 - rate_acc_rate: 0.9740 - rate_loss: 0.0215 - recoil_acc_recoil: 0.9730 - recoil_loss: 0.0153 - val_depth_acc_depth: 0.9778 - val_depth_loss: 0.0533 - val_loss: 0.4455 - val_rate_acc_rate: 0.9317 - val_rate_loss: 0.1390 - val_recoil_acc_recoil: 0.8986 - val_recoil_loss: 0.1313 - learning_rate: 2.5000e-04
# Epoch 23/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - depth_acc_depth: 0.9973 - depth_loss: 0.0031 - loss: 0.0572 - rate_acc_rate: 0.9751 - rate_loss: 0.0212 - recoil_acc_recoil: 0.9746 - recoil_loss: 0.0149 - val_depth_acc_depth: 0.9797 - val_depth_loss: 0.0432 - val_loss: 0.3914 - val_rate_acc_rate: 0.9351 - val_rate_loss: 0.1310 - val_recoil_acc_recoil: 0.9078 - val_recoil_loss: 0.1201 - learning_rate: 2.5000e-04
# Epoch 24/25
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 45s 25ms/step - depth_acc_depth: 0.9976 - depth_loss: 0.0027 - loss: 0.0536 - rate_acc_rate: 0.9768 - rate_loss: 0.0196 - recoil_acc_recoil: 0.9750 - recoil_loss: 0.0142 - val_depth_acc_depth: 0.9809 - val_depth_loss: 0.0453 - val_loss: 0.4127 - val_rate_acc_rate: 0.9331 - val_rate_loss: 0.1335 - val_recoil_acc_recoil: 0.9046 - val_recoil_loss: 0.1280 - learning_rate: 2.5000e-04
# Epoch 25/25
# 1827/1828 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - depth_acc_depth: 0.9978 - depth_loss: 0.0025 - loss: 0.0528 - rate_acc_rate: 0.9774 - rate_loss: 0.0193 - recoil_acc_recoil: 0.9754 - recoil_loss: 0.0142
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1828/1828 ━━━━━━━━━━━━━━━━━━━━ 83s 25ms/step - depth_acc_depth: 0.9976 - depth_loss: 0.0027 - loss: 0.0521 - rate_acc_rate: 0.9774 - rate_loss: 0.0189 - recoil_acc_recoil: 0.9755 - recoil_loss: 0.0139 - val_depth_acc_depth: 0.9804 - val_depth_loss: 0.0501 - val_loss: 0.4450 - val_rate_acc_rate: 0.9322 - val_rate_loss: 0.1423 - val_recoil_acc_recoil: 0.9027 - val_recoil_loss: 0.1339 - learning_rate: 2.5000e-04
# ✓ CNN_BiLSTM complete

# %%
import numpy as np

# Calculate majority class baseline for Depth
unique, counts = np.unique(yd_tr, return_counts=True)
majority_idx = np.argmax(counts)
majority_count = counts[majority_idx]
total_count = len(yd_tr)
baseline_acc = majority_count / total_count

print(f"--- Majority Class Baseline Analysis ---")
print(f"Total training samples: {total_count}")
print(f"Majority class ('{le_depth.classes_[majority_idx]}') count: {majority_count}")
print(f"Majority baseline accuracy: {baseline_acc:.4f}")

if abs(baseline_acc - 0.8186) < 0.001:
    print("\nRESULT: The 0.8186 accuracy matches your majority class baseline.")
    print("This means the model is simply defaulting to the most common class.")
else:
    print("\nRESULT: The 0.8186 is not the majority baseline, but it is highly specific.")
# Out:
# --- Majority Class Baseline Analysis ---
# Total training samples: 58482
# Majority class ('Correct') count: 38988
# Majority baseline accuracy: 0.6667
#
# RESULT: The 0.8186 is not the majority baseline, but it is highly specific.

# %% [markdown]
# ## STAGE 9 — Evaluation: F1, AUC-ROC, Confusion Matrices

# %%
def evaluate(model, name):
    preds = model.predict(X_test, verbose=0)
    # ── FIX: output_heads() returns a dict {'rate':..., 'depth':..., 'recoil':...}
    #    Index by key, not by integer position.
    out = {'model': name}

    for task, y_true, enc in [
        ('rate',   yr_test,  le_rate),
        ('depth',  yd_test,  le_depth),
        ('recoil', yrc_test, le_recoil),
    ]:
        probs  = preds[task]          # FIX: dict key, not preds[i]
        y_pred = np.argmax(probs, axis=1)
        acc    = (y_true == y_pred).mean()
        f1_w   = f1_score(y_true, y_pred, average='weighted', zero_division=0)
        f1_m   = f1_score(y_true, y_pred, average='macro',    zero_division=0)
        try:
            if probs.shape[1] == 2:
                auc = roc_auc_score(y_true, probs[:, 1])
            else:
                auc = roc_auc_score(
                    to_oh(y_true, probs.shape[1]),
                    probs, multi_class='ovr', average='macro')
        except Exception:
            auc = float('nan')

        out[f'{task}_acc']  = round(acc  * 100, 2)
        out[f'{task}_f1_w'] = round(f1_w * 100, 2)
        out[f'{task}_f1_m'] = round(f1_m * 100, 2)
        out[f'{task}_auc']  = round(auc  * 100, 2) if not np.isnan(auc) else float('nan')

        # Per-class breakdown for diagnosis
        report = classification_report(y_true, y_pred,
                                        target_names=enc.classes_,
                                        zero_division=0)
        print(f'  [{task.upper():6s}] acc={acc*100:.1f}% F1_w={f1_w*100:.1f}% F1_m={f1_m*100:.1f}% AUC={'n/a' if np.isnan(auc) else f'{auc:.3f}'}')
        print(report)
    return out


eval_rows = []
for name, model in all_models.items():
    print(f'\n── {name} ──────────────────────────────────────')
    eval_rows.append(evaluate(model, name))

res_df = pd.DataFrame(eval_rows).set_index('model')
res_df.to_csv(str(CHECKPOINT_DIR / 'benchmark_results.csv'))

print('\n\n' + '='*70)
print('FULL COMPARISON TABLE')
print('='*70)
print(res_df[['rate_f1_w','depth_f1_w','recoil_f1_w',
              'rate_auc', 'depth_auc', 'recoil_auc']].to_string())
print('\n✓ Results saved to Drive')
# Out:
# ── BiLSTM ──────────────────────────────────────
#   [RATE  ] acc=63.3% F1_w=70.0% F1_m=48.4% AUC=0.866
#               precision    recall  f1-score   support
#
#      Correct       0.97      0.62      0.75      3570
#     Too_Fast       0.19      0.94      0.32       269
#     Too_Slow       0.29      0.54      0.38       283
#
#     accuracy                           0.63      4122
#    macro avg       0.48      0.70      0.48      4122
# weighted avg       0.87      0.63      0.70      4122
#
#   [DEPTH ] acc=95.5% F1_w=95.3% F1_m=87.7% AUC=0.952
#               precision    recall  f1-score   support
#
#      Correct       0.96      0.98      0.97      3273
#     Too_Deep       0.79      0.60      0.68       277
#  Too_Shallow       0.96      0.99      0.97       572
#
#     accuracy                           0.96      4122
#    macro avg       0.91      0.86      0.88      4122
# weighted avg       0.95      0.96      0.95      4122
#
#   [RECOIL] acc=82.0% F1_w=82.0% F1_m=81.6% AUC=0.893
#               precision    recall  f1-score   support
#
#     Complete       0.79      0.80      0.79      1782
#   Incomplete       0.84      0.84      0.84      2340
#
#     accuracy                           0.82      4122
#    macro avg       0.82      0.82      0.82      4122
# weighted avg       0.82      0.82      0.82      4122
#
#
# ── CNN_LSTM ──────────────────────────────────────
#   [RATE  ] acc=84.2% F1_w=86.2% F1_m=69.4% AUC=0.944
#               precision    recall  f1-score   support
#
#      Correct       0.97      0.85      0.90      3570
#     Too_Fast       0.36      0.86      0.51       269
#     Too_Slow       0.59      0.77      0.67       283
#
#     accuracy                           0.84      4122
#    macro avg       0.64      0.83      0.69      4122
# weighted avg       0.90      0.84      0.86      4122
#
#   [DEPTH ] acc=97.4% F1_w=97.3% F1_m=93.5% AUC=0.979
#               precision    recall  f1-score   support
#
#      Correct       0.98      0.99      0.98      3273
#     Too_Deep       0.89      0.81      0.85       277
#  Too_Shallow       0.96      0.99      0.97       572
#
#     accuracy                           0.97      4122
#    macro avg       0.95      0.93      0.93      4122
# weighted avg       0.97      0.97      0.97      4122
#
#   [RECOIL] acc=85.4% F1_w=85.4% F1_m=85.3% AUC=0.942
#               precision    recall  f1-score   support
#
#     Complete       0.79      0.89      0.84      1782
#   Incomplete       0.91      0.82      0.86      2340
#
#     accuracy                           0.85      4122
#    macro avg       0.85      0.86      0.85      4122
# weighted avg       0.86      0.85      0.85      4122
#
#
# ── GRU ──────────────────────────────────────
#   [RATE  ] acc=56.3% F1_w=64.4% F1_m=39.5% AUC=0.773
#               precision    recall  f1-score   support
#
#      Correct       0.94      0.57      0.71      3570
#     Too_Fast       0.13      0.79      0.23       269
#     Too_Slow       0.23      0.28      0.25       283
#
#     accuracy                           0.56      4122
#    macro avg       0.43      0.55      0.40      4122
# weighted avg       0.84      0.56      0.64      4122
#
#   [DEPTH ] acc=92.9% F1_w=91.6% F1_m=75.3% AUC=0.904
#               precision    recall  f1-score   support
#
#      Correct       0.93      0.99      0.96      3273
#     Too_Deep       0.68      0.23      0.35       277
#  Too_Shallow       0.98      0.93      0.95       572
#
#     accuracy                           0.93      4122
#    macro avg       0.86      0.72      0.75      4122
# weighted avg       0.92      0.93      0.92      4122
#
#   [RECOIL] acc=75.4% F1_w=75.4% F1_m=74.9% AUC=0.839
#               precision    recall  f1-score   support
#
#     Complete       0.71      0.72      0.72      1782
#   Incomplete       0.78      0.78      0.78      2340
#
#     accuracy                           0.75      4122
#    macro avg       0.75      0.75      0.75      4122
# weighted avg       0.75      0.75      0.75      4122
#
#
# ── TCN ──────────────────────────────────────
#   [RATE  ] acc=90.9% F1_w=91.7% F1_m=80.0% AUC=0.983
#               precision    recall  f1-score   support
#
#      Correct       0.99      0.91      0.95      3570
#     Too_Fast       0.58      0.95      0.72       269
#     Too_Slow       0.61      0.90      0.73       283
#
#     accuracy                           0.91      4122
#    macro avg       0.73      0.92      0.80      4122
# weighted avg       0.94      0.91      0.92      4122
#
#   [DEPTH ] acc=98.3% F1_w=98.3% F1_m=95.5% AUC=0.993
#               precision    recall  f1-score   support
#
#      Correct       0.99      0.99      0.99      3273
#     Too_Deep       0.93      0.84      0.88       277
#  Too_Shallow       0.99      1.00      0.99       572
#
#     accuracy                           0.98      4122
#    macro avg       0.97      0.94      0.95      4122
# weighted avg       0.98      0.98      0.98      4122
#
#   [RECOIL] acc=88.5% F1_w=88.5% F1_m=88.4% AUC=0.959
#               precision    recall  f1-score   support
#
#     Complete       0.82      0.94      0.88      1782
#   Incomplete       0.95      0.84      0.89      2340
#
#     accuracy                           0.88      4122
#    macro avg       0.88      0.89      0.88      4122
# weighted avg       0.89      0.88      0.89      4122
#
#
# ── Conv1D ──────────────────────────────────────
#   [RATE  ] acc=84.8% F1_w=86.8% F1_m=70.7% AUC=0.946
#               precision    recall  f1-score   support
#
#      Correct       0.98      0.85      0.91      3570
#     Too_Fast       0.37      0.85      0.52       269
#     Too_Slow       0.58      0.85      0.69       283
#
#     accuracy                           0.85      4122
#    macro avg       0.65      0.85      0.71      4122
# weighted avg       0.91      0.85      0.87      4122
#
#   [DEPTH ] acc=96.3% F1_w=96.3% F1_m=91.2% AUC=0.974
#               precision    recall  f1-score   support
#
#      Correct       0.98      0.98      0.98      3273
#     Too_Deep       0.81      0.79      0.80       277
#  Too_Shallow       0.95      0.96      0.95       572
#
#     accuracy                           0.96      4122
#    macro avg       0.91      0.91      0.91      4122
# weighted avg       0.96      0.96      0.96      4122
#
#   [RECOIL] acc=84.9% F1_w=84.9% F1_m=84.8% AUC=0.943
#               precision    recall  f1-score   support
#
#     Complete       0.77      0.93      0.84      1782
#   Incomplete       0.94      0.79      0.86      2340
#
#     accuracy                           0.85      4122
#    macro avg       0.85      0.86      0.85      4122
# weighted avg       0.86      0.85      0.85      4122
#
#
# ── ST_Transformer ──────────────────────────────────────
#   [RATE  ] acc=74.4% F1_w=78.2% F1_m=54.7% AUC=0.859
#               precision    recall  f1-score   support
#
#      Correct       0.95      0.76      0.84      3570
#     Too_Fast       0.29      0.79      0.42       269
#     Too_Slow       0.29      0.54      0.38       283
#
#     accuracy                           0.74      4122
#    macro avg       0.51      0.70      0.55      4122
# weighted avg       0.86      0.74      0.78      4122
#
#   [DEPTH ] acc=86.4% F1_w=87.4% F1_m=74.9% AUC=0.933
#               precision    recall  f1-score   support
#
#      Correct       0.94      0.90      0.92      3273
#     Too_Deep       0.41      0.76      0.54       277
#  Too_Shallow       0.87      0.73      0.79       572
#
#     accuracy                           0.86      4122
#    macro avg       0.74      0.80      0.75      4122
# weighted avg       0.89      0.86      0.87      4122
#
#   [RECOIL] acc=76.4% F1_w=76.5% F1_m=76.4% AUC=0.879
#               precision    recall  f1-score   support
#
#     Complete       0.68      0.87      0.76      1782
#   Incomplete       0.87      0.69      0.77      2340
#
#     accuracy                           0.76      4122
#    macro avg       0.77      0.78      0.76      4122
# weighted avg       0.79      0.76      0.76      4122
#
#
# ── CNN_BiLSTM ──────────────────────────────────────
#   [RATE  ] acc=90.8% F1_w=91.3% F1_m=78.1% AUC=0.955
#               precision    recall  f1-score   support
#
#      Correct       0.97      0.92      0.95      3570
#     Too_Fast       0.56      0.80      0.66       269
#     Too_Slow       0.68      0.81      0.74       283
#
#     accuracy                           0.91      4122
#    macro avg       0.74      0.84      0.78      4122
# weighted avg       0.92      0.91      0.91      4122
#
#   [DEPTH ] acc=97.6% F1_w=97.5% F1_m=93.9% AUC=0.984
#               precision    recall  f1-score   support
#
#      Correct       0.98      0.99      0.99      3273
#     Too_Deep       0.88      0.83      0.85       277
#  Too_Shallow       0.99      0.97      0.98       572
#
#     accuracy                           0.98      4122
#    macro avg       0.95      0.93      0.94      4122
# weighted avg       0.98      0.98      0.98      4122
#
#   [RECOIL] acc=88.1% F1_w=88.2% F1_m=88.0% AUC=0.955
#               precision    recall  f1-score   support
#
#     Complete       0.84      0.90      0.87      1782
#   Incomplete       0.92      0.86      0.89      2340
#
#     accuracy                           0.88      4122
#    macro avg       0.88      0.88      0.88      4122
# weighted avg       0.88      0.88      0.88      4122
#
#
#
# ======================================================================
# FULL COMPARISON TABLE
# ======================================================================
#                 rate_f1_w  depth_f1_w  recoil_f1_w  rate_auc  depth_auc  recoil_auc
# model
# BiLSTM              70.00       95.31        81.96     86.65      95.19       89.25
# CNN_LSTM            86.21       97.34        85.44     94.36      97.86       94.20
# GRU                 64.44       91.55        75.36     77.29      90.44       83.88
# TCN                 91.71       98.27        88.50     98.27      99.34       95.93
# Conv1D              86.79       96.32        84.92     94.64      97.39       94.34
# ST_Transformer      78.16       87.39        76.46     85.87      93.26       87.93
# CNN_BiLSTM          91.31       97.55        88.15     95.49      98.43       95.54
#
# ✓ Results saved to Drive

# %% [markdown]
# ## STAGE 9.5 — Precision / Recall (post-hoc addition)

# %%
# ── Stage 9.5 — Precision / Recall (added post-hoc, no retrain needed) ───────
# evaluate() (cell above) already computes accuracy, weighted/macro F1, and
# AUC-ROC and saves them to benchmark_results.csv — but never computed
# precision/recall as standalone values (they were only ever visible inside
# the printed classification_report() text, never captured into a variable).
#
# This cell re-runs inference on the already-trained models in `all_models`
# (no training, just predict() + sklearn metrics) and adds
# {task}_precision_w / {task}_recall_w (weighted, matching f1_w's averaging)
# to res_df, then re-saves benchmark_results.csv.
#
# Safe to run any time after the Stage 9 cell above has populated
# `all_models`, `res_df`, and the X_test/y*_test splits — does NOT require
# re-running training or Stage 1-8.

from sklearn.metrics import precision_score, recall_score

precision_recall_rows = []

for name, model in all_models.items():
    preds = model.predict(X_test, verbose=0)
    row = {'model': name}

    for task, y_true, enc in [
        ('rate',   yr_test,  le_rate),
        ('depth',  yd_test,  le_depth),
        ('recoil', yrc_test, le_recoil),
    ]:
        probs  = preds[task]
        y_pred = np.argmax(probs, axis=1)

        prec_w = precision_score(y_true, y_pred, average='weighted', zero_division=0)
        rec_w  = recall_score(y_true, y_pred, average='weighted', zero_division=0)
        prec_m = precision_score(y_true, y_pred, average='macro', zero_division=0)
        rec_m  = recall_score(y_true, y_pred, average='macro', zero_division=0)

        row[f'{task}_precision_w'] = round(prec_w * 100, 2)
        row[f'{task}_recall_w']    = round(rec_w  * 100, 2)
        row[f'{task}_precision_m'] = round(prec_m * 100, 2)
        row[f'{task}_recall_m']    = round(rec_m  * 100, 2)

        print(f'  [{name:14s} | {task.upper():6s}] '
              f'Prec_w={prec_w*100:.1f}%  Rec_w={rec_w*100:.1f}%')

    precision_recall_rows.append(row)

pr_df = pd.DataFrame(precision_recall_rows).set_index('model')

# Merge into the existing res_df (from the Stage 9 evaluate() cell above) and
# re-save — this keeps everything in one CSV instead of two separate files.

# FIX: Remove existing precision/recall columns from res_df before joining to prevent ValueError on re-run
existing_pr_cols = [col for col in pr_df.columns if col in res_df.columns]
if existing_pr_cols:
    res_df = res_df.drop(columns=existing_pr_cols)

res_df = res_df.join(pr_df)
res_df.to_csv(str(CHECKPOINT_DIR / 'benchmark_results.csv'))

print('\n' + '='*70)
print('PRECISION / RECALL — FULL COMPARISON TABLE (weighted)')
print('='*70)
print(res_df[['rate_precision_w', 'rate_recall_w',
              'depth_precision_w', 'depth_recall_w',
              'recoil_precision_w', 'recoil_recall_w']].to_string())

# Define best_name before its usage
best_name = res_df['depth_f1_w'].astype(float).idxmax()
best_pr = res_df.loc[best_name]
print(f'\n🏆 {best_name} (best model) — Precision/Recall summary:')
for task in ['rate', 'depth', 'recoil']:
    print(f'   {task.capitalize():8s} Precision_w={best_pr[f"{task}_precision_w"]:.2f}%  '
          f'Recall_w={best_pr[f"{task}_recall_w"]:.2f}%')

print(f'\n✓ Updated benchmark_results.csv saved to: {CHECKPOINT_DIR}')
# Out:
#   [BiLSTM         | RATE  ] Prec_w=87.2%  Rec_w=63.3%
#   [BiLSTM         | DEPTH ] Prec_w=95.3%  Rec_w=95.5%
#   [BiLSTM         | RECOIL] Prec_w=82.0%  Rec_w=82.0%
#   [CNN_LSTM       | RATE  ] Prec_w=90.5%  Rec_w=84.2%
#   [CNN_LSTM       | DEPTH ] Prec_w=97.3%  Rec_w=97.4%
#   [CNN_LSTM       | RECOIL] Prec_w=86.0%  Rec_w=85.4%
#   [GRU            | RATE  ] Prec_w=83.6%  Rec_w=56.3%
#   [GRU            | DEPTH ] Prec_w=91.8%  Rec_w=92.9%
#   [GRU            | RECOIL] Prec_w=75.4%  Rec_w=75.4%
#   [TCN            | RATE  ] Prec_w=93.8%  Rec_w=90.9%
#   [TCN            | DEPTH ] Prec_w=98.3%  Rec_w=98.3%
#   [TCN            | RECOIL] Prec_w=89.2%  Rec_w=88.5%
#   [Conv1D         | RATE  ] Prec_w=91.1%  Rec_w=84.8%
#   [Conv1D         | DEPTH ] Prec_w=96.3%  Rec_w=96.3%
#   [Conv1D         | RECOIL] Prec_w=86.4%  Rec_w=84.9%
#   [ST_Transformer | RATE  ] Prec_w=85.7%  Rec_w=74.4%
#   [ST_Transformer | DEPTH ] Prec_w=89.3%  Rec_w=86.4%
#   [ST_Transformer | RECOIL] Prec_w=78.8%  Rec_w=76.4%
#   [CNN_BiLSTM     | RATE  ] Prec_w=92.3%  Rec_w=90.8%
#   [CNN_BiLSTM     | DEPTH ] Prec_w=97.5%  Rec_w=97.6%
#   [CNN_BiLSTM     | RECOIL] Prec_w=88.4%  Rec_w=88.1%
#
# ======================================================================
# PRECISION / RECALL — FULL COMPARISON TABLE (weighted)
# ======================================================================
#                 rate_precision_w  rate_recall_w  depth_precision_w  depth_recall_w  recoil_precision_w  recoil_recall_w
# model
# BiLSTM                     87.19          63.32              95.26           95.54               81.97            81.95
# CNN_LSTM                   90.47          84.18              97.33           97.38               85.99            85.37
# GRU                        83.61          56.26              91.85           92.89               75.38            75.35
# TCN                        93.80          90.90              98.27           98.30               89.22            88.45
# Conv1D                     91.08          84.84              96.31           96.34               86.40            84.86
# ST_Transformer             85.72          74.43              89.26           86.44               78.79            76.42
# CNN_BiLSTM                 92.32          90.76              97.53           97.57               88.41            88.11
#
# 🏆 TCN (best model) — Precision/Recall summary:
#    Rate     Precision_w=93.80%  Recall_w=90.90%
#    Depth    Precision_w=98.27%  Recall_w=98.30%
#    Recoil   Precision_w=89.22%  Recall_w=88.45%
#
# ✓ Updated benchmark_results.csv saved to: /content/drive/MyDrive/cpr_coach_checkpoints_tf

# %%
# ── Training curves ───────────────────────────────────────────────────────────
fig, axes = plt.subplots(2, 2, figsize=(16, 10))
colors = plt.cm.tab10(np.linspace(0, 1, len(histories)))

for ax, (vk, title) in zip(axes.flat, [
    ('val_loss',       'Val Total Loss'),
    ('val_rate_acc',   'Val Rate Accuracy'),
    ('val_depth_acc',  'Val Depth Accuracy'),
    ('val_recoil_acc', 'Val Recoil Accuracy'),
]):
    for (nm, h), col in zip(histories.items(), colors):
        if vk in h:
            ax.plot(h[vk], label=nm, color=col, lw=1.8)
    ax.set_title(title, fontweight='bold')
    ax.set_xlabel('Epoch')
    ax.legend(fontsize=7)
    ax.grid(True, alpha=0.3)

plt.suptitle('CPR-Coach Training Curves — All 7 Models', fontsize=13,
             fontweight='bold')
plt.tight_layout()
plt.savefig(str(CHECKPOINT_DIR / 'training_curves.png'), dpi=150,
            bbox_inches='tight')
plt.show()

# ── F1 bar chart ──────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(12, 5))
model_names = res_df.index.tolist()
x = np.arange(len(model_names))
w = 0.25
ax.bar(x - w, res_df['rate_f1_w'],   w, label='Rate F1',   color='#2196F3')
ax.bar(x,     res_df['depth_f1_w'],  w, label='Depth F1',  color='#4CAF50')
ax.bar(x + w, res_df['recoil_f1_w'], w, label='Recoil F1', color='#FF9800')
ax.axhline(85, color='red', ls='--', alpha=0.7, label='Target 85%')
ax.set_xticks(x)
ax.set_xticklabels(model_names, rotation=30, ha='right')
ax.set_ylabel('Weighted F1 (%)')
ax.set_title('Per-Task Weighted F1 — Test Set', fontweight='bold')
ax.legend()
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(str(CHECKPOINT_DIR / 'f1_comparison.png'), dpi=150,
            bbox_inches='tight')
plt.show()

# Best model = highest depth F1 (hardest task)
best_name = res_df['depth_f1_w'].astype(float).idxmax()
print(f'\n🏆 Best model (depth F1): {best_name}')
# Out:
# 🏆 Best model (depth F1): TCN

# %%
print('\n' + '='*70)
print(' MODEL RANKINGS (by mean metric across all tasks)')
print('='*70)

# Calculate mean F1-weighted across tasks
res_df['mean_f1_w'] = res_df[['rate_f1_w', 'depth_f1_w', 'recoil_f1_w']].mean(axis=1)

# Calculate mean Precision-weighted across tasks
res_df['mean_precision_w'] = res_df[['rate_precision_w', 'depth_precision_w', 'recoil_precision_w']].mean(axis=1)

# Calculate mean Recall-weighted across tasks
res_df['mean_recall_w'] = res_df[['rate_recall_w', 'depth_recall_w', 'recoil_recall_w']].mean(axis=1)

# Display rankings for each metric
print('\nRanked by Mean Weighted F1-score:')
print(res_df.sort_values(by='mean_f1_w', ascending=False)[['mean_f1_w', 'rate_f1_w', 'depth_f1_w', 'recoil_f1_w']].round(1).to_string())

print('\nRanked by Mean Weighted Precision:')
print(res_df.sort_values(by='mean_precision_w', ascending=False)[['mean_precision_w', 'rate_precision_w', 'depth_precision_w', 'recoil_precision_w']].round(1).to_string())

print('\nRanked by Mean Weighted Recall:')
print(res_df.sort_values(by='mean_recall_w', ascending=False)[['mean_recall_w', 'rate_recall_w', 'depth_recall_w', 'recoil_recall_w']].round(1).to_string())

print('\n✓ Model rankings generated.')
# Out:
# ======================================================================
#  MODEL RANKINGS (by mean metric across all tasks)
# ======================================================================
#
# Ranked by Mean Weighted F1-score:
#                 mean_f1_w  rate_f1_w  depth_f1_w  recoil_f1_w
# model
# TCN                  92.8       91.7        98.3         88.5
# CNN_BiLSTM           92.3       91.3        97.6         88.2
# CNN_LSTM             89.7       86.2        97.3         85.4
# Conv1D               89.3       86.8        96.3         84.9
# BiLSTM               82.4       70.0        95.3         82.0
# ST_Transformer       80.7       78.2        87.4         76.5
# GRU                  77.1       64.4        91.6         75.4
#
# Ranked by Mean Weighted Precision:
#                 mean_precision_w  rate_precision_w  depth_precision_w  recoil_precision_w
# model
# TCN                         93.8              93.8               98.3                89.2
# CNN_BiLSTM                  92.8              92.3               97.5                88.4
# CNN_LSTM                    91.3              90.5               97.3                86.0
# Conv1D                      91.3              91.1               96.3                86.4
# BiLSTM                      88.1              87.2               95.3                82.0
# ST_Transformer              84.6              85.7               89.3                78.8
# GRU                         83.6              83.6               91.8                75.4
#
# Ranked by Mean Weighted Recall:
#                 mean_recall_w  rate_recall_w  depth_recall_w  recoil_recall_w
# model
# TCN                      92.6           90.9            98.3             88.4
# CNN_BiLSTM               92.1           90.8            97.6             88.1
# CNN_LSTM                 89.0           84.2            97.4             85.4
# Conv1D                   88.7           84.8            96.3             84.9
# BiLSTM                   80.3           63.3            95.5             82.0
# ST_Transformer           79.1           74.4            86.4             76.4
# GRU                      74.8           56.3            92.9             75.4
#
# ✓ Model rankings generated.

# %%
# Models for which to plot confusion matrices
models_to_plot = [best_name, 'Conv1D'] # best_name is CNN_BiLSTM

# Create a figure with a row for each model and 3 columns for tasks
fig, axes = plt.subplots(len(models_to_plot), 3, figsize=(18, 5 * len(models_to_plot)))

# Ensure axes is always 2D for consistent indexing, especially if only one model is plotted
if len(models_to_plot) == 1:
    axes = np.array([axes])

# Define task information once for clarity and reusability
task_details = [
    ('rate',   yr_test,  le_rate),
    ('depth',  yd_test,  le_depth),
    ('recoil', yrc_test, le_recoil),
]

for model_row_idx, model_name in enumerate(models_to_plot):
    current_model = all_models[model_name]
    preds = current_model.predict(X_test, verbose=0)

    for task_col_idx, (task_name, y_true_labels, encoder) in enumerate(task_details):
        ax = axes[model_row_idx, task_col_idx]

        probs  = preds[task_name]
        y_pred = np.argmax(probs, axis=1)
        cm     = confusion_matrix(y_true_labels, y_pred)
        cm_pct = cm.astype(float) / (cm.sum(axis=1, keepdims=True) + 1e-8) * 100
        sns.heatmap(cm_pct, annot=True, fmt='.1f', cmap='Blues',
                    xticklabels=encoder.classes_,
                    yticklabels=encoder.classes_, ax=ax)
        ax.set_title(f'{task_name.capitalize()} [{model_name}]', fontweight='bold')
        ax.set_xlabel('Predicted')
        ax.set_ylabel('Actual')

plt.suptitle('Confusion Matrices — % of True Class — Test Set',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(str(CHECKPOINT_DIR / 'confusion_matrices_selected_models.png'), dpi=150,
            bbox_inches='tight')
plt.show()

# %% [markdown]
# ## STAGE 10 — TFLite INT8 Export + CPU Latency Benchmark

# %%
print(f'Attempting to export Conv1D model to TFLite INT8...')

# Select the Conv1D model for export
export_model_name = 'Conv1D'
if export_model_name not in all_models:
    raise ValueError(f"Model '{export_model_name}' not found in 'all_models'. Please run training first.")

model = all_models[export_model_name]

# Prepare representative dataset for INT8 quantization
# Using a subset of the training data as representative_dataset
calib_idx = np.random.choice(len(X_train), min(200, len(X_train)), replace=False)
calib_data = X_train[calib_idx].astype(np.float32)

def representative_dataset():
    for i in range(len(calib_data)):
        yield [calib_data[i:i+1]]

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
# Target INT8 operations for efficient mobile deployment
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

try:
    tflite_model_buf = converter.convert()
    tflite_path = CHECKPOINT_DIR / f'{export_model_name}_int8.tflite'
    tflite_path.write_bytes(tflite_model_buf)

    size_mb = tflite_path.stat().st_size / 1024 / 1024
    print(f'\n✓ Successfully exported {export_model_name} to TFLite INT8:')
    print(f'  Path : {tflite_path}')
    print(f'  Size : {size_mb:.2f} MB  (proposal target <5 MB) {{{"✓ PASS" if size_mb < 5 else "⚠ EXCEEDS"}}}')

    # Optionally, also export a float32 version for comparison/debugging
    # Float32 export (without quantization)
    print(f'\nAttempting to export {export_model_name} to TFLite Float32...')
    float_converter = tf.lite.TFLiteConverter.from_keras_model(model)
    float_converter.optimizations = [] # No optimizations for float model
    float_converter.target_spec.supported_ops = [
        tf.lite.OpsSet.TFLITE_BUILTINS,
        tf.lite.OpsSet.SELECT_TF_OPS,
    ]
    float_converter.inference_input_type = tf.float32
    float_converter.inference_output_type = tf.float32
    float_converter._experimental_lower_tensor_list_ops = False # Keep as False

    float_tflite_buf = float_converter.convert()
    float_tflite_path = CHECKPOINT_DIR / f'{export_model_name}_float.tflite'
    float_tflite_path.write_bytes(float_tflite_buf)
    float_size_mb = float_tflite_path.stat().st_size / 1024 / 1024
    print(f'✓ Successfully exported {export_model_name} to TFLite Float32:')
    print(f'  Path : {float_tflite_path}')
    print(f'  Size : {float_size_mb:.2f} MB')

except Exception as e:
    print(f'✗ Failed to export {export_model_name} to TFLite INT8: {e}')
# Out:
# Attempting to export Conv1D model to TFLite INT8...
# Saved artifact at '/tmp/tmpixz2ecgw'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 60, 12), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   Dict[['rate', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['depth', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['recoil', TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)]]
# Captures:
#   132155774229520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768230288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768230864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768229136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#
# ✓ Successfully exported Conv1D to TFLite INT8:
#   Path : /content/drive/MyDrive/cpr_coach_checkpoints_tf/Conv1D_int8.tflite
#   Size : 0.10 MB  (proposal target <5 MB) {✓ PASS}
#
# Attempting to export Conv1D to TFLite Float32...
# Saved artifact at '/tmp/tmp15e9w69h'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 60, 12), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   Dict[['rate', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['depth', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['recoil', TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)]]
# Captures:
#   132155774229520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768230288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768230864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768229136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226640: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✓ Successfully exported Conv1D to TFLite Float32:
#   Path : /content/drive/MyDrive/cpr_coach_checkpoints_tf/Conv1D_float.tflite
#   Size : 0.33 MB

# %%
import time
import os

# ── Stage 10: TFLite Export + Latency Benchmark ───────────────────────────────
# Only TCN, Conv1D, ST_Transformer passed <100ms. Recurrent models (BiLSTM,
# GRU, CNN_LSTM, CNN_BiLSTM) use TensorList ops internally that require the
# Flex delegate — which isn't available in standard Colab. Since they also
# fail the latency target by 4-9x, there's no reason to export them.

DEPLOY_CANDIDATES = ['TCN', 'Conv1D', 'ST_Transformer']

# ── Step 1: Keras → TFLite INT8 conversion ───────────────────────────────────
tflite_paths = {}

for name in DEPLOY_CANDIDATES:
    if name not in all_models:
        print(f'⚠ {name} not in all_models — skipping')
        continue

    print(f'Exporting {name} → TFLite INT8...')
    model = all_models[name]

    calib_idx  = np.random.choice(len(X_train), min(200, len(X_train)), replace=False)
    calib_data = X_train[calib_idx].astype(np.float32)

    def representative_dataset():
        for i in range(len(calib_data)):
            yield [calib_data[i:i+1]]

    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    converter.representative_dataset = representative_dataset
    # Standard BUILTINS_INT8 only — no flex ops needed for conv/attention models
    converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
    converter.inference_input_type  = tf.int8
    converter.inference_output_type = tf.int8

    try:
        tflite_model = converter.convert()
        path = CHECKPOINT_DIR / f'{name}_int8.tflite'
        path.write_bytes(tflite_model)
        tflite_paths[name] = path
        print(f'  ✓ {name}: {len(tflite_model)/1024:.1f} KB')
    except Exception as e:
        print(f'  ✗ {name} conversion failed: {e}')

# ── Step 2: Keras float32 latency (all models, CPU only) ─────────────────────
dummy_f32 = np.random.randn(1, SEQ_LEN, N_FEATS).astype(np.float32)
N_RUNS = 100

print('\nCPU latency benchmark — Keras float32 (simulates mid-range Android)\n')
print(f'{"Model":20s} | {"Avg ms":>8} | {"p95 ms":>8} | {"p99 ms":>8} | {"<100ms?":>8}')
print('-' * 62)

lat_records = {}
with tf.device('/CPU:0'):
    for name, model in all_models.items():
        for _ in range(5):                          # warm-up
            model(dummy_f32, training=False)
        ts = []
        for _ in range(N_RUNS):
            t0 = time.perf_counter()
            model(dummy_f32, training=False)
            ts.append((time.perf_counter() - t0) * 1000)
        avg = np.mean(ts)
        p95 = np.percentile(ts, 95)
        p99 = np.percentile(ts, 99)
        lat_records[name] = dict(avg_ms=avg, p95_ms=p95, p99_ms=p99)
        ok = '✓' if p95 < 100 else '✗'
        print(f'{name:20s} | {avg:8.1f} | {p95:8.1f} | {p99:8.1f} | {ok:>8}')

# ── Step 3: TFLite INT8 latency (deploy candidates only) ─────────────────────
print('\nTFLite INT8 latency — deploy candidates only\n')
print(f'{"Model":20s} | {"Avg ms":>8} | {"p95 ms":>8} | {"p99 ms":>8} | {"<100ms?":>8}')
print('-' * 62)

# INT8 interpreter needs int8 dummy input
dummy_i8 = np.zeros((1, SEQ_LEN, N_FEATS), dtype=np.int8)

for name, path in tflite_paths.items():
    try:
        interp = tf.lite.Interpreter(model_path=str(path))
        interp.allocate_tensors()
        in_detail  = interp.get_input_details()[0]
        in_idx     = in_detail['index']

        for _ in range(5):                          # warm-up
            interp.set_tensor(in_idx, dummy_i8)
            interp.invoke()

        ts = []
        for _ in range(N_RUNS):
            t0 = time.perf_counter()
            interp.set_tensor(in_idx, dummy_i8)
            interp.invoke()
            ts.append((time.perf_counter() - t0) * 1000)

        avg = np.mean(ts)
        p95 = np.percentile(ts, 95)
        p99 = np.percentile(ts, 99)
        lat_records[f'{name}_INT8'] = dict(avg_ms=avg, p95_ms=p95, p99_ms=p99)
        ok = '✓' if p95 < 100 else '✗'
        print(f'{name:20s} | {avg:8.1f} | {p95:8.1f} | {p99:8.1f} | {ok:>8}')
    except Exception as e:
        print(f'  ✗ {name} TFLite inference failed: {e}')

# ── Step 4: Pick best deploy model (lowest p95 among accuracy winners) ────────
# TCN had best recoil F1 in previous run — prioritise it if it converted
best_deploy = None
for preferred in ['TCN', 'ST_Transformer', 'Conv1D']:
    if preferred in tflite_paths:
        best_deploy = preferred
        break

if best_deploy:
    tflite_path = tflite_paths[best_deploy]   # used by Stage 11 summary
    print(f'\n✓ Selected deploy model: {best_deploy}')
    print(f'  Path: {tflite_path}')
else:
    print('⚠ No TFLite model exported successfully')
    tflite_path = None
# Out:
# Exporting TCN → TFLite INT8...
# Saved artifact at '/tmp/tmppio4auy0'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 60, 12), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   Dict[['rate', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['depth', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['recoil', TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)]]
# Captures:
#   132156287595344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132156303046800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777415312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777414736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777408976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777416080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777409744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777415504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777413392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777414544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777414352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777416272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777413776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777413968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777412240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777415888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777414160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777410320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777410512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777409168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777408784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777410128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777413584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777412048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777411280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777412816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777412624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777412432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777410704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777411472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777416656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777401296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777411664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777417040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777415120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777405136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777413008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777411088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777416848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777415696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774237008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774231824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777411856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774230864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774230480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774228752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774236816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774238352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774236432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774233552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774236048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774231056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774232784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774238544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774232976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774235088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   ✓ TCN: 134.3 KB
# Exporting Conv1D → TFLite INT8...
# Saved artifact at '/tmp/tmpcw7fatnn'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 60, 12), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   Dict[['rate', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['depth', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['recoil', TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)]]
# Captures:
#   132155774229520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768230288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768230864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768229136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   ✓ Conv1D: 101.0 KB
# Exporting ST_Transformer → TFLite INT8...
# Saved artifact at '/tmp/tmpo_5mmmvc'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 60, 12), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   Dict[['rate', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['depth', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['recoil', TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)]]
# Captures:
#   132155725392080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725389200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725397264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725382096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725397840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725394000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725397456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725390544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725388624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725392272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725391696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725391120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725391888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725389008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725392848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725393232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725390160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725392656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725393040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725389584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725393424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725389392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725392464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725396112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725390736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574875536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574869968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574873808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574873040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574873424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574868624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574869008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574868048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574868432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574868816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574868240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574867472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574863824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574871312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574864784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574865168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574873616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   ✓ ST_Transformer: 122.5 KB
#
# CPU latency benchmark — Keras float32 (simulates mid-range Android)
#
# Model                |   Avg ms |   p95 ms |   p99 ms |  <100ms?
# --------------------------------------------------------------
# BiLSTM               |     61.1 |     79.4 |     87.1 |        ✓
# CNN_LSTM             |     22.9 |     27.4 |     32.3 |        ✓
# GRU                  |     36.4 |     39.3 |     46.1 |        ✓
# TCN                  |     67.2 |     84.4 |     87.2 |        ✓
# Conv1D               |     15.5 |     16.5 |     20.4 |        ✓
# ST_Transformer       |     42.7 |     46.1 |     52.6 |        ✓
# CNN_BiLSTM           |     66.7 |     90.6 |     97.3 |        ✓
#
# TFLite INT8 latency — deploy candidates only
#
# Model                |   Avg ms |   p95 ms |   p99 ms |  <100ms?
# --------------------------------------------------------------
# TCN                  |      0.4 |      0.5 |      0.6 |        ✓
# Conv1D               |      0.1 |      0.2 |      0.2 |        ✓
# ST_Transformer       |      1.2 |      1.9 |      2.1 |        ✓
#
# ✓ Selected deploy model: TCN
#   Path: /content/drive/MyDrive/cpr_coach_checkpoints_tf/TCN_int8.tflite

# %% [markdown]
# ## STAGE 11 — Final Summary Report

# %%
print('\n' + '='*70)
print(' CPR-COACH BENCHMARK — FINAL REPORT')
print('='*70)

print('\n📊 Test-Set Weighted F1 (%)')
print(res_df[['rate_f1_w', 'depth_f1_w', 'recoil_f1_w']].to_string())

print('\n📊 Test-Set Weighted Precision (%)')
print(res_df[['rate_precision_w', 'depth_precision_w', 'recoil_precision_w']].to_string())

print('\n📊 Test-Set Weighted Recall (%)')
print(res_df[['rate_recall_w', 'depth_recall_w', 'recoil_recall_w']].to_string())

print('\n📊 AUC-ROC (%)')
print(res_df[['rate_auc', 'depth_auc', 'recoil_auc']].to_string())

print('\n⏱  Server CPU Latency (ms) — all models')
print(pd.DataFrame(lat_records).T.round(1).to_string())

# ── Best model (accuracy only — web backend has no hard latency constraint) ───
best = res_df.loc[best_name]
keras_p95 = lat_records.get(best_name, {}).get('p95_ms', 0.0)

print(f'\n🏆 Recommended model : {best_name}')
print(f'   Deployment target : Web platform (FastAPI/Flask + Keras)')
print(f'   Rate  F1_w        : {float(best["rate_f1_w"]):.1f}%')
print(f'   Depth F1_w        : {float(best["depth_f1_w"]):.1f}%')
print(f'   Recoil F1_w       : {float(best["recoil_f1_w"]):.1f}%')
print(f'   Rate  Precision_w : {float(best["rate_precision_w"]):.1f}%')
print(f'   Depth Precision_w : {float(best["depth_precision_w"]):.1f}%')
print(f'   Recoil Precision_w: {float(best["recoil_precision_w"]):.1f}%')
print(f'   Rate  Recall_w    : {float(best["rate_recall_w"]):.1f}%')
print(f'   Depth Recall_w    : {float(best["depth_recall_w"]):.1f}%')
print(f'   Recoil Recall_w   : {float(best["recoil_recall_w"]):.1f}%')
print(f'   Server CPU p95    : {keras_p95:.1f} ms per inference')
print(f'   (GPU server will be significantly faster than this CPU benchmark)')

# Save best model explicitly
best_model_path = CHECKPOINT_DIR / f'{best_name}_final.keras'
all_models[best_name].save(str(best_model_path))
print(f'\n   Saved to: {best_model_path}')

# ── Proposal targets (Section 1.4) ───────────────────────────────────────────
print('\n🎯 Proposal targets (Section 1.4):')
for task in ['rate', 'depth', 'recoil']:
    f1 = float(best[f'{task}_f1_w'])
    ok = '✓' if f1 >= 85 else '⚠'
    print(f'  {ok} {task.capitalize():8s} F1_w = {f1:.1f}%  (target ≥85%)')

# Latency target is now "acceptable for web UX" not "<100ms mobile"
# A 500ms server response is fine for feedback after a compression cycle
print(f'  {"✓" if keras_p95 < 500 else "⚠"} '
      f'Latency p95 = {keras_p95:.1f} ms  (target <500 ms for web UX)')

# ── Gap analysis ─────────────────────────────────────────────────────────────
print('\n📋 Gap analysis:')
for task in ['rate', 'depth', 'recoil']:
    f1 = float(best[f'{task}_f1_w'])
    gap = f1 - 85.0
    if gap >= 0:
        print(f'  ✓ {task.capitalize():8s} exceeds target by +{gap:.1f} pp')
    else:
        print(f'  ⚠ {task.capitalize():8s} is {abs(gap):.1f} pp below target')

# ── Model ranking summary ─────────────────────────────────────────────────────
print('\n📋 Full model ranking (by mean F1, Precision, Recall across all tasks):')
res_df['mean_f1_w'] = res_df[['rate_f1_w', 'depth_f1_w', 'recoil_f1_w']].mean(axis=1)
res_df['mean_precision_w'] = res_df[['rate_precision_w', 'depth_precision_w', 'recoil_precision_w']].mean(axis=1)
res_df['mean_recall_w'] = res_df[['rate_recall_w', 'depth_recall_w', 'recoil_recall_w']].mean(axis=1)

print('\nRanked by Mean Weighted F1-score:')
ranking_f1 = res_df[['rate_f1_w', 'depth_f1_w', 'recoil_f1_w', 'mean_f1_w']].sort_values(
    'mean_f1_w', ascending=False).round(1)
print(ranking_f1.to_string())

print('\nRanked by Mean Weighted Precision:')
ranking_precision = res_df[['rate_precision_w', 'depth_precision_w', 'recoil_precision_w', 'mean_precision_w']].sort_values(
    'mean_precision_w', ascending=False).round(1)
print(ranking_precision.to_string())

print('\nRanked by Mean Weighted Recall:')
ranking_recall = res_df[['rate_recall_w', 'depth_recall_w', 'recoil_recall_w', 'mean_recall_w']].sort_values(
    'mean_recall_w', ascending=False).round(1)
print(ranking_recall.to_string())

print(f'\n📂 All outputs saved to: {CHECKPOINT_DIR}')
print('   Includes: .keras models, CSV logs, confusion matrices,')
print('   training curves, benchmark_results.csv')
print('\n' + '='*70)
# Out:
# ======================================================================
#  CPR-COACH BENCHMARK — FINAL REPORT
# ======================================================================
#
# 📊 Test-Set Weighted F1 (%)
#                 rate_f1_w  depth_f1_w  recoil_f1_w
# model
# BiLSTM              70.00       95.31        81.96
# CNN_LSTM            86.21       97.34        85.44
# GRU                 64.44       91.55        75.36
# TCN                 91.71       98.27        88.50
# Conv1D              86.79       96.32        84.92
# ST_Transformer      78.16       87.39        76.46
# CNN_BiLSTM          91.31       97.55        88.15
#
# 📊 Test-Set Weighted Precision (%)
#                 rate_precision_w  depth_precision_w  recoil_precision_w
# model
# BiLSTM                     87.19              95.26               81.97
# CNN_LSTM                   90.47              97.33               85.99
# GRU                        83.61              91.85               75.38
# TCN                        93.80              98.27               89.22
# Conv1D                     91.08              96.31               86.40
# ST_Transformer             85.72              89.26               78.79
# CNN_BiLSTM                 92.32              97.53               88.41
#
# 📊 Test-Set Weighted Recall (%)
#                 rate_recall_w  depth_recall_w  recoil_recall_w
# model
# BiLSTM                  63.32           95.54            81.95
# CNN_LSTM                84.18           97.38            85.37
# GRU                     56.26           92.89            75.35
# TCN                     90.90           98.30            88.45
# Conv1D                  84.84           96.34            84.86
# ST_Transformer          74.43           86.44            76.42
# CNN_BiLSTM              90.76           97.57            88.11
#
# 📊 AUC-ROC (%)
#                 rate_auc  depth_auc  recoil_auc
# model
# BiLSTM             86.65      95.19       89.25
# CNN_LSTM           94.36      97.86       94.20
# GRU                77.29      90.44       83.88
# TCN                98.27      99.34       95.93
# Conv1D             94.64      97.39       94.34
# ST_Transformer     85.87      93.26       87.93
# CNN_BiLSTM         95.49      98.43       95.54
#
# ⏱  Server CPU Latency (ms) — all models
#                      avg_ms  p95_ms  p99_ms
# BiLSTM                 61.1    79.4    87.1
# CNN_LSTM               22.9    27.4    32.3
# GRU                    36.4    39.3    46.1
# TCN                    67.2    84.4    87.2
# Conv1D                 15.5    16.5    20.4
# ST_Transformer         42.7    46.1    52.6
# CNN_BiLSTM             66.7    90.6    97.3
# TCN_INT8                0.4     0.5     0.6
# Conv1D_INT8             0.1     0.2     0.2
# ST_Transformer_INT8     1.2     1.9     2.1
#
# 🏆 Recommended model : TCN
#    Deployment target : Web platform (FastAPI/Flask + Keras)
#    Rate  F1_w        : 91.7%
#    Depth F1_w        : 98.3%
#    Recoil F1_w       : 88.5%
#    Rate  Precision_w : 93.8%
#    Depth Precision_w : 98.3%
#    Recoil Precision_w: 89.2%
#    Rate  Recall_w    : 90.9%
#    Depth Recall_w    : 98.3%
#    Recoil Recall_w   : 88.5%
#    Server CPU p95    : 84.4 ms per inference
#    (GPU server will be significantly faster than this CPU benchmark)
#
#    Saved to: /content/drive/MyDrive/cpr_coach_checkpoints_tf/TCN_final.keras
#
# 🎯 Proposal targets (Section 1.4):
#   ✓ Rate     F1_w = 91.7%  (target ≥85%)
#   ✓ Depth    F1_w = 98.3%  (target ≥85%)
#   ✓ Recoil   F1_w = 88.5%  (target ≥85%)
#   ✓ Latency p95 = 84.4 ms  (target <500 ms for web UX)
#
# 📋 Gap analysis:
#   ✓ Rate     exceeds target by +6.7 pp
#   ✓ Depth    exceeds target by +13.3 pp
#   ✓ Recoil   exceeds target by +3.5 pp
#
# 📋 Full model ranking (by mean F1, Precision, Recall across all tasks):
#
# Ranked by Mean Weighted F1-score:
#                 rate_f1_w  depth_f1_w  recoil_f1_w  mean_f1_w
# model
# TCN                  91.7        98.3         88.5       92.8
# CNN_BiLSTM           91.3        97.6         88.2       92.3
# CNN_LSTM             86.2        97.3         85.4       89.7
# Conv1D               86.8        96.3         84.9       89.3
# BiLSTM               70.0        95.3         82.0       82.4
# ST_Transformer       78.2        87.4         76.5       80.7
# GRU                  64.4        91.6         75.4       77.1
#
# Ranked by Mean Weighted Precision:
#                 rate_precision_w  depth_precision_w  recoil_precision_w  mean_precision_w
# model
# TCN                         93.8               98.3                89.2              93.8
# CNN_BiLSTM                  92.3               97.5                88.4              92.8
# CNN_LSTM                    90.5               97.3                86.0              91.3
# Conv1D                      91.1               96.3                86.4              91.3
# BiLSTM                      87.2               95.3                82.0              88.1
# ST_Transformer              85.7               89.3                78.8              84.6
# GRU                         83.6               91.8                75.4              83.6
#
# Ranked by Mean Weighted Recall:
#                 rate_recall_w  depth_recall_w  recoil_recall_w  mean_recall_w
# model
# TCN                      90.9            98.3             88.4           92.6
# CNN_BiLSTM               90.8            97.6             88.1           92.1
# CNN_LSTM                 84.2            97.4             85.4           89.0
# Conv1D                   84.8            96.3             84.9           88.7
# BiLSTM                   63.3            95.5             82.0           80.3
# ST_Transformer           74.4            86.4             76.4           79.1
# GRU                      56.3            92.9             75.4           74.8
#
# 📂 All outputs saved to: /content/drive/MyDrive/cpr_coach_checkpoints_tf
#    Includes: .keras models, CSV logs, confusion matrices,
#    training curves, benchmark_results.csv
#
# ======================================================================

# %%
# ── Stage 12: Future-proofing — save all deployment artifacts ─────────────────
# Web now, mobile/edge later. Save everything so retraining isn't needed
# when the deployment target changes.

from pathlib import Path
import json

DEPLOY_DIR = CHECKPOINT_DIR / 'deployment_artifacts'
DEPLOY_DIR.mkdir(exist_ok=True)

# ── Tier 1: Web deployment (today) ───────────────────────────────────────────
WEB_DIR = DEPLOY_DIR / 'web'
WEB_DIR.mkdir(exist_ok=True)

web_model = best_name  # CNN_BiLSTM or whoever won
all_models[web_model].save(str(WEB_DIR / f'{web_model}.keras'))
print(f'✓ Web model saved: {web_model}.keras')

# ── Tier 2: Mobile candidates (future Android/iOS) ───────────────────────────
MOBILE_DIR = DEPLOY_DIR / 'mobile'
MOBILE_DIR.mkdir(exist_ok=True)

mobile_candidates = ['TCN', 'Conv1D', 'ST_Transformer']

for name in mobile_candidates:
    if name not in all_models:
        print(f'⚠ {name} not available — skipping')
        continue

    # Save full Keras model (can convert to TFLite later without retraining)
    all_models[name].save(str(MOBILE_DIR / f'{name}.keras'))

    # Also export TFLite INT8 now while we're here
    try:
        calib_idx  = np.random.choice(len(X_train), min(200, len(X_train)), replace=False)
        calib_data = X_train[calib_idx].astype(np.float32)

        def representative_dataset():
            for i in range(len(calib_data)):
                yield [calib_data[i:i+1]]

        converter = tf.lite.TFLiteConverter.from_keras_model(all_models[name])
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        converter.representative_dataset = representative_dataset
        converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
        converter.inference_input_type  = tf.int8
        converter.inference_output_type = tf.int8

        tflite_model = converter.convert()
        tflite_path  = MOBILE_DIR / f'{name}_int8.tflite'
        tflite_path.write_bytes(tflite_model)

        keras_size  = (MOBILE_DIR / f'{name}.keras').stat().st_size / 1024**2
        tflite_size = tflite_path.stat().st_size / 1024**2
        print(f'✓ {name}: keras={keras_size:.1f} MB  tflite={tflite_size:.1f} MB')

    except Exception as e:
        print(f'⚠ {name} TFLite export failed: {e}')
        print(f'  .keras file still saved — convert later with: '
              f'tf.lite.TFLiteConverter.from_saved_model()')

# ── Tier 3: Edge/camera (future 360°/IP cam) ─────────────────────────────────
# Conv1D at ~15ms is the only realistic candidate for edge hardware.
# Save ONNX format for maximum runtime compatibility (OpenCV, ONNX Runtime, etc.)
EDGE_DIR = DEPLOY_DIR / 'edge'
EDGE_DIR.mkdir(exist_ok=True)

edge_candidate = 'Conv1D'
if edge_candidate in all_models:
    all_models[edge_candidate].save(str(EDGE_DIR / f'{edge_candidate}.keras'))
    try:
        import tf2onnx
        import onnx
        model_proto, _ = tf2onnx.convert.from_keras(
            all_models[edge_candidate],
            input_signature=[tf.TensorSpec(
                shape=(1, SEQ_LEN, N_FEATS), dtype=tf.float32, name='input')],
            opset=13
        )
        onnx_path = EDGE_DIR / f'{edge_candidate}.onnx'
        onnx.save(model_proto, str(onnx_path))
        print(f'✓ Edge ONNX saved: {onnx_path.name}  '
              f'({onnx_path.stat().st_size/1024**2:.1f} MB)')
    except ImportError:
        print('⚠ tf2onnx not installed — skipping ONNX export')
        print('  Install with: pip install tf2onnx onnx')
        print(f'  .keras file saved at {EDGE_DIR}/{edge_candidate}.keras')

# ── Save deployment manifest ──────────────────────────────────────────────────
manifest = {
    'web': {
        'model': web_model,
        'format': 'keras',
        'runtime': 'TensorFlow serving / FastAPI',
        'path': str(WEB_DIR / f'{web_model}.keras')
    },
    'mobile': {
        'candidates': mobile_candidates,
        'format': ['keras', 'tflite_int8'],
        'runtime': 'TFLite Android/iOS',
        'recommended': 'TCN',
        'note': 'TCN best recoil F1 among <100ms models'
    },
    'edge': {
        'model': edge_candidate,
        'format': ['keras', 'onnx'],
        'runtime': 'ONNX Runtime / OpenCV DNN',
        'note': 'Conv1D at ~15ms is only model viable for edge inference'
    },
    'label_encoders': {
        'rate':   list(le_rate.classes_),
        'depth':  list(le_depth.classes_),
        'recoil': list(le_recoil.classes_)
    },
    'input': {
        'shape': [1, SEQ_LEN, N_FEATS],
        'description': '12 biomechanical features over SEQ_LEN frames'
    }
}

manifest_path = DEPLOY_DIR / 'deployment_manifest.json'
with open(manifest_path, 'w') as f:
    json.dump(manifest, f, indent=2)

print(f'\n✓ Deployment manifest saved: {manifest_path}')
print('\nArtifact summary:')
print(f'  web/     → {web_model}.keras          (deploy today)')
print(f'  mobile/  → TCN + Conv1D .keras + .tflite  (deploy when ready)')
print(f'  edge/    → Conv1D .keras + .onnx          (deploy when ready)')
# Out:
# ✓ Web model saved: TCN.keras
# Saved artifact at '/tmp/tmpgj7cd0wh'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 60, 12), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   Dict[['rate', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['depth', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['recoil', TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)]]
# Captures:
#   132156287595344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132156303046800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777415312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777414736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777408976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777416080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777409744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777415504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777413392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777414544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777414352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777416272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777413776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777413968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777412240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777415888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777414160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777410320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777410512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777409168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777408784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777410128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777413584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777412048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777411280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777412816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777412624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777412432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777410704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777411472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777416656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777401296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777411664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777417040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777415120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777405136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777413008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777411088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777416848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777415696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774237008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774231824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155777411856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774230864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774230480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774228752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774236816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774238352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774236432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774233552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774236048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774231056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774232784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774238544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774232976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155774235088: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✓ TCN: keras=1.3 MB  tflite=0.1 MB
# Saved artifact at '/tmp/tmpkyisgv3_'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 60, 12), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   Dict[['rate', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['depth', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['recoil', TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)]]
# Captures:
#   132155774229520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768230288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768230864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768229136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768227600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155768226640: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✓ Conv1D: keras=1.0 MB  tflite=0.1 MB
# Saved artifact at '/tmp/tmpfq_yb4kq'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 60, 12), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   Dict[['rate', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['depth', TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)], ['recoil', TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)]]
# Captures:
#   132155725392080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725389200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725397264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725382096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725397840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725394000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725397456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725390544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725388624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725392272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725391696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725391120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725391888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725389008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725392848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725393232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725390160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725392656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725393040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725389584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725393424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725389392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725392464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725396112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155725390736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574875536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574869968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574873808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574873040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574873424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574868624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574869008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574868048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574868432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574868816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574868240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574867472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574863824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574871312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574864784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574865168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132155574873616: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✓ ST_Transformer: keras=1.0 MB  tflite=0.1 MB
# ⚠ tf2onnx not installed — skipping ONNX export
#   Install with: pip install tf2onnx onnx
#   .keras file saved at /content/drive/MyDrive/cpr_coach_checkpoints_tf/deployment_artifacts/edge/Conv1D.keras
#
# ✓ Deployment manifest saved: /content/drive/MyDrive/cpr_coach_checkpoints_tf/deployment_artifacts/deployment_manifest.json
#
# Artifact summary:
#   web/     → TCN.keras          (deploy today)
#   mobile/  → TCN + Conv1D .keras + .tflite  (deploy when ready)
#   edge/    → Conv1D .keras + .onnx          (deploy when ready)
